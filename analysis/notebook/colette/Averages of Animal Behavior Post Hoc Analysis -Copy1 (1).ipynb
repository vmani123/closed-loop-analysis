# %%
import joblib
import os
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import pickle
import time
from tkinter import *
import tkinter as tk
from tkinter import filedialog
from tqdm import tqdm
from tqdm import notebook
import itertools
import math
import seaborn as sns

# %% [markdown]
# # Selecting Multiple NumPy Files

# %%
# Create Tk root
root = tk.Tk()
# Hide the main window
root.withdraw()
root.call('wm', 'attributes', '.', '-topmost', True)

# Ask user to select multiple files from different folders
infiles = []
while True:
    file = filedialog.askopenfilename(title='Load posthoc-predictions.npy', initialdir='/')
    if not file:  # Break the loop if no file selected or Cancel button clicked
        break
    infiles.append(file)
    
file_amount = 0

# Iterate over selected files
for file in infiles:
    file_amount += 1
    print('Selected File:', file)
# Out:
# Selected File: Z:/KayCei/VideoOutputCamera 0-20072023-090516_posthoc-predictions.npy
# Selected File: Z:/KayCei/VideoOutputCamera 0-20072023-102037_posthoc-predictions.npy
# Selected File: Z:/KayCei/VideoOutputCamera 0-24072023-122530_posthoc-predictions.npy
# Selected File: Z:/KayCei/VideoOutputCamera 0-27062023-092810_posthoc-predictions.npy

# %% [markdown]
# # Total Time of Video in deciseconds

# %%
# Create an empty dictionary to store random lists separately
behavior_dict = {}

# Iterate over selected files
for file in infiles:
    # Load the file as a NumPy array
    behavior = np.load(file)
    
    # Get the file name without the extension
    file_name = os.path.splitext(os.path.basename(file))[0]
    
    # Calculate the original time of the video in minutes
    original_time_minutes = len(behavior) / 600
    
    # Calculate the number of elements needed to limit the video to 65 minutes (39000 elements)
    limit_elements = min(len(behavior), 39000)
    
    # Limit the behavior array to the calculated number of elements
    limited_behavior = behavior[:limit_elements]
    
    # Check if the file name already exists in the dictionary
    if file_name in behavior_dict:
        # If the file name exists, append the limited array to the existing list
        behavior_dict[file_name].append(list(limited_behavior))
    else:
        # If the file name doesn't exist, create a new list with the limited array
        behavior_dict[file_name] = list(limited_behavior)

    #print(f'This video is {len(behavior)} deciseconds, which is {original_time_minutes} minutes')
  
    # Calculate the time of the limited video in minutes
    limited_time_minutes = len(limited_behavior) / 600

    #print(f'This video is {len(limited_behavior)} deciseconds, which is {limited_time_minutes} minutes')

# %%
# Print the random lists separately using the dictionary
for key in behavior_dict: #key = file_name
    print(f'\033[1;31m{"="*10} File: {key} {"="*10}\033[0m')
    #for value in behavior_dict[key]: #value = "random_list"
        #print(f'Random List: {value}')
    print('\u2501' * 70)  # Print a wider black line consisting of the Unicode character U+2501
    print()
# Out:
# ========== File: VideoOutputCamera 0-20072023-090516_posthoc-predictions ==========
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# ========== File: VideoOutputCamera 0-20072023-102037_posthoc-predictions ==========
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# ========== File: VideoOutputCamera 0-24072023-122530_posthoc-predictions ==========
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# ========== File: VideoOutputCamera 0-27062023-092810_posthoc-predictions ==========
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

# %% [markdown]
# # Creates an array with tuples of (behavior type, stim count)

# %%
# Save the behavior type and duration information in behavior_type_and_duration_dict
behavior_type_and_duration_dict = {}

# Compute behavior_type_and_duration for each video's random list and store it in the dictionary
for key in behavior_dict: #key = file_name
    behavior_list = behavior_dict[key]
    behavior_type_and_duration = []
    current_value = behavior_list[0]
    count = 0

    for value in behavior_list:
        #print(value)
        if value == current_value:
                count += 1
        else:
            behavior_type_and_duration.append((current_value, count))
            current_value = value
            count = 1        
    behavior_type_and_duration_dict[key] = behavior_type_and_duration

#print(behavior_type_and_duration_dict)


# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (4.0, 2)
# Behavior Type and Duration: (5.0, 42)
# Behavior Type and Duration: (1.0, 3)
# Behavior Type and Duration: (5.0, 5)
# Behavior Type and Duration: (4.0, 1)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (4.0, 3)
# Behavior Type and Duration: (5.0, 5)
# Behavior Type and Duration: (1.0, 3)
# Behavior Type and Duration: (5.0, 18)
# Behavior Type and Duration: (2.0, 1)
# Behavior Type and Duration: (5.0, 31)
# Behavior Type and Duration: (0.0, 1)
# Behavior Type and Duration: (5.0, 9)
# Behavior Type and Duration: (0.0, 1)
# Behavior Type and Duration: (5.0, 5)
# Behavior Type and Duration: (4.0, 9)
# Behavior Type and Duration: (5.0, 17)
# Behavior Type and Duration: (2.0, 2)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (2.0, 1)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (2.0, 2)
# Behavior Type and Duration: (5.0, 2)
# Behavior Type and Duration: (2.0, 17)
# Behavior Type and Duration: (5.0, 24)
# Behavior Type and Duration: (1.0, 2)
# Behavior Type and Duration: (5.0, 2)
# Behavior Type and Duration: (1.0, 1)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (1.0, 1)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (1.0, 1)
# Behavior Type and Duration: (5.0, 101)
# Behavior Type and Duration: (1.0, 1)
# Behavior Type and Duration: (5.0, 5)
# Behavior Type and Duration: (1.0, 1)
# Behavior Type and Duration: (5.0, 6)
# Behavior Type and Duration: (1.0, 1)
# Behavior Type and Duration: (5.0, 77)
# Behavior Type and Duration: (2.0, 11)
# Behavior Type and Duration: (0.0, 2)
# Behavior Type and Duration: (5.0, 4)
# Behavior Type and Duration: (0.0, 1)
# Behavior Type and Duration: (5.0, 7)
# Behavior Type and Duration: (0.0, 5)
# Behavior Type and Duration: (5.0, 110)
# Behavior Type and Duration: (1.0, 1)
# Behavior Type and Duration: (5.0, 176)
# Behavior Type and Duration: (2.0, 1)
# Behavior Type and Duration: (5.0, 7)
# Behavior Type and Duration: (1.0, 2)
# Behavior Type and Duration: (5.0, 103)
# Behavior Type and Duration: (2.0, 2)
# Behavior Type and Duration: (5.0, 36)
# Behavior Type and Duration: (2.0, 12)
# Behavior Type and Duration: (5.0, 51)
# Behavior Type and Duration: (1.0, 3)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (1.0, 1)
# Behavior Type and Duration: (5.0, 90)
# Behavior Type and Duration: (2.0, 1)
# Behavior Type and Duration: (5.0, 14)
# Behavior Type and Duration: (0.0, 3)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (0.0, 4)
# Behavior Type and Duration: (5.0, 127)
# Behavior Type and Duration: (2.0, 1)
# Behavior Type and Duration: (5.0, 5)
# Behavior Type and Duration: (2.0, 1)
# Behavior Type and Duration: (5.0, 14)
# Behavior Type and Duration: (0.0, 1)
# Behavior Type and Duration: (5.0, 32)
# Behavior Type and Duration: (2.0, 8)
# Behavior Type and Duration: (5.0, 7)
# Behavior Type and Duration: (0.0, 7)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (0.0, 1)
# Behavior Type and Duration: (5.0, 4)
# Behavior Type and Duration: (0.0, 1)
# Behavior Type and Duration: (5.0, 27)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 710)
# Behavior Type and Duration: (3.0, 3)
# Behavior Type and Duration: (5.0, 132)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 3)
# Behavior Type and Duration: (3.0, 3)
# Behavior Type and Duration: (5.0, 609)
# Behavior Type and Duration: (3.0, 2)
# Behavior Type and Duration: (5.0, 807)
# Behavior Type and Duration: (4.0, 1)
# Behavior Type and Duration: (5.0, 3)
# Behavior Type and Duration: (3.0, 7)
# Behavior Type and Duration: (5.0, 3)
# Behavior Type and Duration: (3.0, 2)
# Behavior Type and Duration: (5.0, 12)
# Behavior Type and Duration: (3.0, 2)
# Behavior Type and Duration: (5.0, 5)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 7)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 5)
# Behavior Type and Duration: (3.0, 5)
# Behavior Type and Duration: (5.0, 2)
# Behavior Type and Duration: (3.0, 5)
# Behavior Type and Duration: (5.0, 6)
# Behavior Type and Duration: (3.0, 2)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (3.0, 5)
# Behavior Type and Duration: (5.0, 4)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 3)
# Behavior Type and Duration: (3.0, 2)
# Behavior Type and Duration: (5.0, 10)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 41)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 6)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 14)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 9)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 4)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 2)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 4)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (3.0, 2)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 3)
# Behavior Type and Duration: (3.0, 2)
# Behavior Type and Duration: (5.0, 3)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (3.0, 3)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (3.0, 2)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (3.0, 1)
# ...
# Behavior Type and Duration: (3.0, 2)
# Behavior Type and Duration: (5.0, 2)
# Behavior Type and Duration: (4.0, 2)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 2)
# Behavior Type and Duration: (4.0, 5)
# Behavior Type and Duration: (5.0, 3)
# Behavior Type and Duration: (3.0, 3)
# Behavior Type and Duration: (5.0, 2)
# Behavior Type and Duration: (3.0, 6)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (3.0, 4)
# Behavior Type and Duration: (5.0, 2)
# Behavior Type and Duration: (3.0, 4)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (3.0, 3)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (3.0, 8)
# Behavior Type and Duration: (5.0, 7)
# Behavior Type and Duration: (3.0, 3)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (3.0, 6)
# Behavior Type and Duration: (5.0, 15)
# Behavior Type and Duration: (3.0, 2)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (3.0, 6)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (3.0, 3)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (3.0, 20)
# Behavior Type and Duration: (5.0, 3)
# Behavior Type and Duration: (3.0, 19)
# Behavior Type and Duration: (4.0, 2)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (4.0, 15)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (4.0, 7)
# Behavior Type and Duration: (3.0, 5)
# Behavior Type and Duration: (4.0, 5)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (4.0, 4)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (4.0, 8)
# Behavior Type and Duration: (3.0, 2)
# Behavior Type and Duration: (4.0, 2)
# Behavior Type and Duration: (3.0, 2)
# Behavior Type and Duration: (4.0, 9)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (4.0, 5)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (0.0, 1)
# Behavior Type and Duration: (5.0, 8)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 32)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 16)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 11)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (3.0, 2)
# Behavior Type and Duration: (5.0, 17)
# Behavior Type and Duration: (3.0, 2)
# Behavior Type and Duration: (5.0, 10)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 3)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 2)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 83)
# Behavior Type and Duration: (4.0, 2)
# Behavior Type and Duration: (5.0, 23)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 54)
# Behavior Type and Duration: (3.0, 4)
# Behavior Type and Duration: (5.0, 15)
# Behavior Type and Duration: (4.0, 1)
# Behavior Type and Duration: (5.0, 33)
# Behavior Type and Duration: (4.0, 1)
# Behavior Type and Duration: (5.0, 10)
# Behavior Type and Duration: (4.0, 1)
# Behavior Type and Duration: (5.0, 11)
# Behavior Type and Duration: (4.0, 2)
# Behavior Type and Duration: (5.0, 3)
# Behavior Type and Duration: (4.0, 1)
# Behavior Type and Duration: (5.0, 120)
# Behavior Type and Duration: (4.0, 1)
# Behavior Type and Duration: (5.0, 20)
# Behavior Type and Duration: (4.0, 3)
# Behavior Type and Duration: (5.0, 5)
# Behavior Type and Duration: (3.0, 2)
# Behavior Type and Duration: (5.0, 3)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (3.0, 2)
# Behavior Type and Duration: (5.0, 2)
# Behavior Type and Duration: (4.0, 1)
# Behavior Type and Duration: (5.0, 2)
# Behavior Type and Duration: (3.0, 3)
# Behavior Type and Duration: (4.0, 2)
# Behavior Type and Duration: (3.0, 2)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (3.0, 7)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (4.0, 1)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 4)
# Behavior Type and Duration: (4.0, 4)
# Behavior Type and Duration: (5.0, 7)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (4.0, 2)
# Behavior Type and Duration: (5.0, 2)
# Behavior Type and Duration: (4.0, 3)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (4.0, 43)
# Behavior Type and Duration: (3.0, 4)
# Behavior Type and Duration: (5.0, 7)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 6)
# Behavior Type and Duration: (2.0, 12)
# Behavior Type and Duration: (5.0, 4)
# Behavior Type and Duration: (2.0, 1)
# Behavior Type and Duration: (5.0, 2)
# Behavior Type and Duration: (2.0, 2)
# Behavior Type and Duration: (5.0, 4)
# Behavior Type and Duration: (2.0, 5)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (0.0, 3)
# Behavior Type and Duration: (5.0, 44)
# Behavior Type and Duration: (0.0, 1)
# Behavior Type and Duration: (5.0, 9)
# Behavior Type and Duration: (0.0, 1)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (0.0, 1)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (0.0, 4)
# Behavior Type and Duration: (2.0, 1)
# Behavior Type and Duration: (0.0, 3)
# Behavior Type and Duration: (5.0, 19)
# Behavior Type and Duration: (2.0, 16)
# Behavior Type and Duration: (5.0, 3)
# Behavior Type and Duration: (2.0, 1)
# Behavior Type and Duration: (5.0, 4)
# Behavior Type and Duration: (2.0, 1)
# Behavior Type and Duration: (5.0, 7)
# Behavior Type and Duration: (2.0, 7)
# Behavior Type and Duration: (5.0, 18)
# Behavior Type and Duration: (2.0, 1)
# Behavior Type and Duration: (5.0, 2)
# Behavior Type and Duration: (2.0, 1)
# Behavior Type and Duration: (0.0, 4)
# Behavior Type and Duration: (2.0, 19)
# Behavior Type and Duration: (5.0, 17)
# Behavior Type and Duration: (2.0, 1)
# Behavior Type and Duration: (5.0, 2)
# Behavior Type and Duration: (2.0, 1)
# Behavior Type and Duration: (0.0, 1)
# Behavior Type and Duration: (5.0, 6)
# Behavior Type and Duration: (0.0, 2)
# Behavior Type and Duration: (5.0, 5)
# Behavior Type and Duration: (0.0, 2)
# Behavior Type and Duration: (5.0, 44)
# Behavior Type and Duration: (0.0, 1)
# Behavior Type and Duration: (5.0, 40)
# Behavior Type and Duration: (4.0, 2)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (4.0, 16)
# Behavior Type and Duration: (5.0, 35)
# Behavior Type and Duration: (0.0, 1)
# Behavior Type and Duration: (5.0, 2)
# Behavior Type and Duration: (2.0, 16)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (1.0, 1)
# Behavior Type and Duration: (5.0, 3)
# Behavior Type and Duration: (2.0, 2)
# Behavior Type and Duration: (5.0, 18)
# Behavior Type and Duration: (2.0, 1)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (0.0, 4)
# Behavior Type and Duration: (5.0, 3)
# Behavior Type and Duration: (0.0, 5)
# Behavior Type and Duration: (5.0, 4)
# Behavior Type and Duration: (0.0, 1)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (2.0, 16)
# Behavior Type and Duration: (5.0, 16)
# Behavior Type and Duration: (0.0, 3)
# Behavior Type and Duration: (2.0, 4)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (0.0, 2)
# Behavior Type and Duration: (5.0, 4)
# Behavior Type and Duration: (0.0, 7)
# Behavior Type and Duration: (5.0, 8)
# Behavior Type and Duration: (4.0, 1)
# Behavior Type and Duration: (5.0, 5)
# Behavior Type and Duration: (4.0, 1)
# Behavior Type and Duration: (5.0, 5)
# Behavior Type and Duration: (0.0, 2)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (0.0, 1)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (2.0, 21)
# Behavior Type and Duration: (5.0, 11)
# Behavior Type and Duration: (2.0, 1)
# Behavior Type and Duration: (5.0, 28)
# Behavior Type and Duration: (2.0, 5)
# Behavior Type and Duration: (5.0, 3)
# Behavior Type and Duration: (2.0, 13)
# Behavior Type and Duration: (5.0, 6)
# Behavior Type and Duration: (2.0, 7)
# Behavior Type and Duration: (5.0, 8)
# Behavior Type and Duration: (2.0, 1)
# Behavior Type and Duration: (5.0, 6)
# Behavior Type and Duration: (1.0, 3)
# Behavior Type and Duration: (5.0, 5)
# Behavior Type and Duration: (1.0, 2)
# Behavior Type and Duration: (5.0, 29)
# Behavior Type and Duration: (1.0, 1)
# Behavior Type and Duration: (5.0, 52)
# Behavior Type and Duration: (0.0, 1)
# Behavior Type and Duration: (5.0, 27)
# Behavior Type and Duration: (0.0, 3)
# Behavior Type and Duration: (5.0, 77)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 2)
# Behavior Type and Duration: (3.0, 2)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (3.0, 3)
# Behavior Type and Duration: (5.0, 573)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 6)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 174)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 5)
# Behavior Type and Duration: (3.0, 3)
# Behavior Type and Duration: (5.0, 4)
# Behavior Type and Duration: (2.0, 2)
# Behavior Type and Duration: (5.0, 3)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 2)
# Behavior Type and Duration: (2.0, 1)
# Behavior Type and Duration: (5.0, 2)
# Behavior Type and Duration: (3.0, 4)
# Behavior Type and Duration: (4.0, 1)
# Behavior Type and Duration: (5.0, 5)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 2)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 2)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 3)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 6)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 8)
# Behavior Type and Duration: (3.0, 2)
# Behavior Type and Duration: (5.0, 7)
# Behavior Type and Duration: (4.0, 1)
# Behavior Type and Duration: (5.0, 5)
# Behavior Type and Duration: (3.0, 2)
# Behavior Type and Duration: (5.0, 2)
# Behavior Type and Duration: (3.0, 4)
# Behavior Type and Duration: (5.0, 2)
# Behavior Type and Duration: (3.0, 5)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (2.0, 1)
# Behavior Type and Duration: (5.0, 2)
# Behavior Type and Duration: (3.0, 5)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (3.0, 4)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (3.0, 2)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (3.0, 9)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (3.0, 3)
# Behavior Type and Duration: (5.0, 2)
# Behavior Type and Duration: (3.0, 3)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (3.0, 15)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (3.0, 15)
# Behavior Type and Duration: (5.0, 57)
# Behavior Type and Duration: (1.0, 3)
# Behavior Type and Duration: (5.0, 17)
# Behavior Type and Duration: (4.0, 1)
# Behavior Type and Duration: (5.0, 69)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 3)
# Behavior Type and Duration: (3.0, 1)
# Behavior Type and Duration: (5.0, 32)
# Behavior Type and Duration: (4.0, 2)
# Behavior Type and Duration: (5.0, 4571)
# Behavior Type and Duration: (4.0, 1)
# Behavior Type and Duration: (5.0, 2242)
# Behavior Type and Duration: (4.0, 3)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (4.0, 9)
# Behavior Type and Duration: (5.0, 35)
# Behavior Type and Duration: (2.0, 1)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (2.0, 1)
# Behavior Type and Duration: (5.0, 5)
# Behavior Type and Duration: (2.0, 1)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (2.0, 11)
# Behavior Type and Duration: (5.0, 3)
# Behavior Type and Duration: (2.0, 4)
# Behavior Type and Duration: (5.0, 2)
# Behavior Type and Duration: (2.0, 1)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (2.0, 11)
# Behavior Type and Duration: (5.0, 12)
# Behavior Type and Duration: (0.0, 4)
# Behavior Type and Duration: (5.0, 3)
# Behavior Type and Duration: (0.0, 1)
# Behavior Type and Duration: (2.0, 3)
# Behavior Type and Duration: (5.0, 3)
# Behavior Type and Duration: (2.0, 17)
# Behavior Type and Duration: (0.0, 3)
# Behavior Type and Duration: (5.0, 14)
# Behavior Type and Duration: (2.0, 7)
# Behavior Type and Duration: (5.0, 9)
# Behavior Type and Duration: (2.0, 1)
# Behavior Type and Duration: (5.0, 23)
# Behavior Type and Duration: (2.0, 1)
# Behavior Type and Duration: (5.0, 2)
# Behavior Type and Duration: (0.0, 1)
# Behavior Type and Duration: (5.0, 10)
# Behavior Type and Duration: (0.0, 2)
# Behavior Type and Duration: (2.0, 7)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (2.0, 1)
# Behavior Type and Duration: (5.0, 23)
# Behavior Type and Duration: (2.0, 1)
# Behavior Type and Duration: (5.0, 13)
# Behavior Type and Duration: (2.0, 2)
# Behavior Type and Duration: (5.0, 2)
# Behavior Type and Duration: (2.0, 2)
# Behavior Type and Duration: (0.0, 1)
# Behavior Type and Duration: (2.0, 13)
# Behavior Type and Duration: (5.0, 3)
# Behavior Type and Duration: (2.0, 6)
# Behavior Type and Duration: (5.0, 29)
# Behavior Type and Duration: (0.0, 1)
# Behavior Type and Duration: (5.0, 3)
# Behavior Type and Duration: (0.0, 1)
# Behavior Type and Duration: (5.0, 75)
# Behavior Type and Duration: (0.0, 1)
# Behavior Type and Duration: (5.0, 49)
# Behavior Type and Duration: (4.0, 2)
# Behavior Type and Duration: (5.0, 4)
# Behavior Type and Duration: (3.0, 2)
# Behavior Type and Duration: (5.0, 45)
# Behavior Type and Duration: (4.0, 21)
# Behavior Type and Duration: (5.0, 2)
# Behavior Type and Duration: (4.0, 1)
# Behavior Type and Duration: (5.0, 16)
# Behavior Type and Duration: (4.0, 16)
# Behavior Type and Duration: (5.0, 37)
# Behavior Type and Duration: (4.0, 1)
# Behavior Type and Duration: (5.0, 70)
# Behavior Type and Duration: (4.0, 41)
# Behavior Type and Duration: (5.0, 876)
# Behavior Type and Duration: (0.0, 1)
# Behavior Type and Duration: (5.0, 1298)
# Behavior Type and Duration: (4.0, 2)
# Behavior Type and Duration: (5.0, 4)
# Behavior Type and Duration: (0.0, 1)
# Behavior Type and Duration: (5.0, 86)
# Behavior Type and Duration: (2.0, 1)
# Behavior Type and Duration: (5.0, 2)
# Behavior Type and Duration: (2.0, 1)
# Behavior Type and Duration: (5.0, 14)
# Behavior Type and Duration: (2.0, 3)
# Behavior Type and Duration: (5.0, 7)
# Behavior Type and Duration: (2.0, 2)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (1.0, 5)
# Behavior Type and Duration: (2.0, 1)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (2.0, 18)
# Behavior Type and Duration: (5.0, 32)
# Behavior Type and Duration: (0.0, 4)
# Behavior Type and Duration: (2.0, 12)
# Behavior Type and Duration: (5.0, 21)
# Behavior Type and Duration: (2.0, 8)
# Behavior Type and Duration: (5.0, 8)
# Behavior Type and Duration: (2.0, 5)
# Behavior Type and Duration: (5.0, 7)
# Behavior Type and Duration: (0.0, 3)
# Behavior Type and Duration: (2.0, 7)
# Behavior Type and Duration: (5.0, 13)
# Behavior Type and Duration: (2.0, 1)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (2.0, 3)
# Behavior Type and Duration: (5.0, 2)
# Behavior Type and Duration: (2.0, 8)
# Behavior Type and Duration: (5.0, 44)
# Behavior Type and Duration: (2.0, 1)
# Behavior Type and Duration: (5.0, 2)
# Behavior Type and Duration: (0.0, 3)
# Behavior Type and Duration: (5.0, 2)
# Behavior Type and Duration: (0.0, 1)
# Behavior Type and Duration: (2.0, 5)
# Behavior Type and Duration: (5.0, 2)
# Behavior Type and Duration: (2.0, 6)
# Behavior Type and Duration: (5.0, 4)
# Behavior Type and Duration: (0.0, 1)
# Behavior Type and Duration: (2.0, 7)
# Behavior Type and Duration: (5.0, 2)
# Behavior Type and Duration: (2.0, 8)
# Behavior Type and Duration: (5.0, 28)
# Behavior Type and Duration: (0.0, 2)
# Behavior Type and Duration: (5.0, 1)
# Behavior Type and Duration: (4.0, 1)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

# %% [markdown]
# # Filtering Out Based on Frame Rate of 3

# %%
filtered_behavior_duration_dict = {}

# Filter behavior_type_and_duration_dict to only include entries with duration >= 3
for key in behavior_type_and_duration_dict: #key is file_name
    unfiltered_list = behavior_type_and_duration_dict[key] #currently contains behavior types and durations
    filtered_list = [(behavior, duration) for behavior, duration in unfiltered_list if duration >= 3]
    filtered_behavior_duration_dict[key] = filtered_list

# %% [raw]
# filtered_behavior_duration_dict = {}
#
# # Filter behavior_type_and_duration_dict to only include entries with duration >= 3
# for file_name, behavior_type_and_duration in behavior_type_and_duration_dict.items():
#     filtered_behavior_type_and_duration_list = []
#
#     for behavior_type_duration in behavior_type_and_duration:
#         filtered_behavior_type_duration = [(behavior, duration) for behavior, duration in behavior_type_duration if isinstance(duration, int) and duration >= 3]
#         filtered_behavior_type_and_duration_list.extend(filtered_behavior_type_duration)
#
#     filtered_behavior_duration_dict[file_name] = filtered_behavior_type_and_duration_list

# %% [raw]
# # Print the filtered_behavior_duration_dict
# print("\033[1;33mFiltered Behavior Type and Duration Dictionary:\033[0m")
# for file_name, filtered_behavior_type_and_duration in filtered_behavior_duration_dict.items():
#     print(f'\033[1;31m{"="*10} File: {file_name} {"="*10}\033[0m')
#     for behavior_type_duration in filtered_behavior_type_and_duration:
#         print(f'Behavior Type and Duration: {behavior_type_duration}')
#     print('\u2501' * 70)  # Print a wider black line consisting of the Unicode character U+2501
#     print()

# %% [markdown]
# # Setting Behavior of Interest

# %% [markdown]
# Trigger key
# 0 Left Turns
# 1 Right Turns
# 2 Locomotion
# 3 Face Groom
# 4 All Other Groom
# 5 All Other

# %%
behavior_mapping = {
    0: "Left Turn ",
    1: "Right Turn ",
    2: "Locomotion ",
    3: "Face Groom ",
    4: "All Other Groom ",
    5: "All Other "
}

print("Please select the behavior of interest:")
for key, value in behavior_mapping.items():
    print(f"{key}: {value}")

behavior_of_interest = int(input("Enter the number corresponding to the behavior of interest: "))

behavior_name = behavior_mapping.get(behavior_of_interest, "Unknown")

print("Selected behavior of interest:", behavior_name)
# Out:
# Please select the behavior of interest:
# 0: Left Turn
# 1: Right Turn
# 2: Locomotion
# 3: Face Groom
# 4: All Other Groom
# 5: All Other
# Enter the number corresponding to the behavior of interest: 1
# Selected behavior of interest: Right Turn

# %%
selection = input("Please enter the type of fiber connection for the trial (B for Bilateral, I for Ipsilateral, C for Contralateral): ")

if selection == 'b':
    type_of_fiber_connection = 'Bilateral'
elif selection == 'i':
    type_of_fiber_connection = 'Ipsilateral'
elif selection == 'c':
    type_of_fiber_connection = 'Contralateral'
else:
    type_of_fiber_connection = 'Unknown'

print("Selected type of fiber connection:", type_of_fiber_connection)
# Out:
# Please enter the type of fiber connection for the trial (B for Bilateral, I for Ipsilateral, C for Contralateral): b
# Selected type of fiber connection: Bilateral

# %%
trial_type = ""

sham_session = input("Is it a Sham session? (y/n): ")

if sham_session.lower() == "y":
    trial_type = "Sham Session"
# Out:
# Is it a Sham session? (y/n): n

# %% [markdown]
# #  Total Bouts

# %%
# Count the occurrences of the behavior of interest in the filtered data and print for each file
total_bouts = 0  # Total number of bouts for the behavior of interest

for file_name in filtered_behavior_duration_dict:
    count = 0  # Set counter of bouts in curr file to zero
    behavior_list = filtered_behavior_duration_dict[file_name]
    for element in behavior_list: #element is a tuple (behavior, duration)
        if element[0] == behavior_of_interest:
            count += 1

    print('count of curr file =', count)
    total_bouts += count  # Accumulate the total number of bouts for all files

    # Bold the bout count in the output
    bold_count = "\033[1m" + str(count) + "\033[0m"

    print(f"Total of {bold_count} bout(s) of behavior {behavior_mapping.get(behavior_of_interest, 'Unknown')} in filtered data for file {file_name}.")

# Calculate the average
average = total_bouts / file_amount

# Format the average number to be more visible (using bold and color)
formatted_average = "\033[1;35m" + f"{average:.2f}" + "\033[0m"

print(f"\nAverage number of bouts for behavior {behavior_mapping.get(behavior_of_interest, 'Unknown')} in filtered data: {formatted_average}")
# Out:
# count of curr file = 27
# Total of 27 bout(s) of behavior Right Turn  in filtered data for file VideoOutputCamera 0-20072023-090516_posthoc-predictions.
# count of curr file = 245
# Total of 245 bout(s) of behavior Right Turn  in filtered data for file VideoOutputCamera 0-20072023-102037_posthoc-predictions.
# count of curr file = 50
# Total of 50 bout(s) of behavior Right Turn  in filtered data for file VideoOutputCamera 0-24072023-122530_posthoc-predictions.
# count of curr file = 27
# Total of 27 bout(s) of behavior Right Turn  in filtered data for file VideoOutputCamera 0-27062023-092810_posthoc-predictions.
#
# Average number of bouts for behavior Right Turn  in filtered data: 87.25

# %% [markdown]
# # Average Duration and Count

# %%
# Initialize an empty list to store the durations of the behavior of interest
Duration_of_behavior_type = []

# Iterate over the filtered_behavior_duration_dict to find the behavior of interest
for behavior_type, behavior_type_duration in filtered_behavior_duration_dict.items():
    # Initialize a variable to store the sum of durations for each behavior type
    behavior_type_sum = 0

    for behavior, duration in behavior_type_duration:
        if behavior == behavior_of_interest:
            Duration_of_behavior_type.append(duration)
            behavior_type_sum += duration

    # Print the total duration for the current behavior type
    print(f"Total stim count {behavior_type}: {behavior_type_sum}")

# Calculate the total duration of the behavior of interest
total_duration = sum(Duration_of_behavior_type)
print(f"\nTotal stim counts of {behavior_name}: {total_duration}")

average_stim_count=total_duration/file_amount
print(f"\nAverage stim counts of {behavior_name}: {average_stim_count}")
# Out:
# Total stim count VideoOutputCamera 0-20072023-090516_posthoc-predictions: 99
# Total stim count VideoOutputCamera 0-20072023-102037_posthoc-predictions: 902
# Total stim count VideoOutputCamera 0-24072023-122530_posthoc-predictions: 212
# Total stim count VideoOutputCamera 0-27062023-092810_posthoc-predictions: 115
#
# Total stim counts of Right Turn : 1328
#
# Average stim counts of Right Turn : 332.0

# %% [markdown]
# # Integrating Time

# %%
time_array_dict = behavior_type_and_duration_dict.copy()
for key in time_array_dict:
    time_array_dict[key].insert(0, (0, 0))
print(time_array_dict)
# Out:
# {'VideoOutputCamera 0-20072023-090516_posthoc-predictions': [(0, 0), (5.0, 79), (1.0, 1), (5.0, 79), (3.0, 1), (5.0, 4), (3.0, 2), (5.0, 3), (3.0, 2), (5.0, 7), (3.0, 1), (5.0, 4), (3.0, 1), (5.0, 1), (3.0, 1), (5.0, 1), (3.0, 2), (5.0, 2), (3.0, 2), (5.0, 1), (3.0, 1), (5.0, 1), (3.0, 3), (5.0, 1), (3.0, 4), (5.0, 2), (3.0, 2), (5.0, 1), (3.0, 1), (5.0, 1), (3.0, 3), (5.0, 34), (3.0, 1), (5.0, 184), (3.0, 4
, 1), (5.0, 371), (1.0, 2), (2.0, 2), (5.0, 4), (0.0, 1), (5.0, 12), (2.0, 2), (5.0, 22), (0.0, 1), (5.0, 6), (0.0, 2), (5.0, 75), (1.0, 1), (5.0, 2), (1.0, 1), (5.0, 325), (3.0, 1), (5.0, 207), (0.0, 2), (5.0, 343), (0.0, 1), (5.0, 2), (2.0, 12), (5.0, 3), (2.0, 5), (5.0, 6), (0.0, 1), (2.0, 3), (5.0, 9), (2.0, 2), (5.0, 1), (1.0, 1), (5.0, 6), (1.0, 5), (5.0, 15), (1.0, 5), (2.0, 2), (5.0, 29), (1.0, 1), (5.0, 11), (1.0, 1), (5.0, 11), (1.0, 1), (5.0, 3), (1.0, 1), (5.0, 2), (1.0, 1), (5.0, 3), (1.0, 1), (5.0, 5), (0.0, 2), (5.0, 3), (2.0, 14), (0.0, 2), (2.0, 20), (5.0, 2), (2.0, 1), (5.0, 11), (0.0, 5), (5.0, 4), (0.0, 2), (5.0, 55), (1.0, 3), (2.0, 7), (5.0, 1), (2.0, 2), (5.0, 6), (2.0, 2), (5.0, 12), (0.0, 1), (5.0, 7), (0.0, 4), (5.0, 6), (0.0, 1), (5.0, 1), (0.0, 2), (2.0, 3), (1.0, 3), (5.0, 5), (1.0, 1), (5.0, 1), (1.0, 1), (5.0, 119), (0.0, 1), (5.0, 9), (0.0, 1), (5.0, 1), (2.0, 6), (5.0, 1), (2.0, 2), (5.0, 2), (1.0, 2), (2.0, 5), (5.0, 8), (2.0, 1), (5.0, 1), (2.0, 2), (5.0, 9), (2.0, 4), (5.0, 2), (2.0, 4), (5.0, 3), (1.0, 1), (5.0, 1), (2.0, 9), (5.0, 2), (1.0, 3), (2.0, 5), (5.0, 1), (0.0, 1), (5.0, 41), (1.0, 2), (5.0, 31), (1.0, 1), (5.0, 44), (1.0, 1), (5.0, 3), (1.0, 2), (5.0, 1), (1.0, 2), (5.0, 36), (2.0, 1), (5.0, 10), (0.0, 1), (5.0, 1), (2.0, 2), (5.0, 4), (0.0, 1), (5.0, 7), (1.0, 1), (5.0, 1), (2.0, 4), (5.0, 15), (3.0, 1), (5.0, 2), (3.0, 1), (5.0, 6), (0.0, 1), (5.0, 2), (0.0, 1), (2.0, 4), (5.0, 10), (0.0, 2), (5.0, 29), (1.0, 2), (5.0, 1), (1.0, 1), (5.0, 17), (2.0, 8 ...

# %%
time_array_and_behavior_dict = {}

for key in time_array_dict:
    behavior_type_and_duration = time_array_dict[key]
    index = 0
    for behavior_duration_tuple in behavior_type_and_duration:
        behavior = behavior_duration_tuple[0]
        duration = behavior_duration_tuple[1]
        if index > 0:
            previous_tuple = time_array_and_behavior_dict[(key, index - 1)]
            new_duration = duration + previous_tuple[2]
            new_tuple = (behavior, duration, new_duration)
        else:
            new_tuple = (behavior, duration, duration)
        time_array_and_behavior_dict[(key, index)] = new_tuple
        index += 1

# This block of code creates a dictionary where the key is a tuple (file_name, index) and the value is a tuple (behavior, duration, index of last element in the bout)

# %%
print(time_array_and_behavior_dict)
# Out:
# {('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 0): (0, 0, 0), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 1): (5.0, 79, 79), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 2): (1.0, 1, 80), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 3): (5.0, 79, 159), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 4): (3.0, 1, 160), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 5): (5.0, 4, 164), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 6): (3.0, 2, 166), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 7): (5.0, 3, 169), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 8): (3.0, 2, 171), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 9): (5.0, 7, 178), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 10): (3.0, 1, 179), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 11): (5.0, 4, 183), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 12): (3.0, 1, 184), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 13): (5.0, 1, 185), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 14): (3.0, 1, 186), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 15): (5.0, 1, 187), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 16): (3.0, 2, 189), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 17): (5.0, 2, 191), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 18): (3.0, 2, 193), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 19): (5.0, 1, 194), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 20): (3.0, 1, 195), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 21): (5.0, 1, 196), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 22): (3.0, 3, 199), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 23): (5.0, 1, 200), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 24): (3.0, 4, 204), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 25): (5.0, 2, 206), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 26): (3.0, 2, 208), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 27): (5.0, 1, 209), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 28): (3.0, 1, 210), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 29): (5.0, 1, 211), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 30): (3.0, 3, 214), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 31): (5.0, 34, 248), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 32): (3.0, 1, 249), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 33): (5.0, 184, 433), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 34): (3.0, 4, 437), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 35): (4.0, 2, 439), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 36): (5.0, 257, 696), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 37): (2.0, 2, 698), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 38): (5.0, 1, 699), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 39): (2.0, 14, 713), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 40): (5.0, 4, 717), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 41): (1.0, 5, 722), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 42): (2.0, 1, 723), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 43): (5.0, 2, 725), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 44): (2.0, 1, 726), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 45): (5.0, 2, 728), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 46): (1.0, 2, 730), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 47): (2.0, 4, 734), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 48): (5.0, 6, 740), ('VideoOutputCamera 0-20072023-090516_posthoc-predictions', 49): (2.0, 9, 749), ('Video ...

# %% [markdown]
# # WORKS BUT CHANGED IT

# %% [markdown]
# # Total Time of Video in deciseconds

# %% [raw]
# # Create an empty dictionary to store random lists separately
# behavior_dict = {}
#
# # Iterate over selected files
# for file in infiles:
#     # Load the file as a NumPy array
#     behavior = np.load(file)
#
#     # Get the file name without the extension
#     file_name = os.path.splitext(os.path.basename(file))[0]
#
#     # Check if the file name already exists in the dictionary
#     if file_name in behavior_dict:
#         # If the file name exists, append the array to the existing list
#         behavior_dict[file_name].append(list(behavior))
#     else:
#         # If the file name doesn't exist, create a new list with the array
#         behavior_dict[file_name] = [list(behavior)]
#
#     print('This video is', len(behavior), 'deciseconds, which is', (len(behavior) / 600), 'minutes')

# %% [raw]
# #Print the random lists separately using the dictionary
# for file_name, random_list in behavior_dict.items():
#     print(f'\033[1;31mFile: {file_name}\033[0m')
#     for behavior in random_list:
#         print(f'Random List: {behavior}')
#     print('\u2501' * 50)  # Print a wider black line consisting of the Unicode character U+2501
#     print()

# %% [markdown]
# # Creates an array with tuples of (behavior type, stim count)

# %% [raw]
# behavior_type_and_duration_dict = {}
#
# # Iterate over each key-value pair in the behavior_dict
# for file_name, behavior_list in behavior_dict.items():
#     behavior_type_and_duration = []
#     for behavior in behavior_list:
#         current_value = behavior[0]
#         count = 0
#         for value in behavior:
#             if value == current_value:
#                 count += 1
#             else:
#                 behavior_type_and_duration.append((current_value, count))
#                 current_value = value
#                 count = 1
#
#         # Append the final (current_value, count) pair outside the loop
#         behavior_type_and_duration.append((current_value, count))
#
#     # Store the behavior_type_and_duration list in the behavior_type_and_duration_dict
#     behavior_type_and_duration_dict[file_name] = behavior_type_and_duration

# %% [raw]
# for file_name, behavior_type_and_duration in behavior_type_and_duration_dict.items():
#     print(f'\033[1;31mFile: {file_name}\033[0m')
#     print("Behavior Type and Duration:")
#     for behavior in behavior_type_and_duration:
#         print(behavior)
#     print('\u2501' * 50)  # Print a wider black line consisting of the Unicode character U+2501
#     print()

# %% [raw]
# Duration_of_behavior_type = []  # Empty list to store the durations of the behavior type
#
# print("Available File Names:")
# for file_name in behavior_type_and_duration_dict:
#     print(file_name)
#
# # Ask the user for their choice
# choice = input("Enter 'A' to calculate for all files, or 'I' for individual files: ")
#
# if choice.upper() == 'A':
#     # Calculate for all files
#     for behavior_type_and_duration in behavior_type_and_duration_dict.values():
#         for behavior, duration in behavior_type_and_duration:
#             if behavior == behavior_of_interest:
#                 Duration_of_behavior_type.append(duration)
#
#     stim_count = sum(Duration_of_behavior_type)
#     print("Behavior", behavior_of_interest, "was stimmed", stim_count, "times")
#
#     from statistics import mean
#     duration_average = mean(Duration_of_behavior_type)
#     print("The average duration of behavior", behavior_of_interest, "is", duration_average)
#
# elif choice.upper() == 'I':
#     # Calculate for individual files
#     # Ask the user to select a file name
#     selected_file_name = input("Select a File Name: ")
#
#     # Check if the selected file name exists in the behavior_type_and_duration_dict
#     if selected_file_name in behavior_type_and_duration_dict:
#         # Select the behavior type and duration list from the dictionary
#         behavior_type_and_duration_list = behavior_type_and_duration_dict[selected_file_name]
#         for behavior, duration in behavior_type_and_duration_list:
#             if behavior == behavior_of_interest:
#                 Duration_of_behavior_type.append(duration)
#
#         stim_count = sum(Duration_of_behavior_type)
#         print("Behavior", behavior_of_interest, "was stimmed", stim_count, "times")
#
#         from statistics import mean
#         duration_average = mean(Duration_of_behavior_type)
#         print("The average duration of behavior", behavior_of_interest, "is", duration_average)
#
#     else:
#         print("Invalid file name. Please select a valid file name from the list.")
# else:
#     print("Invalid choice. Please enter 'A' or 'I' to choose the calculation type.")

# %% [raw]
# Duration_of_behavior_type = []  # Empty list to store the durations of the behavior type
#
# # Print the available file names in the behavior_type_and_duration_dict
# print("Available File Names:")
# for file_name in behavior_type_and_duration_dict:
#     print(file_name)
#
# # Ask the user to select a file name
# selected_file_name = input("Select a File Name: ")
#
# # Check if the selected file name exists in the behavior_type_and_duration_dict
# if selected_file_name in behavior_type_and_duration_dict:
#     # Select the behavior type and duration list from the dictionary
#     behavior_type_and_duration_list = behavior_type_and_duration_dict[selected_file_name]
# for behavior_type_and_duration in behavior_type_and_duration_dict.values():
#     for behavior, duration in behavior_type_and_duration:
#         if behavior == behavior_of_interest:
#             Duration_of_behavior_type.append(duration)
#
# stim_count = sum(Duration_of_behavior_type)
# print("Behavior", behavior_of_interest, "was stimmed", stim_count, "times")
#
# from statistics import mean
# duration_average = mean(Duration_of_behavior_type)
# print("The average duration of behavior", behavior_of_interest, "is", duration_average)

# %% [markdown]
# # Filtering Out Based on Frame Rate of 3

# %% [raw]
# # Print the updated behavior type and duration lists
# for file_name, behavior_type_and_duration in behavior_type_and_duration_dict.items():
#     print(f'\033[1;31mFile: {file_name}\033[0m')
#     print("Updated Behavior Type and Duration:")
#     for behavior, duration in behavior_type_and_duration:
#         print(f'Behavior: {behavior}, Duration: {duration}')
#     print('\u2501' * 50)  # Print a wider black line consisting of the Unicode character U+2501
#     print()
