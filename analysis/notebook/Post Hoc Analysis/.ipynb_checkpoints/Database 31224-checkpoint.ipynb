# %%
import pandas as pd
import sys
from tkinter import Tk, filedialog
import ast
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
from tabulate import tabulate
import pprint 
import json
import scipy.stats as stats
import json
import pickle
import ipywidgets as widgets
from IPython.display import display
from nbconvert.preprocessors import ExecutePreprocessor
from nbformat import read, write
import nbformat
from functools import reduce
import statistics
from collections import OrderedDict

# %% [markdown]
# ## Upload Database and Filter

# %%
# Load the DataFrame from the pkl file
#file_path = 'K:/KayCei/Naturalistic.pkl' #if on lab computer 
file_path= '/Users/kaycei/K on Server (NoMachine)/KayCei/Naturalistic.pkl' #if on home computer 
with open(file_path, 'rb') as f:
    df = pickle.load(f)

# Identify columns with 'Array' in their names and parse JSON strings in those columns into Python objects
# Identify columns with 'Array' in their names and parse JSON strings in those columns into Python objects
df['Selected Behavior'] = df['Selected Behavior'].str.strip()
columns_to_parse=[]
for col in df.columns:
    if 'Array' in col:
        columns_to_parse.append(col)
#print(columns_to_parse)

for col in columns_to_parse:
    df[col] = df[col].apply(json.loads)

#def convert_to_tuples(item):
    #if isinstance(item, list):
        #return tuple(item)
    #else:
        #return item

# Apply the conversion function to the specified columns
#for col in columns_to_parse:
    #df[col] = df[col].apply(convert_to_tuples)

#Check if conversion was successful and print a statement accordingly
#conversion_successful = all(isinstance(item, tuple) for col in columns_to_parse for item in df[col])
#if conversion_successful:
    #print("JSON strings in columns with 'Array' in their names have been successfully converted to lists of tuples.")
#else:
    #print("Conversion of JSON strings to lists of tuples in columns with 'Array' in their names was unsuccessful.")

# %%
# Replace values in 'Selected_Behavior' column where 'Session_Type' is 'Sham Session'
df.loc[df['Session Type'] == 'Sham Session', 'Selected Behavior'] = 'No Error Value'
df.loc[df['Session Type'] == 'Sham Session', 'Fiber Connection'] = 'No Error Value'

# %% [raw]
# for col in columns_to_parse:
#     first_element = df[col].iloc[0]
#     for z in first_element:
#         for y in z:
#
#             print(type(df[col]))

# %%
original_df=df.copy()

# %% [markdown]
# original_df

# %%
iteration_list = {}

# Display available columns in groups of 3 with aligned numbering
num_columns = 3
columns = df.columns.tolist()
num_options = len(columns)

# Calculate the width of each column
column_width = 32

# Define the number of spaces for tab spacing
tab_space = 1

# Set the number of rows for displaying column options
num_rows = 13

# Initialize iteration number
iteration = 0
iteration_list[iteration]=("Selected Header: None","Column:None",df)

while columns:  # Continue filtering until all headers are filtered
    filtering_criteria = []
    for i in range(num_rows):
        for j in range(i, len(columns), num_rows):
            col_num = j + 1
            col_name = columns[j]
            # Adjust font size for smaller font
            if len(col_name) > column_width:
                print(f"\033[1;33m{col_num:<2}.\033[1;32m{col_name[:column_width]:<{column_width}}\033[0m", end=" " * tab_space)  # Yellow color for smaller font size
            else:
                print(f"\033[1;33m{col_num:<2}.{col_name:<{column_width}}\033[0m", end=" " * tab_space)
        print()
        
    if len(iteration_list)!=1:
        df=current_match
    else:
        pass
    
    # Prompt user to enter the number corresponding to the header
    selected_option = None
    while selected_option is None:
        user_input = input("Enter the number corresponding to the header or '0' to cancel filtering: ")
        try:
            selected_option = int(user_input)
            if selected_option == 0:
                print("Cell execution stopped.")
                sys.exit()  # Exit just the current cell
            elif selected_option > len(columns):
                raise ValueError
        except ValueError:
            print(f"Invalid input. Please enter a number between 1 and {len(columns)} or '0' to cancel filtering.")
            selected_option = None

    print((columns[selected_option-1]))
    selected_header = columns[selected_option - 1]
    
    # Append the selected header to filtering_criteria
    filtering_criteria.append(f"Selected Header: {selected_header}")

    # Remove the selected header from the list of available columns
    print(df[selected_header])    
    
    if selected_header in df.columns and all(isinstance(value, str) for value in df[selected_header]):
        avaliable_value=df[selected_header].unique()
        print(avaliable_value)
        filter_value = input(f"Enter the value to filter by {selected_header}: ")
        # Append the filter value to filtering_criteria
        filtering_criteria.append(f"Filter Value: {filter_value}")

    elif 'Array' in selected_header:
        if selected_header not in df.columns or df[selected_header].empty:
            print(f"The column '{selected_header}' is empty or does not exist.")
            
        available_elements = {
            0:"Behavior",
            1:"Stim Count",
            2: "Frames", 
            3: "Bout", 
            4: "Duration",
            5: "Start Time",
            6: "End Time",
        }
        print("Available elements:")
        for key, value in available_elements.items():
            print(f"{key}: {value}")

        # Prompt user to select elements
        element_positions_input = input(f"Enter the elements you want to filter by {selected_header} (comma-separated): ")
        print(df[selected_header])
        if ',' in element_positions_input:
            selected_positions = [int(pos.strip()) for pos in element_positions_input.split(',')]
            # Check if input is valid
            if all(pos in available_elements for pos in selected_positions):
                combined_filters = []
                for pos in selected_positions:
                    range_or_exact = input(f"Do you want an exact value or a range of values for {available_elements[pos]}?: ")
                    if range_or_exact.lower() == 'exact':
                        filter_value = input(f"Enter the exact value for {available_elements[pos]}: ")
                        y=int(filter_value)
                        filter_value=y
                        combined_filters.append(df[selected_header].apply(lambda tup_list: any((tup[pos] == filter_value for tup in tup_list))))
                        filtering_criteria.append(f"Element to filter: {available_elements.get(pos)}")
                        filtering_criteria.append(f"Exact Value for {available_elements[pos]}: {filter_value}")

                    elif range_or_exact.lower() == 'range':
                        range_value = input(f"Enter the range for {available_elements[pos]} (min,max): ")
                        min_val, max_val = map(float, range_value.split(','))
                        combined_filters.append(df[selected_header].apply(lambda tup_list: any((min_val <= tup[pos] <= max_val for tup in tup_list))))
                        filtering_criteria.append(f"Element to filter: {available_elements.get(pos)}")
                        filtering_criteria.append(f"Range for {available_elements[pos]}: {min_val} to {max_val}")

                    else:
                        print("Invalid input. Please enter 'exact' or 'range'.")

                # Apply combined filter
                array_df = df[reduce(lambda x, y: x & y, combined_filters)]

            else:
                print("Value is not an elemental position")

        else:
            selected_positions = int(element_positions_input)
            if selected_positions in available_elements:
                range_or_exact = input(f"Do you want an exact value or a range of values for {available_elements[selected_positions]}?: ")
                print(df[selected_header])
                if range_or_exact.lower() == 'exact':
                    print(df[selected_header])
                    filter_value= input(f"Enter the exact value for {available_elements[selected_positions]}: ")
                    filtering_criteria.append(f"Element to filter: {available_elements.get(selected_positions)}")
                    filtering_criteria.append(f"Exact Value for {available_elements.get(selected_positions)}: {filter_value}")
                    y=int(filter_value)
                    filter_value=y
                    print(df[selected_header])
                    array_df = df[df[selected_header].apply(lambda tup_list: any((tup[selected_positions] == filter_value for tup in tup_list)))]

                elif range_or_exact.lower() == 'range':
                    range_value = input(f"Enter the range for {available_elements[selected_positions]} (min,max): ")
                    min_val, max_val = map(float, range_value.split(','))
                    filtering_criteria.append(f"Element to filter: {available_elements.get(selected_positions)}")
                    filtering_criteria.append(f"Range for {available_elements.get(selected_positions)}: {min_val} to {max_val}")
                    array_df = df[df[selected_header].apply(lambda tup_list: any((min_val <= tup[selected_positions] <= max_val for tup in tup_list)))]

            else:
                print('An element position was not selected')
        
    if 'Array'not in selected_header:
        columns.remove(selected_header)
    
    if len(iteration_list)==1:
        if "Array" not in selected_header:                                          
            current_match=df[df[selected_header] == filter_value]
            iteration+=1
            iteration_list[iteration]=(filtering_criteria.copy(), columns.copy(), current_match)
        elif "Selected Behavior" or 'Fiber Connection' in selected_header:
            current_match = df[(df[selected_header] == filter_value) | (df[selected_header] == "No Error Value")]
            iteration += 1
            iteration_list[iteration] = (filtering_criteria.copy(), columns.copy(), current_match)
        else:
            current_match=array_df
            iteration+=1
            iteration_list[iteration]=(filtering_criteria.copy(), columns.copy(), current_match)                                       
    else:
        previous_match=current_match
        if'Array' in selected_header:
            current_match=array_df
            iteration+=1
            iteration_list[iteration]=(filtering_criteria.copy(), columns.copy(), current_match) 
        elif "Selected Behavior" or 'Fiber Connection' in selected_header:
            current_match = df[(df[selected_header] == filter_value) | (df[selected_header] == "No Error Value")]
            iteration += 1
            iteration_list[iteration] = (filtering_criteria.copy(), columns.copy(), current_match)
        else:
            current_match=df[df[selected_header]==filter_value]
            iteration+=1
            iteration_list[iteration]=(filtering_criteria.copy(), columns.copy(), current_match)                                        
    
    # Extracting the headers in the original order from the DataFrame
    original_headers = current_match.columns.tolist()
# Out:
# 1 .Mouse                            14.Total Left Turn Bout Count       27.Face Groom Average Duration in S
# 2 .Genotype                         15.Average Duration of Left Turn(se 28.All Other Groom Array
# 3 .Date                             16.Total Left Turn Bouts in Stim Bl 29.Total All Other Groom Bout Count
# 4 .Selected Behavior                17.Left Turn Average Duration in St 30.Average Duration of All Other Gr
# 5 .Session Type                     18.Locomotion Array                 31.Total All Other Groom Bouts in S
# 6 .Session Number                   19.Total Locomotion Bout Count      32.All Other Groom Average Duration
# 7 .Fiber Connection                 20.Average Duration of Locomotion(s 33.All Other Array
# 8 .Right Turn Array                 21.Total Locomotion Bouts in Stim B 34.Total All Other Bout Count
# 9 .Total Right Turn Bout Count      22.Locomotion Average Duration in S 35.Average Duration of All Other(se
# 10.Average Duration of Right Turn(s 23.Face Groom Array                 36.Total All Other Bouts in Stim Bl
# 11.Total Right Turn Bouts in Stim B 24.Total Face Groom Bout Count      37.All Other Average Duration in St
# 12.Right Turn Average Duration in S 25.Average Duration of Face Groom(s
# 13.Left Turn Array                  26.Total Face Groom Bouts in Stim B
# Enter the number corresponding to the header or '0' to cancel filtering: 2
# Genotype
# 0     D1
# 1     D1
# 2     D1
# 3     D1
# 4     D1
#       ..
# 90    D1
# 91    D1
# 92    D1
# 93    D1
# 94    D1
# Name: Genotype, Length: 95, dtype: object
# ['D1' 'D2']
# Enter the value to filter by Genotype: D1
# 1 .Mouse                            14.Average Duration of Left Turn(se 27.All Other Groom Array
# 2 .Date                             15.Total Left Turn Bouts in Stim Bl 28.Total All Other Groom Bout Count
# 3 .Selected Behavior                16.Left Turn Average Duration in St 29.Average Duration of All Other Gr
# 4 .Session Type                     17.Locomotion Array                 30.Total All Other Groom Bouts in S
# 5 .Session Number                   18.Total Locomotion Bout Count      31.All Other Groom Average Duration
# 6 .Fiber Connection                 19.Average Duration of Locomotion(s 32.All Other Array
# 7 .Right Turn Array                 20.Total Locomotion Bouts in Stim B 33.Total All Other Bout Count
# 8 .Total Right Turn Bout Count      21.Locomotion Average Duration in S 34.Average Duration of All Other(se
# 9 .Average Duration of Right Turn(s 22.Face Groom Array                 35.Total All Other Bouts in Stim Bl
# 10.Total Right Turn Bouts in Stim B 23.Total Face Groom Bout Count      36.All Other Average Duration in St
# 11.Right Turn Average Duration in S 24.Average Duration of Face Groom(s
# 12.Left Turn Array                  25.Total Face Groom Bouts in Stim B
# 13.Total Left Turn Bout Count       26.Face Groom Average Duration in S
# Enter the number corresponding to the header or '0' to cancel filtering: 0
# Cell execution stopped.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /Users/kaycei/anaconda3/envs/closed-loop/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3406: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
while True:
    finalize_match = input("\nDo you want to finalize matching data? (yes/no): ")
    if finalize_match.lower() == 'yes':
        break  # Exit the loop if the user chooses to finalize matching data
    
    for iteration, (filtering_criteria, columns, current_match) in iteration_list.items():
        print(iteration, filtering_criteria)

    # Prompt the user to select an iteration to go back to
    selected_iteration = input("\nEnter the iteration number to go back to, or 'exit' to exit: ")
    if selected_iteration.lower() == 'exit':
        break  # Exit the loop if the user chooses to exit
    else:
        try:
            selected_iteration = int(selected_iteration)
            if selected_iteration in iteration_list:
                df=iteration_list[selected_iteration][2]
                current_match = iteration_list[selected_iteration][2]
                iteration_list = {k: v for k, v in iteration_list.items() if k <= selected_iteration}
                print('Run cell above as current match')
                break
        except ValueError:
            print("Invalid input. Please enter a valid iteration number or 'exit' to exit.")
# Out:
# Do you want to finalize matching data? (yes/no): yes

# %%
if finalize_match!='yes':
    # Define a list to store all selections and filtering criteria
    #iteration_list={}
    # Display available columns in groups of 3 with aligned numbering
    num_columns = 3
    columns = df.columns.tolist()
    num_options = len(columns)

    # Calculate the width of each column
    column_width = 32

    # Define the number of spaces for tab spacing
    tab_space = 1

    # Set the number of rows for displaying column options
    num_rows = 13

    while columns:  # Continue filtering until all headers are filtered
        for i in range(num_rows):
            for j in range(i, len(columns), num_rows):
                col_num = j + 1
                col_name = columns[j]
                # Adjust font size for smaller font
                if len(col_name) > column_width:
                    print(f"\033[1;33m{col_num:<2}.\033[1;32m{col_name[:column_width]:<{column_width}}\033[0m", end=" " * tab_space)  # Yellow color for smaller font size
                else:
                    print(f"\033[1;33m{col_num:<2}.{col_name:<{column_width}}\033[0m", end=" " * tab_space)
            print()

        if len(iteration_list)!=1:
            df=current_match
        else:
            pass
        filtering_criteria = []
        # Prompt user to enter the number corresponding to the header
        selected_option = None
        while selected_option is None:
            user_input = input("Enter the number corresponding to the header or '0' to cancel filtering: ")
            try:
                selected_option = int(user_input)
                if selected_option == 0:
                    print("Cell execution stopped.")
                    sys.exit()  # Exit just the current cell
                elif selected_option > len(columns):
                    raise ValueError
            except ValueError:
                print(f"Invalid input. Please enter a number between 1 and {len(columns)} or '0' to cancel filtering.")
                selected_option = None

        print((columns[selected_option-1]))
        selected_header = columns[selected_option - 1]

        # Append the selected header to filtering_criteria
        filtering_criteria.append(f"Selected Header: {selected_header}")

        # Remove the selected header from the list of available columns

        if selected_header in df.columns and all(isinstance(value, str) for value in df[selected_header]):
            avaliable_value=df[selected_header].unique()
            print(avaliable_value)
            filter_value = input(f"Enter the value to filter by {selected_header}: ")
            # Append the filter value to filtering_criteria
            filtering_criteria.append(f"Filter Value: {filter_value}")

        elif 'Array' in selected_header:
            available_elements = {
                0:"Behavior",
                1:"Stim Count",
                2: "Frames", 
                3: "Bout", 
                4: "Duration",
                5: "Start Time",
                6: "End Time",
            }
            print("Available elements:")
            for key, value in available_elements.items():
                print(f"{key}: {value}")

            # Prompt user to select elements
            element_positions_input = input(f"Enter the elements you want to filter by {selected_header} (comma-separated): ")
            print("Selected positions:", selected_positions)  # Add this line for debugging
            if ',' in element_positions_input:
                selected_positions = [int(pos.strip()) for pos in element_positions_input.split(',')]
                # Check if input is valid
                if all(pos in available_elements for pos in selected_positions):
                    combined_filters = []
                    for pos in selected_positions:
                        range_or_exact = input(f"Do you want an exact value or a range of values for {available_elements[pos]}?: ")
                        if range_or_exact.lower() == 'exact':
                            filter_value = input(f"Enter the exact value for {available_elements[pos]}: ")
                            # Add condition to the combined filter
                            combined_filters.append(df[selected_header].apply(lambda row: any((x[pos] == filter_value for x in tup)for tup in row)))
                            filtering_criteria.append(f"Element to filter: {available_elements.get(pos)}")
                            filtering_criteria.append(f"Exact Value for {available_elements[pos]}: {filter_value}")
                        elif range_or_exact.lower() == 'range':
                            range_value = input(f"Enter the range for {available_elements[pos]} (min,max): ")
                            min_val, max_val = map(float, range_value.split(','))
                            # Add condition to the combined filter
                            combined_filters.append(df[selected_header].apply(lambda row: any((min_val <= x[pos]<= max_val for x in tup)for tup in row)))
                            filtering_criteria.append(f"Element to filter: {available_elements.get(pos)}")
                            filtering_criteria.append(f"Range for {available_elements[pos]}: {min_val} to {max_val}")
                        else:
                            print("Invalid input. Please enter 'exact' or 'range'.")
                    # Apply combined filter
                    array_df = df[reduce(lambda x, y: x & y, combined_filters)]
                else:
                    print("Value is not an elemental position")
            else:
                selected_positions = int(element_positions_input)
                print(selected_positions)
                if selected_positions in available_elements:
                    range_or_exact = input(f"Do you want an exact value or a range of values for {available_elements[selected_positions]}?: ")
                    if range_or_exact.lower() == 'exact':
                        filter_value= input(f"Enter the exact value for {available_elements[selected_positions]}: ")
                        filtering_criteria.append(f"Element to filter: {available_elements.get(selected_positions)}")
                        filtering_criteria.append(f"Exact Value for {available_elements.get(selected_positions)}: {filter_value}")
                        array_df = df[df[selected_header].apply(lambda row: any((x[selected_positions] == filter_value for x in tup) for tup in row))]
                    elif range_or_exact== 'range':
                        range_value = input(f"Enter the range for {available_elements[selected_positions]} (min,max): ")
                        min_val, max_val = map(float, range_value.split(','))
                        filtering_criteria.append(f"Element to filter: {available_elements.get(selected_positions)}")
                        filtering_criteria.append(f"Range for {available_elements.get(selected_position)}: {min_val} to {max_val}")
                        array_df=df[df[selected_header].apply(lambda y: any((min_val <= x[selected_positions] <= max_val for x in tup)for tup in y))]
                else:
                    print('An element position was not selected')

        if 'Array'not in selected_header:
            columns.remove(selected_header)

        if len(iteration_list)==1:
            if "Array" in selected_header:                                          
                current_match=array_df
                iteration+=1
                iteration_list[iteration]=(filtering_criteria.copy(), columns.copy(), current_match)
            elif "Selected Behavior" or 'Fiber Connection' in selected_header:
                current_match = df[(df[selected_header] == filter_value) | (df[selected_header] == "No Error Value")]
                iteration += 1
                iteration_list[iteration] = (filtering_criteria.copy(), columns.copy(), current_match)
            else:
                current_match=df[df[selected_header] == filter_value]
                iteration+=1
                iteration_list[iteration]=(filtering_criteria.copy(), columns.copy(), current_match)                                       
        else:
            previous_match=current_match
            if'Array' in selected_header:
                current_match=array_df
                iteration+=1
                iteration_list[iteration]=(filtering_criteria.copy(), columns.copy(), current_match) 
            elif "Selected Behavior" or 'Fiber Connection' in selected_header:
                current_match = df[(df[selected_header] == filter_value) | (df[selected_header] == "No Error Value")]
                iteration += 1
                iteration_list[iteration] = (filtering_criteria.copy(), columns.copy(), current_match)
            else:
                current_match=df[df[selected_header]==filter_value]
                iteration+=1
                iteration_list[iteration]=(filtering_criteria.copy(), columns.copy(), current_match)                                       

        # Extracting the headers in the original order from the DataFrame
        original_headers = current_match.columns.tolist()
else:
    pass

# %%
current_match
# Out:
#    Mouse Genotype    Date Selected Behavior  Session Type Session Number  \
# 0   AD12       D1  021624        Right Turn  Stim Session              1
# 1   AD12       D1  022024        Locomotion  Stim Session              1
# 2   AD12       D1  022324        Face Groom  Stim Session              1
# 3   AD14       D1  022324        Right Turn  Stim Session              1
# 4   AD14       D1  022624        Locomotion  Stim Session              1
# 5   AD14       D1  030624        Face Groom  Stim Session              1
# 20  AD22       D1  030624        Right Turn  Stim Session              1
# 44  AD10       D1  060823    No Error Value  Sham Session              1
# 45  AD10       D1  061523        Right Turn  Stim Session              1
# 46  AD10       D1  062623        Locomotion  Stim Session              1
# 47  AD10       D1  062723        Face Groom  Stim Session              1
# 48  AD10       D1  062923    No Error Value  Sham Session              1
# 49  AD10       D1  071023    No Error Value  Sham Session              1
# 50  AD10       D1  071123        Right Turn  Stim Session              1
# 51  AD10       D1  071323    No Error Value  Sham Session              1
# 52  AD10       D1  071423        Right Turn  Stim Session              1
# 53  AD10       D1  071723    No Error Value  Sham Session              1
# 54  AD10       D1  071923    No Error Value  Sham Session              2
# 55  AD10       D1  072423        Right Turn  Stim Session              2
# 56  AD10       D1  072723        Locomotion  Stim Session              2
# 57  AD10       D1  100123        Face Groom  Stim Session              2
# 58  AD10       D1  100423        Right Turn  Stim Session              2
# 59  AD10       D1  102423        Locomotion  Stim Session              3
# 60  AD11       D1  051123        Right Turn  Stim Session              1
# 61  AD11       D1  051223        Locomotion  Stim Session              1
# 62  AD11       D1  051723        Face Groom  Stim Session              1
# 63  AD11       D1  052223        Right Turn  Stim Session              1
# 64  AD11       D1  060823    No Error Value  Sham Session              1
# 65  AD11       D1  061223    No Error Value  Sham Session              1
# 66  AD11       D1  062923    No Error Value  Sham Session              1
# 67  AD11       D1  071023    No Error Value  Sham Session              1
# 68  AD11       D1  071123        Right Turn  Stim Session              1
# 69  AD11       D1  071323    No Error Value  Sham Session              1
# 70  AD11       D1  072023        Right Turn  Stim Session              2
# 71  AD11       D1  072423    No Error Value  Sham Session              2
# 72  AD11       D1  072523        Locomotion  Stim Session              2
# 73  AD11       D1  072823    No Error Value  Sham Session              2
# 81   P22       D1  052423        Right Turn  Stim Session              1
# 82   P22       D1  060723    No Error Value  Sham Session              1
# 83   P22       D1  061223    No Error Value  Sham Session              1
# 84   P22       D1  062923        Locomotion  Stim Session              1
# 85   P22       D1  071123    No Error Value  Sham Session              1
# 86   P22       D1  071223    No Error Value  Sham Session              1
# 87   P22       D1  071323        Face Groom  Stim Session              1
# 88   P22       D1  071423        Right Turn  Stim Session              1
# 89   P22       D1  071723    No Error Value  Sham Session              1
# 90   P22       D1  071823        Right Turn  Stim Session              1
# 91   P22       D1  072023        Right Turn  Stim Session              2
# 92   P22       D1  072123    No Error Value  Sham Session              2
# 93   P22       D1  072523        Locomotion  Stim Session              2
# 94   P22       D1  072823    No Error Value  Sham Session              2
#
#    Fiber Connection                                   Right Turn Array  \
# 0         Bilateral  [[1, 0, 3, 1, 1, 203, 204], [1, 0, 3, 2, 1, 21...
# 1         Bilateral  [[1, 0, 3, 1, 1, 13, 14], [1, 1, 9, 2, 3, 19, ...
# 2         Bilateral  [[1, 1, 9, 1, 3, 0, 3], [1, 1, 6, 2, 2, 41, 43...
# 3         Bilateral  [[1, 0, 3, 1, 1, 91, 92], [1, 1, 6, 2, 2, 198,...
# 4         Bilateral  [[1, 1, 12, 1, 4, 46, 50], [1, 0, 3, 2, 1, 62,...
# 5         Bilateral  [[1, 0, 3, 1, 1, 25, 26], [1, 0, 3, 2, 1, 27, ...
# 20        Bilateral  [[1, 1, 12, 1, 4, 250, 254], [1, 0, 3, 2, 1, 2...
# 44   No Error Value  [[0, 1, 6, 1, 2, 231, 233], [0, 1, 6, 2, 2, 57...
# 45        Bilateral  [[0, 0, 3, 1, 1, 207, 208], [0, 1, 6, 2, 2, 20...
# 46        Bilateral  [[0, 1, 6, 1, 2, 81, 83], [0, 0, 3, 2, 1, 168,...
# 47        Bilateral  [[0, 1, 6, 1, 2, 192, 194], [0, 0, 3, 2, 1, 19...
# 48   No Error Value  [[0, 0, 3, 1, 1, 112, 113], [0, 2, 21, 2, 7, 1...
# 49   No Error Value  [[0, 2, 18, 1, 6, 20, 26], [0, 1, 12, 2, 4, 58...
# 50      Ipsilateral  [[0, 0, 3, 1, 1, 5, 6], [0, 0, 3, 2, 1, 71, 72...
# 51   No Error Value  [[0, 0, 3, 1, 1, 75, 76], [0, 0, 3, 2, 1, 546,...
# 52    Contralateral  [[0, 0, 3, 1, 1, 231, 232], [0, 0, 3, 2, 1, 25...
# 53   No Error Value  [[0, 0, 3, 1, 1, 23, 24], [0, 1, 6, 2, 2, 859,...
# 54   No Error Value  [[0, 0, 3, 1, 1, 261, 262], [0, 1, 6, 2, 2, 26...
# 55        Bilateral  [[0, 0, 3, 1, 1, 65, 66], [0, 0, 3, 2, 1, 70, ...
# 56        Bilateral  [[0, 1, 6, 1, 2, 4, 6], [0, 1, 6, 2, 2, 129, 1...
# 57        Bilateral  [[0, 1, 9, 1, 3, 1127, 1130], [0, 1, 12, 2, 4,...
# 58      Ipsilateral  [[0, 1, 12, 1, 4, 302, 306], [0, 1, 12, 2, 4, ...
# 59        Bilateral  [[0, 3, 24, 1, 8, 54, 62], [0, 0, 3, 2, 1, 303...
# 60        Bilateral  [[0, 1, 9, 1, 3, 14, 17], [0, 2, 15, 2, 5, 18,...
# 61        Bilateral  [[0, 0, 3, 1, 1, 52, 53], [0, 2, 18, 2, 6, 287...
# 62        Bilateral  [[0, 0, 3, 1, 1, 52, 53], [0, 2, 18, 2, 6, 287...
# 63      Ipsilateral  [[0, 1, 9, 1, 3, 111, 114], [0, 1, 12, 2, 4, 1...
# 64   No Error Value  [[0, 0, 3, 1, 1, 80, 81], [0, 0, 3, 2, 1, 104,...
# 65   No Error Value  [[0, 0, 3, 1, 1, 29, 30], [0, 0, 3, 2, 1, 55, ...
# 66   No Error Value  [[0, 1, 6, 1, 2, 262, 264], [0, 0, 3, 2, 1, 72...
# 67   No Error Value  [[0, 0, 3, 1, 1, 136, 137], [0, 1, 12, 2, 4, 2...
# 68    Contralateral  [[0, 1, 9, 1, 3, 643, 646], [0, 1, 6, 2, 2, 64...
# 69   No Error Value  [[0, 1, 6, 1, 2, 358, 360], [0, 0, 3, 2, 1, 40...
# 70        Bilateral  [[0, 1, 6, 1, 2, 833, 835], [0, 0, 3, 2, 1, 13...
# 71   No Error Value  [[0, 1, 9, 1, 3, 179, 182], [0, 2, 21, 2, 7, 2...
# 72        Bilateral  [[0, 0, 3, 1, 1, 14, 15], [0, 0, 3, 2, 1, 427,...
# 73   No Error Value  [[0, 0, 3, 1, 1, 99, 100], [0, 1, 9, 2, 3, 260...
# 81        Bilateral  [[0, 0, 3, 1, 1, 1, 2], [0, 3, 24, 2, 8, 136, ...
# 82   No Error Value  [[0, 1, 6, 1, 2, 0, 2], [0, 0, 3, 2, 1, 24, 25...
# 83   No Error Value  [[0, 1, 6, 1, 2, 0, 2], [0, 1, 6, 2, 2, 8, 10]...
# 84        Bilateral  [[0, 0, 3, 1, 1, 183, 184], [0, 0, 3, 2, 1, 23...
# 85   No Error Value  [[0, 1, 9, 1, 3, 55, 58], [0, 1, 6, 2, 2, 61, ...
# 86   No Error Value  [[0, 1, 9, 1, 3, 62, 65], [0, 1, 9, 2, 3, 75, ...
# 87        Bilateral  [[0, 1, 9, 1, 3, 33, 36], [0, 1, 6, 2, 2, 191,...
# 88      Ipsilateral  [[0, 0, 3, 1, 1, 44, 45], [0, 0, 3, 2, 1, 75, ...
# 89   No Error Value  [[0, 0, 3, 1, 1, 24, 25], [0, 1, 6, 2, 2, 74, ...
# 90    Contralateral  [[0, 1, 6, 1, 2, 20, 22], [0, 2, 21, 2, 7, 41,...
# 91        Bilateral  [[0, 0, 3, 1, 1, 94, 95], [0, 1, 6, 2, 2, 97, ...
# 92   No Error Value  [[0, 1, 6, 1, 2, 38, 40], [0, 1, 9, 2, 3, 54, ...
# 93        Bilateral  [[0, 1, 9, 1, 3, 39, 42], [0, 0, 3, 2, 1, 45, ...
# 94   No Error Value  [[0, 1, 6, 1, 2, 19, 21], [0, 0, 3, 2, 1, 22, ...
#
#    Total Right Turn Bout Count Average Duration of Right Turn(seconds)  ...  \
# 0                          666                                   0.183  ...
# 1                          789                                   0.199  ...
# 2                          719                                   0.192  ...
# 3                          361                                   0.172  ...
# 4                          249                                   0.143  ...
# 5                          698                                   0.167  ...
# 20                         506                                   0.173  ...
# 44                         367                                   0.184  ...
# 45                         423                                   0.198  ...
# 46                         334                                   0.216  ...
# 47                         203                                   0.205  ...
# 48                         290                                   0.219  ...
# 49                         212                                   0.182  ...
# 50                         169                                   0.202  ...
# 51                         214                                   0.206  ...
# 52                         243                                   0.179  ...
# 53                         134                                   0.193  ...
# 54                         218                                   0.206  ...
# 55                         184                                   0.226  ...
# 56                         850                                   0.204  ...
# 57                         597                                   0.245  ...
# 58                         284                                   0.243  ...
# 59                         420                                   0.257  ...
# 60                         711                                   0.205  ...
# 61                         890                                   0.206  ...
# 62                         890                                   0.206  ...
# 63                         807                                    0.19  ...
# 64                         650                                   0.224  ...
# 65                         661                                   0.213  ...
# 66                         646                                   0.213  ...
# 67                         477                                   0.217  ...
# 68                         200                                   0.206  ...
# 69                         325                                   0.208  ...
# 70                         128                                   0.187  ...
# 71                         199                                   0.194  ...
# 72                          50                                   0.204  ...
# 73                          68                                    0.21  ...
# 81                         965                                     0.2  ...
# 82                        1320                                   0.215  ...
# 83                        1183                                   0.214  ...
# 84                        1174                                   0.207  ...
# 85                        1439                                   0.215  ...
# 86                        1380                                   0.202  ...
# 87                        1197                                     0.2  ...
# 88                        1161                                     0.2  ...
# 89                        1057                                     0.2  ...
# 90                        1081                                   0.202  ...
# 91                        1361                                   0.192  ...
# 92                        1122                                   0.205  ...
# 93                         859                                   0.197  ...
# 94                         794                                     0.2  ...
#
#                                 All Other Groom Array  \
# 0   [[4, 1, 6, 1, 2, 2663, 2665], [4, 0, 3, 2, 1, ...
# 1   [[4, 0, 3, 1, 1, 2011, 2012], [4, 0, 3, 2, 1, ...
# 2   [[4, 0, 3, 1, 1, 426, 427], [4, 0, 3, 2, 1, 45...
# 3   [[4, 1, 6, 1, 2, 3979, 3981], [4, 0, 3, 2, 1, ...
# 4   [[4, 0, 3, 1, 1, 97, 98], [4, 0, 3, 2, 1, 373,...
# 5   [[4, 0, 3, 1, 1, 774, 775], [4, 0, 3, 2, 1, 78...
# 20  [[4, 0, 3, 1, 1, 95, 96], [4, 0, 3, 2, 1, 2780...
# 44  [[4, 0, 3, 1, 1, 1462, 1463], [4, 0, 3, 2, 1, ...
# 45  [[4, 0, 3, 1, 1, 4401, 4402], [4, 0, 3, 2, 1, ...
# 46  [[4, 0, 3, 1, 1, 380, 381], [4, 0, 3, 2, 1, 42...
# 47  [[4, 1, 6, 1, 2, 1251, 1253], [4, 1, 9, 2, 3, ...
# 48  [[4, 0, 3, 1, 1, 3537, 3538], [4, 1, 6, 2, 2, ...
# 49  [[4, 0, 3, 1, 1, 2058, 2059], [4, 0, 3, 2, 1, ...
# 50  [[4, 0, 3, 1, 1, 152, 153], [4, 0, 3, 2, 1, 40...
# 51  [[4, 0, 3, 1, 1, 2680, 2681], [4, 0, 3, 2, 1, ...
# 52  [[4, 0, 3, 1, 1, 1855, 1856], [4, 0, 3, 2, 1, ...
# 53  [[4, 1, 6, 1, 2, 404, 406], [4, 30, 267, 2, 89...
# 54  [[4, 0, 3, 1, 1, 1363, 1364], [4, 2, 15, 2, 5,...
# 55  [[4, 0, 3, 1, 1, 959, 960], [4, 0, 3, 2, 1, 10...
# 56  [[4, 1, 9, 1, 3, 309, 312], [4, 0, 3, 2, 1, 31...
# 57  [[4, 0, 3, 1, 1, 2600, 2601], [4, 0, 3, 2, 1, ...
# 58  [[4, 1, 9, 1, 3, 75, 78], [4, 1, 6, 2, 2, 85, ...
# 59  [[4, 0, 3, 1, 1, 1128, 1129], [4, 0, 3, 2, 1, ...
# 60  [[4, 0, 3, 1, 1, 978, 979], [4, 0, 3, 2, 1, 10...
# 61  [[4, 1, 6, 1, 2, 145, 147], [4, 0, 3, 2, 1, 28...
# 62  [[4, 1, 6, 1, 2, 145, 147], [4, 0, 3, 2, 1, 28...
# 63  [[4, 0, 3, 1, 1, 869, 870], [4, 1, 6, 2, 2, 10...
# 64  [[4, 0, 3, 1, 1, 548, 549], [4, 0, 3, 2, 1, 13...
# 65  [[4, 0, 3, 1, 1, 182, 183], [4, 2, 15, 2, 5, 1...
# 66  [[4, 0, 3, 1, 1, 1199, 1200], [4, 0, 3, 2, 1, ...
# 67  [[4, 0, 3, 1, 1, 49, 50], [4, 1, 6, 2, 2, 55, ...
# 68  [[4, 0, 3, 1, 1, 1349, 1350], [4, 0, 3, 2, 1, ...
# 69  [[4, 2, 18, 1, 6, 364, 370], [4, 0, 3, 2, 1, 3...
# 70  [[4, 1, 6, 1, 2, 437, 439], [4, 0, 3, 2, 1, 32...
# 71  [[4, 0, 3, 1, 1, 897, 898], [4, 0, 3, 2, 1, 11...
# 72  [[4, 0, 3, 1, 1, 1932, 1933], [4, 1, 6, 2, 2, ...
# 73  [[4, 0, 3, 1, 1, 5, 6], [4, 0, 3, 2, 1, 7, 8],...
# 81  [[4, 1, 9, 1, 3, 817, 820], [4, 0, 3, 2, 1, 11...
# 82  [[4, 0, 3, 1, 1, 8, 9], [4, 1, 6, 2, 2, 49, 51...
# 83  [[4, 1, 6, 1, 2, 108, 110], [4, 0, 3, 2, 1, 11...
# 84  [[4, 1, 9, 1, 3, 141, 144], [4, 1, 9, 2, 3, 14...
# 85  [[4, 1, 6, 1, 2, 487, 489], [4, 2, 18, 2, 6, 4...
# 86  [[4, 0, 3, 1, 1, 152, 153], [4, 1, 9, 2, 3, 52...
# 87  [[4, 1, 6, 1, 2, 312, 314], [4, 1, 9, 2, 3, 31...
# 88  [[4, 0, 3, 1, 1, 95, 96], [4, 0, 3, 2, 1, 635,...
# 89  [[4, 0, 3, 1, 1, 161, 162], [4, 0, 3, 2, 1, 19...
# 90  [[4, 0, 3, 1, 1, 34, 35], [4, 1, 9, 2, 3, 117,...
# 91  [[4, 1, 9, 1, 3, 82, 85], [4, 0, 3, 2, 1, 93, ...
# 92  [[4, 1, 9, 1, 3, 114, 117], [4, 1, 9, 2, 3, 12...
# 93  [[4, 0, 3, 1, 1, 130, 131], [4, 0, 3, 2, 1, 15...
# 94  [[4, 0, 3, 1, 1, 4, 5], [4, 0, 3, 2, 1, 7, 8],...
#
#    Total All Other Groom Bout Count  \
# 0                               253
# 1                               484
# 2                               336
# 3                               412
# 4                               348
# 5                               282
# 20                              181
# 44                              102
# 45                              470
# 46                               82
# 47                              369
# 48                              448
# 49                              649
# 50                              295
# 51                              245
# 52                              381
# 53                              645
# 54                              371
# 55                              413
# 56                               81
# 57                               84
# 58                               76
# 59                               78
# 60                              168
# 61                              318
# 62                              318
# 63                              177
# 64                              169
# 65                              281
# 66                              333
# 67                              218
# 68                              601
# 69                              447
# 70                              346
# 71                              281
# 72                              162
# 73                              226
# 81                             1255
# 82                             1123
# 83                              990
# 84                             1308
# 85                              327
# 86                              439
# 87                              520
# 88                              298
# 89                              702
# 90                              732
# 91                              810
# 92                              678
# 93                              747
# 94                              715
#
#    Average Duration of All Other Groom(seconds)  \
# 0                                         0.182
# 1                                         0.219
# 2                                         0.282
# 3                                         0.275
# 4                                         0.182
# 5                                         0.195
# 20                                        0.219
# 44                                        0.395
# 45                                        0.551
# 46                                         0.23
# 47                                        0.575
# 48                                        0.503
# 49                                        0.516
# 50                                        0.574
# 51                                        0.258
# 52                                        0.302
# 53                                        0.411
# 54                                        0.577
# 55                                        0.725
# 56                                         0.16
# 57                                        0.148
# 58                                        0.926
# 59                                        0.549
# 60                                        0.185
# 61                                         0.24
# 62                                         0.24
# 63                                        0.276
# 64                                        0.274
# 65                                        0.229
# 66                                        0.215
# 67                                        0.211
# 68                                        0.265
# 69                                        0.327
# 70                                        0.259
# 71                                        0.373
# 72                                        0.242
# 73                                        0.367
# 81                                        0.276
# 82                                        0.231
# 83                                        0.219
# 84                                        0.268
# 85                                         0.24
# 86                                        0.197
# 87                                         0.45
# 88                                        0.198
# 89                                        0.239
# 90                                        0.304
# 91                                        0.232
# 92                                        0.237
# 93                                        0.215
# 94                                        0.234
#
#    Total All Other Groom Bouts in Stim Block  \
# 0                                        134
# 1                                         64
# 2                                         96
# 3                                        197
# 4                                        144
# 5                                        103
# 20                                        91
# 44                                        49
# 45                                       207
# 46                                        26
# 47                                       242
# 48                                       326
# 49                                       457
# 50                                        89
# 51                                       150
# 52                                       197
# 53                                       351
# 54                                       171
# 55                                       274
# 56                                        41
# 57                                        31
# 58                                        64
# 59                                        18
# 60                                       110
# 61                                       130
# 62                                       130
# 63                                        82
# 64                                       105
# 65                                       106
# 66                                       142
# 67                                        82
# 68                                       296
# 69                                       133
# 70                                       110
# 71                                       120
# 72                                        65
# 73                                       219
# 81                                       565
# 82                                       519
# 83                                       565
# 84                                       642
# 85                                       165
# 86                                       245
# 87                                       167
# 88                                       185
# 89                                       315
# 90                                       301
# 91                                       419
# 92                                       305
# 93                                       289
# 94                                       413
#
#    All Other Groom Average Duration in Stim Block(seconds)  \
# 0                                                0.16
# 1                                                0.24
# 2                                                0.18
# 3                                                0.29
# 4                                                0.16
# 5                                                0.18
# 20                                               0.16
# 44                                               0.57
# 45                                                0.7
# 46                                               0.13
# 47                                               0.55
# 48                                               0.56
# 49                                               0.52
# 50                                               1.19
# 51                                               0.33
# 52                                               0.39
# 53                                               0.46
# 54                                               0.47
# 55                                               0.77
# 56                                               0.16
# 57                                               0.18
# 58                                               0.92
# 59                                               0.15
# 60                                                0.2
# 61                                               0.24
# 62                                               0.24
# 63                                               0.26
# 64                                               0.29
# 65                                                0.2
# 66                                               0.22
# 67                                               0.22
# 68                                               0.22
# 69                                               0.26
# 70                                               0.32
# 71                                               0.27
# 72                                               0.29
# 73                                               0.38
# 81                                               0.32
# 82                                               0.22
# 83                                               0.22
# 84                                                0.3
# 85                                               0.21
# 86                                               0.22
# 87                                               0.24
# 88                                                0.2
# 89                                               0.25
# 90                                               0.25
# 91                                               0.24
# 92                                               0.22
# 93                                               0.24
# 94                                               0.19
#
#                                       All Other Array  \
# 0   [[5, 0, 3, 1, 1, 0, 1], [5, 0, 3, 2, 1, 5, 6],...
# 1   [[5, 1, 12, 1, 4, 0, 4], [5, 3, 24, 2, 8, 5, 1...
# 2   [[5, 0, 3, 1, 1, 22, 23], [5, 1, 6, 2, 2, 25, ...
# 3   [[5, 1, 12, 1, 4, 0, 4], [5, 4, 33, 2, 11, 9, ...
# 4   [[5, 0, 3, 1, 1, 0, 1], [5, 1, 6, 2, 2, 12, 14...
# 5   [[5, 0, 3, 1, 1, 8, 9], [5, 0, 3, 2, 1, 26, 27...
# 20  [[5, 2, 15, 1, 5, 0, 5], [5, 3, 27, 2, 9, 8, 1...
# 44  [[5, 25, 228, 1, 76, 0, 76], [5, 2, 18, 2, 6, ...
# 45  [[5, 15, 135, 1, 45, 0, 45], [5, 1, 9, 2, 3, 5...
# 46  [[5, 4, 36, 1, 12, 0, 12], [5, 1, 6, 2, 2, 18,...
# 47  [[5, 21, 186, 1, 62, 0, 62], [5, 0, 3, 2, 1, 6...
# 48  [[5, 1, 12, 1, 4, 1, 5], [5, 1, 9, 2, 3, 6, 9]...
# 49  [[5, 2, 15, 1, 5, 15, 20], [5, 6, 54, 2, 18, 4...
# 50  [[5, 2, 18, 1, 6, 0, 6], [5, 22, 195, 2, 65, 6...
# 51  [[5, 25, 228, 1, 76, 0, 76], [5, 10, 87, 2, 29...
# 52  [[5, 21, 186, 1, 62, 0, 62], [5, 1, 6, 2, 2, 6...
# 53  [[5, 8, 72, 1, 24, 0, 24], [5, 29, 264, 2, 88,...
# 54  [[5, 0, 3, 1, 1, 4, 5], [5, 5, 48, 2, 16, 9, 2...
# 55  [[5, 22, 198, 1, 66, 0, 66], [5, 1, 12, 2, 4, ...
# 56  [[5, 0, 3, 1, 1, 3, 4], [5, 5, 45, 2, 15, 6, 2...
# 57  [[5, 240, 2157, 1, 719, 0, 719], [5, 11, 99, 2...
# 58  [[5, 4, 39, 1, 13, 0, 13], [5, 3, 30, 2, 10, 1...
# 59  [[5, 4, 39, 1, 13, 0, 13], [5, 1, 9, 2, 3, 14,...
# 60  [[5, 5, 45, 1, 15, 0, 15], [5, 0, 3, 2, 1, 17,...
# 61  [[5, 2, 15, 1, 5, 0, 5], [5, 2, 21, 2, 7, 5, 1...
# 62  [[5, 2, 15, 1, 5, 0, 5], [5, 2, 21, 2, 7, 5, 1...
# 63  [[5, 27, 246, 1, 82, 0, 82], [5, 6, 54, 2, 18,...
# 64  [[5, 1, 9, 1, 3, 8, 11], [5, 1, 6, 2, 2, 17, 1...
# 65  [[5, 1, 9, 1, 3, 0, 3], [5, 0, 3, 2, 1, 6, 7],...
# 66  [[5, 16, 144, 1, 48, 0, 48], [5, 6, 51, 2, 17,...
# 67  [[5, 17, 150, 1, 50, 0, 50], [5, 2, 15, 2, 5, ...
# 68  [[5, 125, 1128, 1, 376, 1, 377], [5, 0, 3, 2, ...
# 69  [[5, 30, 267, 1, 89, 0, 89], [5, 40, 363, 2, 1...
# 70  [[5, 27, 240, 1, 80, 0, 80], [5, 26, 237, 2, 7...
# 71  [[5, 1, 9, 1, 3, 1, 4], [5, 39, 351, 2, 117, 5...
# 72  [[5, 0, 3, 1, 1, 13, 14], [5, 12, 111, 2, 37, ...
# 73  [[5, 1, 6, 1, 2, 3, 5], [5, 0, 3, 2, 1, 6, 7],...
# 81  [[5, 1, 6, 1, 2, 0, 2], [5, 2, 15, 2, 5, 14, 1...
# 82  [[5, 2, 21, 1, 7, 1, 8], [5, 0, 3, 2, 1, 9, 10...
# 83  [[5, 2, 21, 1, 7, 1, 8], [5, 4, 39, 2, 13, 10,...
# 84  [[5, 1, 12, 1, 4, 0, 4], [5, 4, 33, 2, 11, 4, ...
# 85  [[5, 16, 144, 1, 48, 0, 48], [5, 2, 21, 2, 7, ...
# 86  [[5, 3, 27, 1, 9, 0, 9], [5, 15, 132, 2, 44, 1...
# 87  [[5, 0, 3, 1, 1, 1, 2], [5, 2, 21, 2, 7, 3, 10...
# 88  [[5, 3, 30, 1, 10, 0, 10], [5, 8, 75, 2, 25, 1...
# 89  [[5, 1, 12, 1, 4, 0, 4], [5, 5, 45, 2, 15, 7, ...
# 90  [[5, 2, 18, 1, 6, 0, 6], [5, 1, 6, 2, 2, 22, 2...
# 91  [[5, 23, 207, 1, 69, 0, 69], [5, 1, 12, 2, 4, ...
# 92  [[5, 2, 18, 1, 6, 3, 9], [5, 2, 15, 2, 5, 12, ...
# 93  [[5, 3, 30, 1, 10, 0, 10], [5, 2, 21, 2, 7, 11...
# 94  [[5, 2, 15, 1, 5, 0, 5], [5, 1, 6, 2, 2, 5, 7]...
#
#    Total All Other Bout Count Average Duration of All Other(seconds)  \
# 0                        3120                                  0.854
# 1                        3405                                  0.771
# 2                        3148                                    0.9
# 3                        2953                                  0.925
# 4                        2487                                  1.303
# 5                        3313                                  0.778
# 20                       2967                                  0.978
# 44                       1423                                  2.317
# 45                       2006                                  1.477
# 46                       1625                                  2.009
# 47                       1294                                  2.528
# 48                       1471                                  2.171
# 49                       1558                                  1.984
# 50                       1034                                  3.306
# 51                       1949                                  1.629
# 52                       1673                                  1.986
# 53                       2316                                  1.306
# 54                       1543                                  2.029
# 55                       1207                                  2.716
# 56                       1964                                  1.663
# 57                       2307                                  1.243
# 58                       1382                                  1.085
# 59                       1896                                  1.583
# 60                       1876                                  1.788
# 61                       2876                                  1.037
# 62                       2876                                  1.037
# 63                       2378                                  1.313
# 64                       2113                                    1.5
# 65                       2198                                  1.464
# 66                       2085                                  1.553
# 67                       1757                                  1.888
# 68                       1663                                  2.034
# 69                       1611                                  2.099
# 70                       1466                                  2.346
# 71                       1288                                  2.682
# 72                       1230                                  2.839
# 73                        882                                  4.144
# 81                       3594                                   0.72
# 82                       3861                                  0.681
# 83                       3657                                   0.72
# 84                       3593                                  0.681
# 85                       3185                                  0.861
# 86                       3476                                  0.761
# 87                       3227                                   0.81
# 88                       3048                                  0.943
# 89                       3224                                  0.853
# 90                       3341                                  0.793
# 91                       3716                                  0.705
# 92                       3133                                    0.9
# 93                       3456                                  0.736
# 94                       2690                                  1.063
#
#    Total All Other Bouts in Stim Block  \
# 0                                 1371
# 1                                 1517
# 2                                 1435
# 3                                 1431
# 4                                 1072
# 5                                 1464
# 20                                1388
# 44                                 745
# 45                                 910
# 46                                 821
# 47                                 882
# 48                                 727
# 49                                1049
# 50                                 504
# 51                                1054
# 52                                 844
# 53                                1059
# 54                                 965
# 55                                 740
# 56                                 954
# 57                                1106
# 58                                1142
# 59                                 923
# 60                                1002
# 61                                1352
# 62                                1352
# 63                                1191
# 64                                 953
# 65                                 959
# 66                                 887
# 67                                 710
# 68                                 767
# 69                                 643
# 70                                 462
# 71                                 572
# 72                                 711
# 73                                 712
# 81                                1691
# 82                                1820
# 83                                1797
# 84                                1711
# 85                                1516
# 86                                1693
# 87                                1547
# 88                                1470
# 89                                1603
# 90                                1611
# 91                                1803
# 92                                1471
# 93                                1566
# 94                                1327
#
#    All Other Average Duration in Stim Block(seconds)
# 0                                                0.9
# 1                                               0.78
# 2                                               0.92
# 3                                               0.85
# 4                                               1.44
# 5                                                0.8
# 20                                              0.94
# 44                                               2.0
# 45                                              1.46
# 46                                               1.8
# 47                                              1.48
# 48                                              1.87
# 49                                              1.22
# 50                                              2.71
# 51                                              1.24
# 52                                              1.69
# 53                                              1.21
# 54                                              1.45
# 55                                              1.82
# 56                                              1.55
# 57                                              1.15
# 58                                              1.09
# 59                                              1.46
# 60                                              1.49
# 61                                              1.01
# 62                                              1.01
# 63                                              1.19
# 64                                              1.55
# 65                                              1.56
# 66                                              1.67
# 67                                              2.22
# 68                                              2.04
# 69                                              2.51
# 70                                              3.53
# 71                                              2.78
# 72                                              2.16
# 73                                              2.12
# 81                                              0.69
# 82                                              0.68
# 83                                              0.65
# 84                                              0.61
# 85                                              0.83
# 86                                              0.71
# 87                                              0.79
# 88                                              0.89
# 89                                              0.79
# 90                                              0.75
# 91                                              0.67
# 92                                              0.88
# 93                                              0.74
# 94                                              1.01
#
# [51 rows x 37 columns]

# %% [raw]
# for iteration, (filtering_criteria, columns, current_match) in iteration_list.items():
#     print(iteration, filtering_criteria)

# %% [markdown]
# # Build Out Analysis:

# %% [markdown]
# # Q1: WAS THERE AN IN SESSION CHANGE ?

# %% [markdown]
# I would like to compare the change bout and duration for each session for each selected behavior for pre, stim, post. To do this I need to additional rows to the Dataframe.
# Step 1 ) Start w/Original DF

# %%
original_df
# Out:
#    Mouse Genotype    Date Selected Behavior  Session Type Session Number  \
# 0   AD12       D1  021624        Right Turn  Stim Session              1
# 1   AD12       D1  022024        Locomotion  Stim Session              1
# 2   AD12       D1  022324        Face Groom  Stim Session              1
# 3   AD14       D1  022324        Right Turn  Stim Session              1
# 4   AD14       D1  022624        Locomotion  Stim Session              1
# ..   ...      ...     ...               ...           ...            ...
# 90   P22       D1  071823        Right Turn  Stim Session              1
# 91   P22       D1  072023        Right Turn  Stim Session              2
# 92   P22       D1  072123    No Error Value  Sham Session              2
# 93   P22       D1  072523        Locomotion  Stim Session              2
# 94   P22       D1  072823    No Error Value  Sham Session              2
#
#    Fiber Connection                                   Right Turn Array  \
# 0         Bilateral  [[1, 0, 3, 1, 1, 203, 204], [1, 0, 3, 2, 1, 21...
# 1         Bilateral  [[1, 0, 3, 1, 1, 13, 14], [1, 1, 9, 2, 3, 19, ...
# 2         Bilateral  [[1, 1, 9, 1, 3, 0, 3], [1, 1, 6, 2, 2, 41, 43...
# 3         Bilateral  [[1, 0, 3, 1, 1, 91, 92], [1, 1, 6, 2, 2, 198,...
# 4         Bilateral  [[1, 1, 12, 1, 4, 46, 50], [1, 0, 3, 2, 1, 62,...
# ..              ...                                                ...
# 90    Contralateral  [[0, 1, 6, 1, 2, 20, 22], [0, 2, 21, 2, 7, 41,...
# 91        Bilateral  [[0, 0, 3, 1, 1, 94, 95], [0, 1, 6, 2, 2, 97, ...
# 92   No Error Value  [[0, 1, 6, 1, 2, 38, 40], [0, 1, 9, 2, 3, 54, ...
# 93        Bilateral  [[0, 1, 9, 1, 3, 39, 42], [0, 0, 3, 2, 1, 45, ...
# 94   No Error Value  [[0, 1, 6, 1, 2, 19, 21], [0, 0, 3, 2, 1, 22, ...
#
#    Total Right Turn Bout Count Average Duration of Right Turn(seconds)  \
# 0                          666                                   0.183
# 1                          789                                   0.199
# 2                          719                                   0.192
# 3                          361                                   0.172
# 4                          249                                   0.143
# ..                         ...                                     ...
# 90                        1081                                   0.202
# 91                        1361                                   0.192
# 92                        1122                                   0.205
# 93                         859                                   0.197
# 94                         794                                     0.2
#
#    Total Right Turn Bouts in Stim Block  \
# 0                                   310
# 1                                   336
# 2                                   356
# 3                                   180
# 4                                   121
# ..                                  ...
# 90                                  566
# 91                                  682
# 92                                  508
# 93                                  476
# 94                                  365
#
#    Right Turn Average Duration in Stim Block(seconds)  \
# 0                                                0.18
# 1                                                0.21
# 2                                                0.19
# 3                                                0.16
# 4                                                0.14
# ..                                                ...
# 90                                                0.2
# 91                                               0.19
# 92                                                0.2
# 93                                                0.2
# 94                                                0.2
#
#                                       Left Turn Array  \
# 0   [[0, 0, 3, 1, 1, 10, 11], [0, 1, 6, 2, 2, 12, ...
# 1   [[0, 0, 3, 1, 1, 60, 61], [0, 0, 3, 2, 1, 63, ...
# 2   [[0, 0, 3, 1, 1, 23, 24], [0, 0, 3, 2, 1, 27, ...
# 3   [[0, 2, 15, 1, 5, 4, 9], [0, 1, 12, 2, 4, 32, ...
# 4   [[0, 1, 6, 1, 2, 14, 16], [0, 0, 3, 2, 1, 18, ...
# ..                                                ...
# 90  [[1, 2, 18, 1, 6, 8, 14], [1, 1, 6, 2, 2, 136,...
# 91  [[1, 0, 3, 1, 1, 106, 107], [1, 1, 12, 2, 4, 1...
# 92  [[1, 1, 6, 1, 2, 9, 11], [1, 0, 3, 2, 1, 21, 2...
# 93  [[1, 1, 6, 1, 2, 9, 11], [1, 0, 3, 2, 1, 23, 2...
# 94  [[1, 0, 3, 1, 1, 71, 72], [1, 0, 3, 2, 1, 80, ...
#
#    Total Left Turn Bout Count Average Duration of Left Turn(seconds)  \
# 0                         921                                  0.184
# 1                         926                                  0.187
# 2                         893                                  0.179
# 3                         558                                  0.186
# 4                         227                                  0.145
# ..                        ...                                    ...
# 90                        917                                  0.194
# 91                       1135                                  0.182
# 92                        831                                  0.184
# 93                        613                                  0.185
# 94                        674                                   0.18
#
#    Total Left Turn Bouts in Stim Block  \
# 0                                  429
# 1                                  418
# 2                                  449
# 3                                  253
# 4                                  137
# ..                                 ...
# 90                                 498
# 91                                 542
# 92                                 396
# 93                                 347
# 94                                 267
#
#    Left Turn Average Duration in Stim Block(seconds)  \
# 0                                               0.18
# 1                                               0.18
# 2                                               0.18
# 3                                               0.18
# 4                                               0.14
# ..                                               ...
# 90                                               0.2
# 91                                              0.17
# 92                                              0.18
# 93                                              0.18
# 94                                              0.18
#
#                                      Locomotion Array  \
# 0   [[2, 1, 12, 1, 4, 1, 5], [2, 1, 12, 2, 4, 6, 1...
# 1   [[2, 0, 3, 1, 1, 4, 5], [2, 3, 30, 2, 10, 22, ...
# 2   [[2, 6, 57, 1, 19, 3, 22], [2, 0, 3, 2, 1, 24,...
# 3   [[2, 1, 6, 1, 2, 36, 38], [2, 0, 3, 2, 1, 39, ...
# 4   [[2, 4, 33, 1, 11, 1, 12], [2, 1, 9, 2, 3, 31,...
# ..                                                ...
# 90  [[2, 1, 9, 1, 3, 5, 8], [2, 2, 18, 2, 6, 14, 2...
# 91  [[2, 2, 21, 1, 7, 99, 106], [2, 2, 15, 2, 5, 2...
# 92  [[2, 1, 12, 1, 4, 0, 4], [2, 0, 3, 2, 1, 11, 1...
# 93  [[2, 1, 12, 1, 4, 18, 22], [2, 1, 9, 2, 3, 42,...
# 94  [[2, 1, 9, 1, 3, 66, 69], [2, 1, 12, 2, 4, 92,...
#
#    Total Locomotion Bout Count Average Duration of Locomotion(seconds)  \
# 0                         1758                                    0.47
# 1                         1661                                   0.433
# 2                         1389                                   0.388
# 3                         1481                                   0.477
# 4                          644                                   0.333
# ..                         ...                                     ...
# 90                         923                                   0.246
# 91                        1126                                   0.237
# 92                         851                                   0.258
# 93                         716                                   0.272
# 94                         541                                   0.291
#
#    Total Locomotion Bouts in Stim Block  \
# 0                                   795
# 1                                   852
# 2                                   726
# 3                                   722
# 4                                   407
# ..                                  ...
# 90                                  531
# 91                                  520
# 92                                  386
# 93                                  435
# 94                                  246
#
#    Locomotion Average Duration in Stim Block(seconds)  \
# 0                                                0.49
# 1                                                0.43
# 2                                                0.38
# 3                                                 0.5
# 4                                                0.28
# ..                                                ...
# 90                                               0.25
# 91                                               0.21
# 92                                               0.28
# 93                                               0.25
# 94                                               0.32
#
#                                      Face Groom Array  \
# 0   [[3, 3, 24, 1, 8, 1376, 1384], [3, 0, 3, 2, 1,...
# 1   [[3, 0, 3, 1, 1, 104, 105], [3, 0, 3, 2, 1, 10...
# 2   [[3, 0, 3, 1, 1, 421, 422], [3, 0, 3, 2, 1, 42...
# 3   [[3, 0, 3, 1, 1, 20, 21], [3, 1, 9, 2, 3, 540,...
# 4   [[3, 1, 9, 1, 3, 20, 23], [3, 0, 3, 2, 1, 24, ...
# ..                                                ...
# 90  [[3, 1, 9, 1, 3, 24, 27], [3, 0, 3, 2, 1, 167,...
# 91  [[3, 1, 12, 1, 4, 68, 72], [3, 0, 3, 2, 1, 76,...
# 92  [[3, 1, 6, 1, 2, 117, 119], [3, 0, 3, 2, 1, 12...
# 93  [[3, 1, 6, 1, 2, 134, 136], [3, 3, 27, 2, 9, 1...
# 94  [[3, 0, 3, 1, 1, 101, 102], [3, 1, 6, 2, 2, 10...
#
#    Total Face Groom Bout Count Average Duration of Face Groom(seconds)  \
# 0                          293                                   0.245
# 1                          312                                   0.379
# 2                          437                                   0.315
# 3                          606                                   0.303
# 4                         1214                                   0.258
# ..                         ...                                     ...
# 90                        1159                                   0.348
# 91                        1100                                   0.327
# 92                        1051                                   0.303
# 93                        1650                                   0.436
# 94                         945                                   0.461
#
#    Total Face Groom Bouts in Stim Block  \
# 0                                    97
# 1                                   175
# 2                                   133
# 3                                   305
# 4                                   350
# ..                                  ...
# 90                                  471
# 91                                  485
# 92                                  507
# 93                                  628
# 94                                  431
#
#    Face Groom Average Duration in Stim Block(seconds)  \
# 0                                                0.24
# 1                                                0.46
# 2                                                0.21
# 3                                                 0.3
# 4                                                0.23
# ..                                                ...
# 90                                               0.36
# 91                                               0.32
# 92                                               0.31
# 93                                               0.48
# 94                                               0.41
#
#                                 All Other Groom Array  \
# 0   [[4, 1, 6, 1, 2, 2663, 2665], [4, 0, 3, 2, 1, ...
# 1   [[4, 0, 3, 1, 1, 2011, 2012], [4, 0, 3, 2, 1, ...
# 2   [[4, 0, 3, 1, 1, 426, 427], [4, 0, 3, 2, 1, 45...
# 3   [[4, 1, 6, 1, 2, 3979, 3981], [4, 0, 3, 2, 1, ...
# 4   [[4, 0, 3, 1, 1, 97, 98], [4, 0, 3, 2, 1, 373,...
# ..                                                ...
# 90  [[4, 0, 3, 1, 1, 34, 35], [4, 1, 9, 2, 3, 117,...
# 91  [[4, 1, 9, 1, 3, 82, 85], [4, 0, 3, 2, 1, 93, ...
# 92  [[4, 1, 9, 1, 3, 114, 117], [4, 1, 9, 2, 3, 12...
# 93  [[4, 0, 3, 1, 1, 130, 131], [4, 0, 3, 2, 1, 15...
# 94  [[4, 0, 3, 1, 1, 4, 5], [4, 0, 3, 2, 1, 7, 8],...
#
#    Total All Other Groom Bout Count  \
# 0                               253
# 1                               484
# 2                               336
# 3                               412
# 4                               348
# ..                              ...
# 90                              732
# 91                              810
# 92                              678
# 93                              747
# 94                              715
#
#    Average Duration of All Other Groom(seconds)  \
# 0                                         0.182
# 1                                         0.219
# 2                                         0.282
# 3                                         0.275
# 4                                         0.182
# ..                                          ...
# 90                                        0.304
# 91                                        0.232
# 92                                        0.237
# 93                                        0.215
# 94                                        0.234
#
#    Total All Other Groom Bouts in Stim Block  \
# 0                                        134
# 1                                         64
# 2                                         96
# 3                                        197
# 4                                        144
# ..                                       ...
# 90                                       301
# 91                                       419
# 92                                       305
# 93                                       289
# 94                                       413
#
#    All Other Groom Average Duration in Stim Block(seconds)  \
# 0                                                0.16
# 1                                                0.24
# 2                                                0.18
# 3                                                0.29
# 4                                                0.16
# ..                                                ...
# 90                                               0.25
# 91                                               0.24
# 92                                               0.22
# 93                                               0.24
# 94                                               0.19
#
#                                       All Other Array  \
# 0   [[5, 0, 3, 1, 1, 0, 1], [5, 0, 3, 2, 1, 5, 6],...
# 1   [[5, 1, 12, 1, 4, 0, 4], [5, 3, 24, 2, 8, 5, 1...
# 2   [[5, 0, 3, 1, 1, 22, 23], [5, 1, 6, 2, 2, 25, ...
# 3   [[5, 1, 12, 1, 4, 0, 4], [5, 4, 33, 2, 11, 9, ...
# 4   [[5, 0, 3, 1, 1, 0, 1], [5, 1, 6, 2, 2, 12, 14...
# ..                                                ...
# 90  [[5, 2, 18, 1, 6, 0, 6], [5, 1, 6, 2, 2, 22, 2...
# 91  [[5, 23, 207, 1, 69, 0, 69], [5, 1, 12, 2, 4, ...
# 92  [[5, 2, 18, 1, 6, 3, 9], [5, 2, 15, 2, 5, 12, ...
# 93  [[5, 3, 30, 1, 10, 0, 10], [5, 2, 21, 2, 7, 11...
# 94  [[5, 2, 15, 1, 5, 0, 5], [5, 1, 6, 2, 2, 5, 7]...
#
#    Total All Other Bout Count Average Duration of All Other(seconds)  \
# 0                        3120                                  0.854
# 1                        3405                                  0.771
# 2                        3148                                    0.9
# 3                        2953                                  0.925
# 4                        2487                                  1.303
# ..                        ...                                    ...
# 90                       3341                                  0.793
# 91                       3716                                  0.705
# 92                       3133                                    0.9
# 93                       3456                                  0.736
# 94                       2690                                  1.063
#
#    Total All Other Bouts in Stim Block  \
# 0                                 1371
# 1                                 1517
# 2                                 1435
# 3                                 1431
# 4                                 1072
# ..                                 ...
# 90                                1611
# 91                                1803
# 92                                1471
# 93                                1566
# 94                                1327
#
#    All Other Average Duration in Stim Block(seconds)
# 0                                                0.9
# 1                                               0.78
# 2                                               0.92
# 3                                               0.85
# 4                                               1.44
# ..                                               ...
# 90                                              0.75
# 91                                              0.67
# 92                                              0.88
# 93                                              0.74
# 94                                              1.01
#
# [95 rows x 37 columns]

# %%
prepost_boutduration=original_df.copy()

# %%
len(prepost_boutduration.columns)
# Out:
# 37

# %%
for col_name in prepost_boutduration.columns:
    if "Array" in col_name:
        action= col_name.split('Array')[0]
        preboutrowtocol=[]
        postboutrowtocol=[]
        predurationrowtocol=[]
        postdurationrowtocol=[]
        for element in prepost_boutduration[col_name]: #calls the row which is a  list of tuples
            prebout=0
            postbout=0
            preduration=[]
            postduration=[]
            for tup in element: # calls the tuples individually
                if tup[5]>=0 and tup[6]<= 3000:
                    prebout+=1
                    preduration.append(tup[4])
                if tup[5]>=21001 and tup[6]<=39000:
                    postbout+=1
                    postduration.append(tup[4])
            preboutrowtocol.append(prebout)
            postboutrowtocol.append(postbout)
            predurationaverage=round((statistics.mean(preduration))/10,2) if preduration else 0
            postdurationaverage=round((statistics.mean(postduration))/10,2) if postduration else 0
            predurationrowtocol.append(predurationaverage)
            postdurationrowtocol.append(postdurationaverage)
            
        prepost_boutduration[f'{action}Bouts Pre Stim']= preboutrowtocol
        prepost_boutduration[f'{action}Bouts Post Stim']=postboutrowtocol
        prepost_boutduration[f'{action}Average Duration Pre Stim']=predurationrowtocol
        prepost_boutduration[f'{action}Average Duration Post Stim']=postdurationrowtocol
        
prepost_boutduration[f'{action}Total Bouts Pre Stim']= preboutrowtocol
prepost_boutduration[f'{action}Total Bouts Post Stim']=postboutrowtocol
prepost_boutduration[f'{action}Average Duration Pre Stim']=predurationrowtocol
prepost_boutduration[f'{action}Average Duration Post Stim']=postdurationrowtocol

# %%
for col in prepost_boutduration.columns:
    if "Bouts Post Stim" in col or "Bouts Pre Stim" in col or "Bouts in Stim Block" in col:
         if behavior in bout_data:
# Out:
#   Input In [376]
#     if behavior in bout_data:
#                              ^
# SyntaxError: incomplete input

# %%
bout_data = {}
duration_data = {}

for col in prepost_boutduration.columns:
    if "Bouts Post Stim" in col or "Bouts Pre Stim" in col or "Bouts in Stim Block" in col:
        bouts=[]
        if 'Total' in col:
            col_1=col.replace("Total","")
            col_name= col_1.strip().split('Bout')[0].strip()
            time_frame = col_name[1].strip()
        else:
            col_name = col.strip().split('Bouts')[0].strip()
            time_frame = col.strip().split('Bouts')[1].strip()
  
        if "Pre Stim" in time_frame:
            time_frame_key = "Pre Stim"
        elif "Post Stim" in time_frame:
            time_frame_key = "Post Stim"
        else:
            time_frame_key = "Stim"
            
        bout_data.setdefault(col_name, {})[time_frame_key] = list(prepost_boutduration[col])
            

    if 'Average Duration Post Stim' in col or "Average Duration Pre Stim" in col or 'Average Duration in Stim Block' in col:
        if 'Total' in col:
            col_1=col.replace("Total", "")
            col_name= col_1.strip().split('Average Duration')[0].strip()
            time_frame = col_name[1].strip()
        else:
            col_name = col.strip().split('Average Duration')[0]
            time_frame = col.strip().split('Average Duration')[1]
        
        if "Pre Stim" in time_frame:
            time_frame_key = "Pre Stim"
        elif "Post Stim" in time_frame:
            time_frame_key = "Post Stim"
        else:
            time_frame_key = "Stim"
        duration_data.setdefault(col_name,{})[time_frame_key]=list(prepost_boutduration[col])

# %%
for key, value in bout_data.items():
        if 'Stim' in value and 'Pre Stim' in value and 'Post Stim' in value:
            pre = []
            post = []
            
            for pre_stim, stim in zip(value['Pre Stim'], value['Stim']):
                stimminuspre = stim - pre_stim
                pre.append(stimminuspre)

            for stim, post_stim in zip(value['Stim'], value['Post Stim']):
                stimminuspost = stim - post_stim
                post.append(stimminuspost)

            prepost_boutduration[f'{key} stim-pre bouts'] = pre
            prepost_boutduration[f'{key} stim-post bouts'] = post
            
for key, value in duration_data.items():
        if 'Stim' in value and 'Pre Stim' in value and 'Post Stim' in value:
            pre = []
            post = []
            
            for pre_stim, stim in zip(value['Pre Stim'], value['Stim']):
                stimminuspre = stim - pre_stim
                pre.append(stimminuspre)

            for stim, post_stim in zip(value['Stim'], value['Post Stim']):
                stimminuspost = stim - post_stim
                post.append(stimminuspost)

            prepost_boutduration[f'{key}stim-pre duration'] = pre
            prepost_boutduration[f'{key}stim-post duration'] = post
# Out:
#  Right Turn: (39, 310)
#  Right Turn: (58, 336)
#  Right Turn: (74, 356)
#  Right Turn: (48, 180)
#  Right Turn: (82, 121)
#  Right Turn: (56, 340)
#  Right Turn: (49, 210)
#  Right Turn: (65, 352)
#  Right Turn: (48, 381)
#  Right Turn: (66, 435)
#  Right Turn: (68, 446)
#  Right Turn: (105, 378)
#  Right Turn: (102, 476)
#  Right Turn: (41, 308)
#  Right Turn: (133, 684)
#  Right Turn: (112, 477)
#  Right Turn: (90, 562)
#  Right Turn: (117, 676)
#  Right Turn: (106, 553)
#  Right Turn: (71, 493)
#  Right Turn: (48, 247)
#  Right Turn: (103, 282)
#  Right Turn: (75, 367)
#  Right Turn: (76, 122)
#  Right Turn: (66, 336)
#  Right Turn: (35, 55)
#  Right Turn: (54, 118)
#  Right Turn: (136, 738)
#  Right Turn: (122, 733)
#  Right Turn: (136, 738)
#  Right Turn: (141, 569)
#  Right Turn: (78, 362)
#  Right Turn: (110, 419)
#  Right Turn: (62, 82)
#  Right Turn: (34, 57)
#  Right Turn: (43, 114)
#  Right Turn: (35, 180)
#  Right Turn: (91, 288)
#  Right Turn: (90, 392)
#  Right Turn: (126, 438)
#  Right Turn: (49, 412)
#  Right Turn: (104, 412)
#  Right Turn: (89, 490)
#  Right Turn: (79, 384)
#  Right Turn: (36, 227)
#  Right Turn: (20, 229)
#  Right Turn: (45, 190)
#  Right Turn: (28, 134)
#  Right Turn: (34, 136)
#  Right Turn: (49, 104)
#  Right Turn: (37, 110)
#  Right Turn: (31, 159)
#  Right Turn: (47, 165)
#  Right Turn: (18, 104)
#  Right Turn: (39, 160)
#  Right Turn: (36, 100)
#  Right Turn: (49, 412)
#  Right Turn: (43, 319)
#  Right Turn: (37, 237)
#  Right Turn: (48, 220)
#  Right Turn: (111, 392)
#  Right Turn: (74, 448)
#  Right Turn: (74, 448)
#  Right Turn: (78, 378)
#  Right Turn: (58, 294)
#  Right Turn: (61, 319)
#  Right Turn: (30, 275)
#  Right Turn: (43, 184)
#  Right Turn: (31, 98)
#  Right Turn: (42, 111)
#  Right Turn: (24, 48)
#  Right Turn: (44, 80)
#  Right Turn: (17, 24)
#  Right Turn: (19, 49)
#  Right Turn: (103, 563)
#  Right Turn: (116, 500)
#  Right Turn: (111, 460)
#  Right Turn: (78, 387)
#  Right Turn: (69, 160)
#  Right Turn: (52, 192)
#  Right Turn: (59, 234)
#  Right Turn: (72, 518)
#  Right Turn: (118, 636)
#  Right Turn: (109, 546)
#  Right Turn: (129, 561)
#  Right Turn: (125, 668)
#  Right Turn: (63, 677)
#  Right Turn: (115, 662)
#  Right Turn: (104, 576)
#  Right Turn: (81, 547)
#  Right Turn: (98, 566)
#  Right Turn: (136, 682)
#  Right Turn: (131, 508)
#  Right Turn: (132, 476)
#  Right Turn: (123, 365)
#  Left Turn: (89, 429)
#  Left Turn: (88, 418)
#  Left Turn: (86, 449)
#  Left Turn: (88, 253)
#  Left Turn: (40, 137)
#  Left Turn: (66, 342)
#  Left Turn: (46, 208)
#  Left Turn: (77, 566)
#  Left Turn: (100, 509)
#  Left Turn: (74, 514)
#  Left Turn: (97, 552)
#  Left Turn: (91, 476)
#  Left Turn: (83, 573)
#  Left Turn: (57, 274)
#  Left Turn: (153, 729)
#  Left Turn: (109, 687)
#  Left Turn: (114, 650)
#  Left Turn: (89, 513)
#  Left Turn: (107, 627)
#  Left Turn: (112, 536)
#  Left Turn: (71, 372)
#  Left Turn: (142, 292)
#  Left Turn: (104, 270)
#  Left Turn: (78, 146)
#  Left Turn: (93, 347)
#  Left Turn: (53, 63)
#  Left Turn: (62, 170)
#  Left Turn: (85, 610)
#  Left Turn: (100, 610)
#  Left Turn: (85, 610)
#  Left Turn: (88, 674)
#  Left Turn: (71, 317)
#  Left Turn: (107, 256)
#  Left Turn: (60, 54)
#  Left Turn: (28, 35)
#  Left Turn: (25, 84)
#  Left Turn: (35, 125)
#  Left Turn: (76, 276)
#  Left Turn: (69, 314)
#  Left Turn: (81, 456)
#  Left Turn: (51, 332)
#  Left Turn: (78, 418)
#  Left Turn: (72, 440)
#  Left Turn: (80, 293)
#  Left Turn: (27, 125)
#  Left Turn: (45, 161)
#  Left Turn: (61, 179)
#  Left Turn: (29, 106)
#  Left Turn: (39, 54)
#  Left Turn: (60, 67)
#  Left Turn: (30, 81)
#  Left Turn: (26, 122)
#  Left Turn: (22, 101)
#  Left Turn: (31, 113)
#  Left Turn: (47, 172)
#  Left Turn: (32, 105)
#  Left Turn: (51, 332)
#  Left Turn: (41, 292)
#  Left Turn: (31, 300)
#  Left Turn: (27, 216)
#  Left Turn: (90, 363)
#  Left Turn: (100, 385)
#  Left Turn: (100, 385)
#  Left Turn: (82, 359)
#  Left Turn: (83, 303)
#  Left Turn: (69, 246)
#  Left Turn: (39, 252)
#  Left Turn: (55, 161)
#  Left Turn: (39, 83)
#  Left Turn: (29, 87)
#  Left Turn: (25, 70)
#  Left Turn: (27, 61)
#  Left Turn: (17, 16)
#  Left Turn: (36, 51)
#  Left Turn: (72, 413)
#  Left Turn: (102, 345)
#  Left Turn: (74, 322)
#  Left Turn: (85, 255)
#  Left Turn: (66, 189)
#  Left Turn: (71, 229)
#  Left Turn: (62, 160)
#  Left Turn: (82, 349)
#  Left Turn: (80, 491)
#  Left Turn: (94, 480)
#  Left Turn: (57, 318)
#  Left Turn: (72, 568)
#  Left Turn: (91, 534)
#  Left Turn: (63, 544)
#  Left Turn: (61, 569)
#  Left Turn: (64, 507)
#  Left Turn: (93, 498)
#  Left Turn: (126, 542)
#  Left Turn: (62, 396)
#  Left Turn: (80, 347)
#  Left Turn: (132, 267)
#  Locomotion: (231, 795)
#  Locomotion: (196, 852)
#  Locomotion: (166, 726)
#  Locomotion: (241, 722)
#  Locomotion: (142, 407)
#  Locomotion: (204, 907)
#  Locomotion: (134, 335)
#  Locomotion: (131, 641)
#  Locomotion: (171, 684)
#  Locomotion: (193, 1046)
#  Locomotion: (171, 969)
#  Locomotion: (156, 614)
#  Locomotion: (192, 1155)
#  Locomotion: (148, 595)
#  Locomotion: (223, 1122)
#  Locomotion: (200, 1052)
#  Locomotion: (131, 862)
#  Locomotion: (166, 869)
#  Locomotion: (195, 1228)
#  Locomotion: (226, 1122)
#  Locomotion: (180, 787)
#  Locomotion: (179, 394)
#  Locomotion: (102, 411)
#  Locomotion: (92, 174)
#  Locomotion: (79, 777)
#  Locomotion: (74, 159)
#  Locomotion: (109, 218)
#  Locomotion: (139, 755)
#  Locomotion: (127, 781)
#  Locomotion: (139, 755)
#  Locomotion: (132, 713)
#  Locomotion: (73, 290)
#  Locomotion: (119, 289)
#  Locomotion: (66, 44)
#  Locomotion: (31, 24)
#  Locomotion: (33, 97)
#  Locomotion: (41, 105)
#  Locomotion: (79, 284)
#  Locomotion: (75, 319)
#  Locomotion: (104, 462)
#  Locomotion: (52, 333)
#  Locomotion: (77, 559)
#  Locomotion: (85, 459)
#  Locomotion: (104, 225)
#  Locomotion: (113, 386)
#  Locomotion: (125, 383)
#  Locomotion: (135, 514)
#  Locomotion: (86, 306)
#  Locomotion: (86, 176)
#  Locomotion: (125, 133)
#  Locomotion: (93, 174)
#  Locomotion: (49, 210)
#  Locomotion: (80, 192)
#  Locomotion: (55, 152)
#  Locomotion: (74, 330)
#  Locomotion: (55, 172)
#  Locomotion: (52, 333)
#  Locomotion: (84, 669)
#  Locomotion: (123, 625)
#  Locomotion: (127, 620)
#  Locomotion: (90, 250)
#  Locomotion: (106, 443)
#  Locomotion: (106, 443)
#  Locomotion: (100, 374)
#  Locomotion: (86, 258)
#  Locomotion: (73, 300)
#  Locomotion: (48, 262)
#  Locomotion: (50, 169)
#  Locomotion: (53, 93)
#  Locomotion: (42, 114)
#  Locomotion: (28, 55)
#  Locomotion: (41, 62)
#  Locomotion: (15, 28)
#  Locomotion: (97, 107)
#  Locomotion: (128, 555)
#  Locomotion: (104, 408)
#  Locomotion: (98, 461)
#  Locomotion: (92, 291)
#  Locomotion: (73, 233)
#  Locomotion: (104, 186)
#  Locomotion: (120, 413)
#  Locomotion: (83, 425)
#  Locomotion: (73, 396)
#  Locomotion: (61, 401)
#  Locomotion: (78, 344)
#  Locomotion: (68, 489)
#  Locomotion: (58, 478)
#  Locomotion: (86, 603)
#  Locomotion: (77, 512)
#  Locomotion: (64, 427)
#  Locomotion: (78, 531)
#  Locomotion: (107, 520)
#  Locomotion: (84, 386)
#  Locomotion: (102, 435)
#  Locomotion: (93, 246)
#  Face Groom: (13, 97)
#  Face Groom: (22, 175)
#  Face Groom: (16, 133)
#  Face Groom: (4, 305)
#  Face Groom: (54, 350)
#  Face Groom: (20, 124)
#  Face Groom: (18, 443)
#  Face Groom: (27, 290)
#  Face Groom: (58, 415)
#  Face Groom: (15, 117)
#  Face Groom: (19, 164)
#  Face Groom: (45, 295)
#  Face Groom: (19, 172)
#  Face Groom: (19, 374)
#  Face Groom: (8, 237)
#  Face Groom: (19, 136)
#  Face Groom: (36, 223)
#  Face Groom: (34, 231)
#  Face Groom: (17, 185)
#  Face Groom: (4, 105)
#  Face Groom: (19, 141)
#  Face Groom: (18, 110)
#  Face Groom: (42, 293)
#  Face Groom: (109, 346)
#  Face Groom: (54, 248)
#  Face Groom: (2, 43)
#  Face Groom: (13, 109)
#  Face Groom: (38, 222)
#  Face Groom: (37, 298)
#  Face Groom: (38, 222)
#  Face Groom: (38, 234)
#  Face Groom: (19, 228)
#  Face Groom: (8, 65)
#  Face Groom: (7, 324)
#  Face Groom: (8, 163)
#  Face Groom: (23, 363)
#  Face Groom: (4, 15)
#  Face Groom: (26, 111)
#  Face Groom: (22, 144)
#  Face Groom: (39, 141)
#  Face Groom: (18, 110)
#  Face Groom: (21, 107)
#  Face Groom: (36, 44)
#  Face Groom: (6, 55)
#  Face Groom: (6, 107)
#  Face Groom: (11, 241)
#  Face Groom: (29, 61)
#  Face Groom: (10, 277)
#  Face Groom: (18, 417)
#  Face Groom: (8, 665)
#  Face Groom: (29, 184)
#  Face Groom: (41, 617)
#  Face Groom: (14, 423)
#  Face Groom: (85, 651)
#  Face Groom: (42, 275)
#  Face Groom: (29, 345)
#  Face Groom: (18, 110)
#  Face Groom: (35, 83)
#  Face Groom: (32, 202)
#  Face Groom: (17, 61)
#  Face Groom: (30, 146)
#  Face Groom: (42, 410)
#  Face Groom: (42, 410)
#  Face Groom: (35, 328)
#  Face Groom: (21, 221)
#  Face Groom: (39, 185)
#  Face Groom: (47, 129)
#  Face Groom: (23, 236)
#  Face Groom: (17, 268)
#  Face Groom: (23, 266)
#  Face Groom: (18, 203)
#  Face Groom: (11, 308)
#  Face Groom: (7, 597)
#  Face Groom: (16, 354)
#  Face Groom: (15, 260)
#  Face Groom: (12, 194)
#  Face Groom: (23, 313)
#  Face Groom: (17, 145)
#  Face Groom: (20, 329)
#  Face Groom: (26, 139)
#  Face Groom: (19, 68)
#  Face Groom: (49, 557)
#  Face Groom: (51, 488)
#  Face Groom: (117, 503)
#  Face Groom: (77, 648)
#  Face Groom: (89, 312)
#  Face Groom: (52, 521)
#  Face Groom: (68, 348)
#  Face Groom: (31, 281)
#  Face Groom: (58, 520)
#  Face Groom: (105, 471)
#  Face Groom: (57, 485)
#  Face Groom: (57, 507)
#  Face Groom: (94, 628)
#  Face Groom: (38, 431)
#  All Other Groom: (4, 134)
#  All Other Groom: (6, 64)
#  All Other Groom: (3, 96)
#  All Other Groom: (0, 197)
#  All Other Groom: (16, 144)
#  All Other Groom: (4, 103)
#  All Other Groom: (0, 206)
#  All Other Groom: (4, 54)
#  All Other Groom: (2, 38)
#  All Other Groom: (6, 81)
#  All Other Groom: (2, 89)
#  All Other Groom: (13, 89)
#  All Other Groom: (8, 52)
#  All Other Groom: (8, 208)
#  All Other Groom: (2, 100)
#  All Other Groom: (1, 60)
#  All Other Groom: (12, 128)
#  All Other Groom: (1, 20)
#  All Other Groom: (3, 18)
#  All Other Groom: (1, 2)
#  All Other Groom: (3, 91)
#  All Other Groom: (2, 37)
#  All Other Groom: (10, 137)
#  All Other Groom: (14, 203)
#  All Other Groom: (35, 69)
#  All Other Groom: (1, 5)
#  All Other Groom: (0, 21)
#  All Other Groom: (7, 146)
#  All Other Groom: (6, 64)
#  All Other Groom: (7, 146)
#  All Other Groom: (4, 51)
#  All Other Groom: (5, 196)
#  All Other Groom: (7, 46)
#  All Other Groom: (5, 235)
#  All Other Groom: (6, 100)
#  All Other Groom: (0, 246)
#  All Other Groom: (1, 15)
#  All Other Groom: (7, 63)
#  All Other Groom: (5, 44)
#  All Other Groom: (7, 26)
#  All Other Groom: (8, 41)
#  All Other Groom: (4, 41)
#  All Other Groom: (5, 16)
#  All Other Groom: (5, 18)
#  All Other Groom: (4, 49)
#  All Other Groom: (0, 207)
#  All Other Groom: (2, 26)
#  All Other Groom: (4, 242)
#  All Other Groom: (0, 326)
#  All Other Groom: (1, 457)
#  All Other Groom: (27, 89)
#  All Other Groom: (1, 150)
#  All Other Groom: (12, 197)
#  All Other Groom: (24, 351)
#  All Other Groom: (2, 171)
#  All Other Groom: (13, 274)
#  All Other Groom: (8, 41)
#  All Other Groom: (1, 31)
#  All Other Groom: (12, 64)
#  All Other Groom: (3, 18)
#  All Other Groom: (2, 110)
#  All Other Groom: (9, 130)
#  All Other Groom: (9, 130)
#  All Other Groom: (5, 82)
#  All Other Groom: (4, 105)
#  All Other Groom: (19, 106)
#  All Other Groom: (21, 142)
#  All Other Groom: (25, 82)
#  All Other Groom: (37, 296)
#  All Other Groom: (35, 133)
#  All Other Groom: (1, 110)
#  All Other Groom: (7, 120)
#  All Other Groom: (1, 65)
#  All Other Groom: (7, 219)
#  All Other Groom: (8, 141)
#  All Other Groom: (7, 100)
#  All Other Groom: (18, 123)
#  All Other Groom: (2, 104)
#  All Other Groom: (20, 209)
#  All Other Groom: (10, 99)
#  All Other Groom: (8, 33)
#  All Other Groom: (15, 565)
#  All Other Groom: (58, 519)
#  All Other Groom: (54, 565)
#  All Other Groom: (126, 642)
#  All Other Groom: (27, 165)
#  All Other Groom: (25, 245)
#  All Other Groom: (18, 167)
#  All Other Groom: (41, 185)
#  All Other Groom: (35, 315)
#  All Other Groom: (55, 301)
#  All Other Groom: (32, 419)
#  All Other Groom: (30, 305)
#  All Other Groom: (37, 289)
#  All Other Groom: (23, 413)
#  All Other: (263, 1484)
#  All Other: (253, 1635)
#  All Other: (225, 1485)
#  All Other: (272, 1248)
#  All Other: (267, 1146)
#  All Other: (268, 1578)
#  All Other: (219, 1478)
#  All Other: (223, 1635)
#  All Other: (309, 1765)
#  All Other: (272, 1763)
#  All Other: (252, 1745)
#  All Other: (287, 1480)
#  All Other: (246, 1696)
#  All Other: (234, 1572)
#  All Other: (306, 2115)
#  All Other: (276, 65)
#  All Other: (287, 1763)
#  All Other: (269, 1761)
#  All Other: (291, 1624)
#  All Other: (292, 1639)
#  All Other: (255, 1322)
#  All Other: (306, 829)
#  All Other: (274, 1341)
#  All Other: (294, 1035)
#  All Other: (257, 978)
#  All Other: (141, 248)
#  All Other: (205, 695)
#  All Other: (227, 820)
#  All Other: (245, 1657)
#  All Other: (227, 820)
#  All Other: (264, 1573)
#  All Other: (177, 816)
#  All Other: (275, 1051)
#  All Other: (160, 283)
#  All Other: (98, 238)
#  All Other: (116, 788)
#  All Other: (102, 512)
#  All Other: (230, 634)
#  All Other: (207, 1123)
#  All Other: (275, 1141)
#  All Other: (151, 856)
#  All Other: (226, 1258)
#  All Other: (219, 1022)
#  All Other: (225, 1175)
#  All Other: (165, 510)
#  All Other: (180, 913)
#  All Other: (220, 582)
#  All Other: (142, 268)
#  All Other: (155, 587)
#  All Other: (189, 318)
#  All Other: (179, 348)
#  All Other: (122, 772)
#  All Other: (151, 677)
#  All Other: (153, 1102)
#  All Other: (171, 406)
#  All Other: (135, 330)
#  All Other: (151, 856)
#  All Other: (176, 1022)
#  All Other: (210, 29)
#  All Other: (167, 803)
#  All Other: (233, 638)
#  All Other: (237, 1284)
#  All Other: (237, 1284)
#  All Other: (221, 965)
#  All Other: (184, 974)
#  All Other: (219, 1017)
#  All Other: (174, 1021)
#  All Other: (154, 890)
#  All Other: (158, 735)
#  All Other: (149, 817)
#  All Other: (87, 915)
#  All Other: (110, 603)
#  All Other: (53, 463)
#  All Other: (152, 16)
#  All Other: (216, 1408)
#  All Other: (223, 1102)
#  All Other: (205, 849)
#  All Other: (188, 869)
#  All Other: (190, 818)
#  All Other: (206, 723)
#  All Other: (215, 0)
#  All Other: (218, 1682)
#  All Other: (263, 1775)
#  All Other: (325, 1533)
#  All Other: (278, 1602)
#  All Other: (267, 1400)
#  All Other: (216, 1566)
#  All Other: (256, 1423)
#  All Other: (189, 1387)
#  All Other: (220, 1399)
#  All Other: (316, 1411)
#  All Other: (304, 1606)
#  All Other: (240, 1419)
#  All Other: (286, 1602)
#  All Other: (266, 1094)
#  Right Turn : (0.19, 0.18)
#  Right Turn : (0.17, 0.21)
#  Right Turn : (0.21, 0.19)
#  Right Turn : (0.19, 0.16)
#  Right Turn : (0.14, 0.14)
#  Right Turn : (0.16, 0.17)
#  Right Turn : (0.17, 0.17)
#  Right Turn : (0.18, 0.17)
#  Right Turn : (0.19, 0.17)
#  Right Turn : (0.19, 0.19)
#  Right Turn : (0.19, 0.17)
#  Right Turn : (0.16, 0.16)
#  Right Turn : (0.18, 0.19)
#  Right Turn : (0.17, 0.15)
#  Right Turn : (0.2, 0.2)
#  Right Turn : (0.24, 0.2)
#  Right Turn : (0.22, 0.21)
#  Right Turn : (0.23, 0.2)
#  Right Turn : (0.21, 0.2)
#  Right Turn : (0.21, 0.18)
#  Right Turn : (0.16, 0.17)
#  Right Turn : (0.17, 0.16)
#  Right Turn : (0.18, 0.17)
#  Right Turn : (0.18, 0.17)
#  Right Turn : (0.21, 0.17)
#  Right Turn : (0.21, 0.15)
#  Right Turn : (0.19, 0.17)
#  Right Turn : (0.25, 0.23)
#  Right Turn : (0.24, 0.22)
#  Right Turn : (0.25, 0.23)
#  Right Turn : (0.26, 0.21)
#  Right Turn : (0.21, 0.21)
#  Right Turn : (0.18, 0.2)
#  Right Turn : (0.2, 0.17)
#  Right Turn : (0.16, 0.2)
#  Right Turn : (0.23, 0.19)
#  Right Turn : (0.21, 0.16)
#  Right Turn : (0.22, 0.21)
#  Right Turn : (0.23, 0.22)
#  Right Turn : (0.24, 0.21)
#  Right Turn : (0.23, 0.2)
#  Right Turn : (0.28, 0.23)
#  Right Turn : (0.24, 0.22)
#  Right Turn : (0.23, 0.2)
#  Right Turn : (0.19, 0.18)
#  Right Turn : (0.16, 0.2)
#  Right Turn : (0.21, 0.22)
#  Right Turn : (0.23, 0.2)
#  Right Turn : (0.23, 0.22)
#  Right Turn : (0.18, 0.18)
#  Right Turn : (0.25, 0.19)
#  Right Turn : (0.21, 0.21)
#  Right Turn : (0.19, 0.19)
#  Right Turn : (0.18, 0.19)
#  Right Turn : (0.2, 0.21)
#  Right Turn : (0.25, 0.21)
#  Right Turn : (0.23, 0.2)
#  Right Turn : (0.26, 0.25)
#  Right Turn : (0.28, 0.24)
#  Right Turn : (0.32, 0.27)
#  Right Turn : (0.21, 0.21)
#  Right Turn : (0.2, 0.2)
#  Right Turn : (0.2, 0.2)
#  Right Turn : (0.22, 0.19)
#  Right Turn : (0.2, 0.23)
#  Right Turn : (0.22, 0.22)
#  Right Turn : (0.19, 0.22)
#  Right Turn : (0.19, 0.22)
#  Right Turn : (0.19, 0.2)
#  Right Turn : (0.24, 0.23)
#  Right Turn : (0.17, 0.19)
#  Right Turn : (0.21, 0.2)
#  Right Turn : (0.2, 0.19)
#  Right Turn : (0.19, 0.22)
#  Right Turn : (0.2, 0.21)
#  Right Turn : (0.21, 0.2)
#  Right Turn : (0.23, 0.19)
#  Right Turn : (0.27, 0.2)
#  Right Turn : (0.21, 0.21)
#  Right Turn : (0.17, 0.19)
#  Right Turn : (0.19, 0.16)
#  Right Turn : (0.22, 0.21)
#  Right Turn : (0.24, 0.21)
#  Right Turn : (0.23, 0.22)
#  Right Turn : (0.21, 0.21)
#  Right Turn : (0.22, 0.22)
#  Right Turn : (0.2, 0.21)
#  Right Turn : (0.19, 0.2)
#  Right Turn : (0.2, 0.21)
#  Right Turn : (0.18, 0.2)
#  Right Turn : (0.21, 0.2)
#  Right Turn : (0.18, 0.19)
#  Right Turn : (0.21, 0.2)
#  Right Turn : (0.2, 0.2)
#  Right Turn : (0.2, 0.2)
#  Left Turn : (0.17, 0.18)
#  Left Turn : (0.19, 0.18)
#  Left Turn : (0.21, 0.18)
#  Left Turn : (0.21, 0.18)
#  Left Turn : (0.16, 0.14)
#  Left Turn : (0.19, 0.21)
#  Left Turn : (0.15, 0.17)
#  Left Turn : (0.21, 0.17)
#  Left Turn : (0.2, 0.18)
#  Left Turn : (0.18, 0.18)
#  Left Turn : (0.2, 0.18)
#  Left Turn : (0.16, 0.18)
#  Left Turn : (0.24, 0.21)
#  Left Turn : (0.19, 0.19)
#  Left Turn : (0.22, 0.2)
#  Left Turn : (0.21, 0.19)
#  Left Turn : (0.22, 0.21)
#  Left Turn : (0.21, 0.19)
#  Left Turn : (0.19, 0.19)
#  Left Turn : (0.18, 0.19)
#  Left Turn : (0.18, 0.18)
#  Left Turn : (0.2, 0.18)
#  Left Turn : (0.21, 0.16)
#  Left Turn : (0.22, 0.16)
#  Left Turn : (0.21, 0.17)
#  Left Turn : (0.2, 0.17)
#  Left Turn : (0.19, 0.18)
#  Left Turn : (0.24, 0.21)
#  Left Turn : (0.23, 0.23)
#  Left Turn : (0.24, 0.21)
#  Left Turn : (0.24, 0.23)
#  Left Turn : (0.21, 0.23)
#  Left Turn : (0.21, 0.21)
#  Left Turn : (0.2, 0.19)
#  Left Turn : (0.18, 0.18)
#  Left Turn : (0.15, 0.18)
#  Left Turn : (0.23, 0.17)
#  Left Turn : (0.26, 0.23)
#  Left Turn : (0.21, 0.23)
#  Left Turn : (0.19, 0.21)
#  Left Turn : (0.17, 0.21)
#  Left Turn : (0.25, 0.22)
#  Left Turn : (0.24, 0.21)
#  Left Turn : (0.22, 0.2)
#  Left Turn : (0.16, 0.21)
#  Left Turn : (0.18, 0.19)
#  Left Turn : (0.2, 0.19)
#  Left Turn : (0.23, 0.18)
#  Left Turn : (0.23, 0.24)
#  Left Turn : (0.22, 0.21)
#  Left Turn : (0.26, 0.21)
#  Left Turn : (0.21, 0.23)
#  Left Turn : (0.2, 0.2)
#  Left Turn : (0.2, 0.22)
#  Left Turn : (0.23, 0.23)
#  Left Turn : (0.25, 0.21)
#  Left Turn : (0.17, 0.21)
#  Left Turn : (0.22, 0.24)
#  Left Turn : (0.19, 0.22)
#  Left Turn : (0.28, 0.23)
#  Left Turn : (0.26, 0.24)
#  Left Turn : (0.18, 0.19)
#  Left Turn : (0.18, 0.19)
#  Left Turn : (0.18, 0.19)
#  Left Turn : (0.22, 0.19)
#  Left Turn : (0.2, 0.19)
#  Left Turn : (0.19, 0.18)
#  Left Turn : (0.2, 0.2)
#  Left Turn : (0.16, 0.16)
#  Left Turn : (0.23, 0.2)
#  Left Turn : (0.17, 0.17)
#  Left Turn : (0.21, 0.17)
#  Left Turn : (0.18, 0.2)
#  Left Turn : (0.31, 0.2)
#  Left Turn : (0.22, 0.21)
#  Left Turn : (0.22, 0.21)
#  Left Turn : (0.28, 0.23)
#  Left Turn : (0.22, 0.2)
#  Left Turn : (0.22, 0.22)
#  Left Turn : (0.19, 0.19)
#  Left Turn : (0.19, 0.19)
#  Left Turn : (0.18, 0.18)
#  Left Turn : (0.19, 0.19)
#  Left Turn : (0.21, 0.22)
#  Left Turn : (0.18, 0.19)
#  Left Turn : (0.19, 0.2)
#  Left Turn : (0.2, 0.2)
#  Left Turn : (0.2, 0.21)
#  Left Turn : (0.17, 0.18)
#  Left Turn : (0.19, 0.17)
#  Left Turn : (0.22, 0.2)
#  Left Turn : (0.19, 0.17)
#  Left Turn : (0.2, 0.18)
#  Left Turn : (0.19, 0.18)
#  Left Turn : (0.18, 0.18)
#  Locomotion : (0.44, 0.49)
#  Locomotion : (0.54, 0.43)
#  Locomotion : (0.6, 0.38)
#  Locomotion : (0.5, 0.5)
#  Locomotion : (0.45, 0.28)
#  Locomotion : (0.53, 0.49)
#  Locomotion : (0.38, 0.38)
#  Locomotion : (0.41, 0.28)
#  Locomotion : (0.44, 0.36)
#  Locomotion : (0.43, 0.37)
#  Locomotion : (0.51, 0.37)
#  Locomotion : (0.42, 0.36)
#  Locomotion : (0.49, 0.39)
#  Locomotion : (0.28, 0.28)
#  Locomotion : (0.4, 0.39)
#  Locomotion : (0.45, 0.41)
#  Locomotion : (0.38, 0.35)
#  Locomotion : (0.46, 0.43)
#  Locomotion : (0.46, 0.42)
#  Locomotion : (0.43, 0.4)
#  Locomotion : (0.41, 0.43)
#  Locomotion : (0.36, 0.37)
#  Locomotion : (0.38, 0.31)
#  Locomotion : (0.41, 0.41)
#  Locomotion : (0.4, 0.29)
#  Locomotion : (0.41, 0.27)
#  Locomotion : (0.35, 0.29)
#  Locomotion : (0.47, 0.37)
#  Locomotion : (0.4, 0.39)
#  Locomotion : (0.47, 0.37)
#  Locomotion : (0.47, 0.41)
#  Locomotion : (0.41, 0.39)
#  Locomotion : (0.35, 0.32)
#  Locomotion : (0.33, 0.31)
#  Locomotion : (0.37, 0.3)
#  Locomotion : (0.35, 0.36)
#  Locomotion : (0.4, 0.32)
#  Locomotion : (0.47, 0.39)
#  Locomotion : (0.41, 0.4)
#  Locomotion : (0.44, 0.39)
#  Locomotion : (0.38, 0.41)
#  Locomotion : (0.45, 0.35)
#  Locomotion : (0.44, 0.32)
#  Locomotion : (0.44, 0.3)
#  Locomotion : (0.4, 0.44)
#  Locomotion : (0.39, 0.45)
#  Locomotion : (0.49, 0.43)
#  Locomotion : (0.42, 0.42)
#  Locomotion : (0.54, 0.49)
#  Locomotion : (0.49, 0.5)
#  Locomotion : (0.43, 0.52)
#  Locomotion : (0.43, 0.52)
#  Locomotion : (0.43, 0.47)
#  Locomotion : (0.47, 0.5)
#  Locomotion : (0.56, 0.44)
#  Locomotion : (0.67, 0.49)
#  Locomotion : (0.38, 0.41)
#  Locomotion : (0.49, 0.51)
#  Locomotion : (0.5, 0.52)
#  Locomotion : (0.49, 0.51)
#  Locomotion : (0.35, 0.33)
#  Locomotion : (0.36, 0.33)
#  Locomotion : (0.36, 0.33)
#  Locomotion : (0.39, 0.36)
#  Locomotion : (0.45, 0.42)
#  Locomotion : (0.42, 0.41)
#  Locomotion : (0.47, 0.48)
#  Locomotion : (0.48, 0.45)
#  Locomotion : (0.38, 0.44)
#  Locomotion : (0.57, 0.43)
#  Locomotion : (0.48, 0.5)
#  Locomotion : (0.47, 0.48)
#  Locomotion : (0.54, 0.5)
#  Locomotion : (0.43, 0.39)
#  Locomotion : (0.37, 0.36)
#  Locomotion : (0.4, 0.36)
#  Locomotion : (0.41, 0.43)
#  Locomotion : (0.57, 0.48)
#  Locomotion : (0.49, 0.45)
#  Locomotion : (0.44, 0.51)
#  Locomotion : (0.48, 0.37)
#  Locomotion : (0.35, 0.31)
#  Locomotion : (0.26, 0.27)
#  Locomotion : (0.28, 0.26)
#  Locomotion : (0.32, 0.26)
#  Locomotion : (0.28, 0.32)
#  Locomotion : (0.29, 0.25)
#  Locomotion : (0.33, 0.3)
#  Locomotion : (0.26, 0.27)
#  Locomotion : (0.24, 0.22)
#  Locomotion : (0.27, 0.25)
#  Locomotion : (0.24, 0.21)
#  Locomotion : (0.25, 0.28)
#  Locomotion : (0.28, 0.25)
#  Locomotion : (0.25, 0.32)
#  Face Groom : (0.43, 0.24)
#  Face Groom : (0.2, 0.46)
#  Face Groom : (0.12, 0.21)
#  Face Groom : (0.6, 0.3)
#  Face Groom : (0.17, 0.23)
#  Face Groom : (0.16, 0.27)
#  Face Groom : (0.28, 0.4)
#  Face Groom : (0.34, 0.18)
#  Face Groom : (0.27, 0.28)
#  Face Groom : (0.14, 0.22)
#  Face Groom : (0.24, 0.29)
#  Face Groom : (0.4, 0.22)
#  Face Groom : (0.17, 0.23)
#  Face Groom : (0.32, 0.21)
#  Face Groom : (0.11, 0.21)
#  Face Groom : (0.38, 0.25)
#  Face Groom : (0.25, 0.23)
#  Face Groom : (0.26, 0.26)
#  Face Groom : (0.24, 0.23)
#  Face Groom : (0.12, 0.2)
#  Face Groom : (0.21, 0.2)
#  Face Groom : (0.49, 0.33)
#  Face Groom : (0.17, 0.27)
#  Face Groom : (0.24, 0.24)
#  Face Groom : (0.3, 0.3)
#  Face Groom : (0.15, 0.19)
#  Face Groom : (0.15, 0.2)
#  Face Groom : (0.33, 0.25)
#  Face Groom : (0.18, 0.18)
#  Face Groom : (0.33, 0.25)
#  Face Groom : (0.2, 0.26)
#  Face Groom : (0.18, 0.23)
#  Face Groom : (0.16, 0.32)
#  Face Groom : (0.14, 0.24)
#  Face Groom : (0.19, 0.2)
#  Face Groom : (0.17, 0.22)
#  Face Groom : (0.38, 0.14)
#  Face Groom : (0.44, 0.38)
#  Face Groom : (0.24, 0.25)
#  Face Groom : (0.25, 0.25)
#  Face Groom : (0.22, 0.23)
#  Face Groom : (0.25, 0.34)
#  Face Groom : (0.24, 0.29)
#  Face Groom : (0.32, 0.18)
#  Face Groom : (0.27, 0.21)
#  Face Groom : (0.44, 0.26)
#  Face Groom : (0.47, 0.33)
#  Face Groom : (0.19, 0.57)
#  Face Groom : (0.17, 0.25)
#  Face Groom : (0.2, 0.27)
#  Face Groom : (0.23, 0.21)
#  Face Groom : (0.31, 0.43)
#  Face Groom : (0.15, 0.26)
#  Face Groom : (0.2, 0.35)
#  Face Groom : (0.59, 0.32)
#  Face Groom : (0.33, 0.31)
#  Face Groom : (0.22, 0.23)
#  Face Groom : (0.26, 0.25)
#  Face Groom : (0.27, 0.25)
#  Face Groom : (0.44, 0.39)
#  Face Groom : (0.24, 0.18)
#  Face Groom : (0.21, 0.22)
#  Face Groom : (0.21, 0.22)
#  Face Groom : (0.17, 0.28)
#  Face Groom : (0.23, 0.25)
#  Face Groom : (0.19, 0.22)
#  Face Groom : (0.21, 0.32)
#  Face Groom : (0.17, 0.23)
#  Face Groom : (0.12, 0.27)
#  Face Groom : (0.23, 0.21)
#  Face Groom : (0.22, 0.31)
#  Face Groom : (0.18, 0.38)
#  Face Groom : (0.2, 0.35)
#  Face Groom : (0.21, 0.21)
#  Face Groom : (0.17, 0.3)
#  Face Groom : (0.23, 0.42)
#  Face Groom : (0.22, 0.27)
#  Face Groom : (0.18, 0.23)
#  Face Groom : (0.2, 0.26)
#  Face Groom : (0.18, 0.19)
#  Face Groom : (0.26, 0.21)
#  Face Groom : (0.47, 0.28)
#  Face Groom : (0.18, 0.24)
#  Face Groom : (0.37, 0.37)
#  Face Groom : (0.25, 0.47)
#  Face Groom : (0.36, 0.28)
#  Face Groom : (0.3, 0.34)
#  Face Groom : (0.31, 0.28)
#  Face Groom : (0.31, 0.31)
#  Face Groom : (0.28, 0.33)
#  Face Groom : (0.43, 0.36)
#  Face Groom : (0.2, 0.32)
#  Face Groom : (0.32, 0.31)
#  Face Groom : (0.32, 0.48)
#  Face Groom : (0.28, 0.41)
#  All Other Groom : (0.15, 0.16)
#  All Other Groom : (0.13, 0.24)
#  All Other Groom : (0.1, 0.18)
#  All Other Groom : (0.0, 0.29)
#  All Other Groom : (0.12, 0.16)
#  All Other Groom : (0.15, 0.18)
#  All Other Groom : (0.0, 0.3)
#  All Other Groom : (0.12, 0.19)
#  All Other Groom : (0.15, 0.22)
#  All Other Groom : (0.15, 0.29)
#  All Other Groom : (0.15, 0.18)
#  All Other Groom : (0.15, 0.17)
#  All Other Groom : (0.2, 0.25)
#  All Other Groom : (0.14, 0.2)
#  All Other Groom : (0.1, 0.19)
#  All Other Groom : (0.6, 0.17)
#  All Other Groom : (0.37, 0.24)
#  All Other Groom : (0.1, 0.2)
#  All Other Groom : (0.17, 0.16)
#  All Other Groom : (0.1, 0.1)
#  All Other Groom : (0.3, 0.16)
#  All Other Groom : (0.1, 0.36)
#  All Other Groom : (0.31, 0.24)
#  All Other Groom : (0.13, 0.18)
#  All Other Groom : (0.32, 0.33)
#  All Other Groom : (0.1, 0.1)
#  All Other Groom : (0.0, 0.19)
#  All Other Groom : (0.13, 0.24)
#  All Other Groom : (0.17, 0.13)
#  All Other Groom : (0.13, 0.24)
#  All Other Groom : (0.12, 0.12)
#  All Other Groom : (0.12, 0.33)
#  All Other Groom : (0.16, 0.45)
#  All Other Groom : (0.36, 0.19)
#  All Other Groom : (0.18, 0.18)
#  All Other Groom : (0.0, 0.21)
#  All Other Groom : (0.5, 0.11)
#  All Other Groom : (0.19, 0.16)
#  All Other Groom : (0.12, 0.2)
#  All Other Groom : (0.11, 0.19)
#  All Other Groom : (0.24, 0.16)
#  All Other Groom : (0.1, 0.39)
#  All Other Groom : (0.12, 0.17)
#  All Other Groom : (0.22, 0.17)
#  All Other Groom : (0.1, 0.57)
#  All Other Groom : (0.0, 0.7)
#  All Other Groom : (0.1, 0.13)
#  All Other Groom : (0.17, 0.55)
#  All Other Groom : (0.0, 0.56)
#  All Other Groom : (0.1, 0.52)
#  All Other Groom : (0.27, 1.19)
#  All Other Groom : (0.1, 0.33)
#  All Other Groom : (0.17, 0.39)
#  All Other Groom : (1.22, 0.46)
#  All Other Groom : (0.3, 0.47)
#  All Other Groom : (0.6, 0.77)
#  All Other Groom : (0.24, 0.16)
#  All Other Groom : (0.1, 0.18)
#  All Other Groom : (0.94, 0.92)
#  All Other Groom : (0.1, 0.15)
#  All Other Groom : (0.1, 0.2)
#  All Other Groom : (0.19, 0.24)
#  All Other Groom : (0.19, 0.24)
#  All Other Groom : (0.12, 0.26)
#  All Other Groom : (0.17, 0.29)
#  All Other Groom : (0.16, 0.2)
#  All Other Groom : (0.16, 0.22)
#  All Other Groom : (0.19, 0.22)
#  All Other Groom : (0.22, 0.22)
#  All Other Groom : (0.23, 0.26)
#  All Other Groom : (0.2, 0.32)
#  All Other Groom : (0.57, 0.27)
#  All Other Groom : (0.1, 0.29)
#  All Other Groom : (0.1, 0.38)
#  All Other Groom : (0.1, 0.2)
#  All Other Groom : (0.23, 0.17)
#  All Other Groom : (0.18, 0.2)
#  All Other Groom : (0.15, 0.23)
#  All Other Groom : (0.12, 0.26)
#  All Other Groom : (0.1, 0.23)
#  All Other Groom : (0.25, 0.21)
#  All Other Groom : (0.15, 0.32)
#  All Other Groom : (0.18, 0.22)
#  All Other Groom : (0.17, 0.22)
#  All Other Groom : (0.33, 0.3)
#  All Other Groom : (0.26, 0.21)
#  All Other Groom : (0.15, 0.22)
#  All Other Groom : (0.15, 0.24)
#  All Other Groom : (0.2, 0.2)
#  All Other Groom : (0.2, 0.25)
#  All Other Groom : (0.26, 0.25)
#  All Other Groom : (0.2, 0.24)
#  All Other Groom : (0.19, 0.22)
#  All Other Groom : (0.24, 0.24)
#  All Other Groom : (0.15, 0.19)
#  All Other : (0.64, 0.9)
#  All Other : (0.64, 0.78)
#  All Other : (0.72, 0.92)
#  All Other : (0.55, 0.85)
#  All Other : (0.77, 1.44)
#  All Other : (0.62, 0.8)
#  All Other : (1.04, 1.08)
#  All Other : (0.94, 0.92)
#  All Other : (0.58, 0.76)
#  All Other : (0.69, 0.74)
#  All Other : (0.7, 0.71)
#  All Other : (0.64, 0.91)
#  All Other : (0.66, 0.6)
#  All Other : (1.0, 0.92)
#  All Other : (0.48, 0.52)
#  All Other : (0.55, 0.67)
#  All Other : (0.67, 0.64)
#  All Other : (0.63, 0.66)
#  All Other : (0.56, 0.55)
#  All Other : (0.57, 0.7)
#  All Other : (0.79, 0.94)
#  All Other : (0.59, 1.57)
#  All Other : (0.78, 1.08)
#  All Other : (0.69, 1.66)
#  All Other : (0.81, 0.87)
#  All Other : (1.77, 5.45)
#  All Other : (1.16, 2.88)
#  All Other : (0.73, 0.7)
#  All Other : (0.77, 0.7)
#  All Other : (0.73, 0.7)
#  All Other : (0.66, 0.78)
#  All Other : (1.33, 1.28)
#  All Other : (0.77, 1.71)
#  All Other : (1.55, 2.44)
#  All Other : (2.79, 3.26)
#  All Other : (2.33, 1.88)
#  All Other : (2.54, 4.14)
#  All Other : (0.9, 1.77)
#  All Other : (1.1, 1.51)
#  All Other : (0.72, 1.17)
#  All Other : (1.69, 1.55)
#  All Other : (0.93, 1.1)
#  All Other : (0.98, 1.23)
#  All Other : (0.96, 1.85)
#  All Other : (1.45, 2.0)
#  All Other : (1.26, 1.46)
#  All Other : (0.9, 1.8)
#  All Other : (1.72, 1.48)
#  All Other : (1.41, 1.87)
#  All Other : (1.08, 1.22)
#  All Other : (1.26, 2.71)
#  All Other : (2.08, 1.24)
#  All Other : (1.64, 1.69)
#  All Other : (1.42, 1.21)
#  All Other : (1.25, 1.45)
#  All Other : (1.69, 1.82)
#  All Other : (1.69, 1.55)
#  All Other : (1.31, 1.15)
#  All Other : (0.96, 1.09)
#  All Other : (1.24, 1.46)
#  All Other : (0.92, 1.49)
#  All Other : (0.91, 1.01)
#  All Other : (0.91, 1.01)
#  All Other : (1.01, 1.19)
#  All Other : (1.23, 1.55)
#  All Other : (1.06, 1.56)
#  All Other : (1.42, 1.67)
#  All Other : (1.58, 2.22)
#  All Other : (1.63, 2.04)
#  All Other : (1.65, 2.51)
#  All Other : (3.03, 3.53)
#  All Other : (2.35, 2.78)
#  All Other : (5.3, 2.16)
#  All Other : (1.47, 2.12)
#  All Other : (0.99, 1.0)
#  All Other : (0.93, 1.33)
#  All Other : (1.0, 1.13)
#  All Other : (1.09, 1.6)
#  All Other : (1.2, 1.69)
#  All Other : (1.08, 2.18)
#  All Other : (0.98, 1.33)
#  All Other : (0.99, 0.69)
#  All Other : (0.83, 0.68)
#  All Other : (0.57, 0.65)
#  All Other : (0.64, 0.61)
#  All Other : (0.74, 0.83)
#  All Other : (1.08, 0.71)
#  All Other : (0.83, 0.79)
#  All Other : (1.22, 0.89)
#  All Other : (1.07, 0.79)
#  All Other : (0.56, 0.75)
#  All Other : (0.68, 0.67)
#  All Other : (0.9, 0.88)
#  All Other : (0.65, 0.74)
#  All Other : (0.8, 1.01)

# %%
prepost_boutduration.columns
# Out:
# Index(['Mouse', 'Genotype', 'Date', 'Selected Behavior', 'Session Type',
#        'Session Number', 'Fiber Connection', 'Right Turn Array',
#        'Total Right Turn Bout Count',
#        'Average Duration of Right Turn(seconds)',
#        'Total Right Turn Bouts in Stim Block',
#        'Right Turn Average Duration in Stim Block(seconds)', 'Left Turn Array',
#        'Total Left Turn Bout Count', 'Average Duration of Left Turn(seconds)',
#        'Total Left Turn Bouts in Stim Block',
#        'Left Turn Average Duration in Stim Block(seconds)', 'Locomotion Array',
#        'Total Locomotion Bout Count',
#        'Average Duration of Locomotion(seconds)',
#        'Total Locomotion Bouts in Stim Block',
#        'Locomotion Average Duration in Stim Block(seconds)',
#        'Face Groom Array', 'Total Face Groom Bout Count',
#        'Average Duration of Face Groom(seconds)',
#        'Total Face Groom Bouts in Stim Block',
#        'Face Groom Average Duration in Stim Block(seconds)',
#        'All Other Groom Array', 'Total All Other Groom Bout Count',
#        'Average Duration of All Other Groom(seconds)',
#        'Total All Other Groom Bouts in Stim Block',
#        'All Other Groom Average Duration in Stim Block(seconds)',
#        'All Other Array', 'Total All Other Bout Count',
#        'Average Duration of All Other(seconds)',
#        'Total All Other Bouts in Stim Block',
#        'All Other Average Duration in Stim Block(seconds)',
#        'Right Turn Bouts Pre Stim', 'Right Turn Bouts Post Stim',
#        'Right Turn Average Duration Pre Stim',
#        'Right Turn Average Duration Post Stim', 'Left Turn Bouts Pre Stim',
#        'Left Turn Bouts Post Stim', 'Left Turn Average Duration Pre Stim',
#        'Left Turn Average Duration Post Stim', 'Locomotion Bouts Pre Stim',
#        'Locomotion Bouts Post Stim', 'Locomotion Average Duration Pre Stim',
#        'Locomotion Average Duration Post Stim', 'Face Groom Bouts Pre Stim',
#        'Face Groom Bouts Post Stim', 'Face Groom Average Duration Pre Stim',
#        'Face Groom Average Duration Post Stim',
#        'All Other Groom Bouts Pre Stim', 'All Other Groom Bouts Post Stim',
#        'All Other Groom Average Duration Pre Stim',
#        'All Other Groom Average Duration Post Stim',
#        'All Other Bouts Pre Stim', 'All Other Bouts Post Stim',
#        'All Other Average Duration Pre Stim',
#        'All Other Average Duration Post Stim',
#        'All Other Total Bouts Pre Stim', 'All Other Total Bouts Post Stim',
#        'Right Turn stim-pre bouts', 'Right Turn stim-post bouts',
#        'Left Turn stim-pre bouts', 'Left Turn stim-post bouts',
#        'Locomotion stim-pre bouts', 'Locomotion stim-post bouts',
#        'Face Groom stim-pre bouts', 'Face Groom stim-post bouts',
#        'All Other Groom stim-pre bouts', 'All Other Groom stim-post bouts',
#        'All Other stim-pre bouts', 'All Other stim-post bouts',
#        'Right Turn stim-pre duration', 'Right Turn stim-post duration',
#        'Left Turn stim-pre duration', 'Left Turn stim-post duration',
#        'Locomotion stim-pre duration', 'Locomotion stim-post duration',
#        'Face Groom stim-pre duration', 'Face Groom stim-post duration',
#        'All Other Groom stim-pre duration',
#        'All Other Groom stim-post duration', 'All Other stim-pre duration',
#        'All Other stim-post duration'],
#       dtype='object')

# %%
from datetime import datetime

# Convert date strings to datetime objects
dates_as_datetime = [datetime.strptime(date, '%m%d%y') for date in prepost_boutduration['Date']]

# Sort datetime objects in descending order
sorted_dates = sorted(dates_as_datetime, reverse=True)

# Print the sorted dates
for x in sorted_dates:
    print(x.strftime('%m%d%y'))  # Print in the desired format
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [572], in <cell line: 4>()
#       1 from datetime import datetime
#       3 # Convert date strings to datetime objects
# ----> 4 dates_as_datetime = [datetime.strptime(date, '%m%d%y') for date in prepost_boutduration['Date']]
#       6 # Sort datetime objects in descending order
#       7 sorted_dates = sorted(dates_as_datetime, reverse=True)
#
# Input In [572], in <listcomp>(.0)
#       1 from datetime import datetime
#       3 # Convert date strings to datetime objects
# ----> 4 dates_as_datetime = [datetime.strptime(date, '%m%d%y') for date in prepost_boutduration['Date']]
#       6 # Sort datetime objects in descending order
#       7 sorted_dates = sorted(dates_as_datetime, reverse=True)
#
# TypeError: strptime() argument 1 must be str, not Timestamp

# %%
for x in sorted_dates:
    print(x.strftime('%m%d%y'))  # Print in the desired format
# Out:
# 030724
# 030724
# 030624
# 030624
# 030624
# 030624
# 030524
# 030524
# 030124
# 022824
# 022624
# 022624
# 022324
# 022324
# 022324
# 022224
# 022024
# 022024
# 021924
# 021624
# 021624
# 111723
# 111523
# 111323
# 111323
# 111023
# 110823
# 103023
# 102723
# 102523
# 102523
# 102423
# 100423
# 100423
# 100423
# 100123
# 100123
# 072823
# 072823
# 072723
# 072723
# 072523
# 072523
# 072523
# 072423
# 072423
# 072423
# 072423
# 072123
# 072123
# 072023
# 072023
# 072023
# 071923
# 071823
# 071823
# 071723
# 071723
# 071423
# 071423
# 071323
# 071323
# 071323
# 071223
# 071123
# 071123
# 071123
# 071023
# 071023
# 071023
# 062923
# 062923
# 062923
# 062723
# 062623
# 061523
# 061523
# 061223
# 061223
# 061223
# 060823
# 060823
# 060823
# 060723
# 060723
# 052423
# 052423
# 052223
# 052223
# 051723
# 051223
# 051223
# 051123
# 051123
# 050923

# %%
import pandas as pd

# Assuming '230411' is a date string in the format 'YYMMDD'
date_string = "231104"

# Convert the date string to a pandas Timestamp object
comparison_date = pd.to_datetime(date_string, format="%y%m%d")

# Now you can compare the Timestamp objects
for x in prepost_boutduration['Date']:
    if x >= comparison_date:
        print(x)
# Out:
# 2024-02-16 00:00:00
# 2024-02-20 00:00:00
# 2024-02-23 00:00:00
# 2024-02-23 00:00:00
# 2024-02-26 00:00:00
# 2024-03-06 00:00:00
# 2024-02-23 00:00:00
# 2024-02-26 00:00:00
# 2024-02-28 00:00:00
# 2024-03-06 00:00:00
# 2024-03-05 00:00:00
# 2024-02-19 00:00:00
# 2024-03-05 00:00:00
# 2024-03-07 00:00:00
# 2024-02-16 00:00:00
# 2024-02-20 00:00:00
# 2024-02-22 00:00:00
# 2024-03-01 00:00:00
# 2024-03-06 00:00:00
# 2024-03-07 00:00:00
# 2024-03-06 00:00:00
# 2023-11-08 00:00:00
# 2023-11-10 00:00:00
# 2023-11-13 00:00:00
# 2023-11-15 00:00:00
# 2023-11-13 00:00:00
# 2023-11-17 00:00:00

# %%
# Convert the date strings to datetime objects

t_test_results = {}

group1 = prepost_boutduration.loc[(prepost_boutduration['Genotype'] == 'D1') &
                                  (prepost_boutduration['Date'] >= comparison_date)&
                                  (prepost_boutduration['Session Type'] == "Sham Session"), 
                                  [col for col in prepost_boutduration.columns if 'Bouts in Stim Block' in col]]
group2 = prepost_boutduration.loc[(prepost_boutduration['Genotype'] == 'D1') & 
                                  (prepost_boutduration['Date'] >= comparison_date)&
                                  (prepost_boutduration['Session Type'] == "Stim Session"),
                                  [col for col in prepost_boutduration.columns if 'Bouts in Stim Block' in col]]

for col in group1.columns:
    # Extract the data for the current column
    data_group1 = group1[col]
    data_group2 = group2[col]

    # Convert data_group1 and data_group2 to numeric types
    data_group1 = pd.to_numeric(data_group1, errors='coerce')
    data_group2 = pd.to_numeric(data_group2, errors='coerce')

    # Perform the t-test
    t_statistic, p_value = stats.ttest_ind(data_group1.dropna(), data_group2.dropna())

    # Store the results in the dictionary
    t_test_results[col] = {'t_statistic': t_statistic, 'p_value': p_value}

# Print the results
for col, result in t_test_results.items():
    print(f"Column: {col}")
    print(f"T-statistic: {result['t_statistic']}")
    print(f"P-value: {result['p_value']}")
    print()
    
# Create a list to hold the table data
table_data = []
for col, result in t_test_results.items():
    table_data.append([col, result['t_statistic'], result['p_value']])
Title='D1 Sham vs Stim Bouts During Stim Period (All Selected Actions) Post 110423'
print(Title)
print()
# Print the table
print(tabulate(table_data, headers=["Column", "T-statistic", "P-value"], tablefmt="pretty"))
# Out:
# Column: Total Right Turn Bouts in Stim Block
# T-statistic: nan
# P-value: nan
#
# Column: Total Left Turn Bouts in Stim Block
# T-statistic: nan
# P-value: nan
#
# Column: Total Locomotion Bouts in Stim Block
# T-statistic: nan
# P-value: nan
#
# Column: Total Face Groom Bouts in Stim Block
# T-statistic: nan
# P-value: nan
#
# Column: Total All Other Groom Bouts in Stim Block
# T-statistic: nan
# P-value: nan
#
# Column: Total All Other Bouts in Stim Block
# T-statistic: nan
# P-value: nan
#
# D1 Sham vs Stim Bouts During Stim Period (All Selected Actions) Post 110423
#
# +-------------------------------------------+-------------+---------+
# |                  Column                   | T-statistic | P-value |
# +-------------------------------------------+-------------+---------+
# |   Total Right Turn Bouts in Stim Block    |     nan     |   nan   |
# |    Total Left Turn Bouts in Stim Block    |     nan     |   nan   |
# |   Total Locomotion Bouts in Stim Block    |     nan     |   nan   |
# |   Total Face Groom Bouts in Stim Block    |     nan     |   nan   |
# | Total All Other Groom Bouts in Stim Block |     nan     |   nan   |
# |    Total All Other Bouts in Stim Block    |     nan     |   nan   |
# +-------------------------------------------+-------------+---------+

# %%
# Filter data for group D1 and Sham == "y"
group1 = prepost_boutduration.loc[(prepost_boutduration['Genotype'] == 'D1') & (prepost_boutduration['Selected Behavior'] == "Face Groom") &
                                  (prepost_boutduration['Session Type'] == "Sham Session"),
                                  [col for col in prepost_boutduration.columns if 'Bouts in Stim Block' in col]]

# Filter data for group D2 and Sham == "y"
group2 = prepost_boutduration.loc[(prepost_boutduration['Genotype'] == 'D1') & (prepost_boutduration['Selected Behavior'] == "Face Groom") &
                                  (prepost_boutduration['Session Type'] == "Stim Session"),
                                  [col for col in prepost_boutduration.columns if 'Bouts in Stim Block' in col]]
#print(f'Group 1: {group1.columns}')
#print(f'Group 2: {group2.columns}')
#print(len(group2.columns))
# Initialize an empty dictionary to store t-test results
t_test_results = {}

# Determine the minimum number of columns to iterate through
num_columns = min(len(group1.columns), len(group2.columns))

# Iterate through each column index up to the minimum
for col_index in range(num_columns):
    # Extract the data for the current column index in group1
    data_group1 = pd.to_numeric(group1.iloc[:, col_index], errors='coerce')

    # Extract the data for the corresponding column index in group2
    data_group2 = pd.to_numeric(group2.iloc[:, col_index], errors='coerce')

    # Perform the t-test
    t_statistic, p_value = stats.ttest_ind(data_group1.dropna(), data_group2.dropna())

    # Store the results in the dictionary
    col_name = group1.columns[col_index]
    t_test_results[col_name] = {'t_statistic': t_statistic, 'p_value': p_value}

# Print the results
for col, result in t_test_results.items():
    print(f"Column: {col}")
    print(f"T-statistic: {result['t_statistic']}")
    print(f"P-value: {result['p_value']}")
    print()
    
table_data = [["Column", "T-statistic", "P-value"]]
Title= "Independent T-Test: D1 vs D2  Bouts During Stim Period (Face Groom)"
for col, result in t_test_results.items():
    # Split column name to remove 'in' if it exists
    col_name = col.split('in')[0].strip()
    table_data.append([col_name, result['t_statistic'], result['p_value']])
    
print(Title)
print()

# Print the table
print(tabulate(table_data, headers="firstrow"))
# Out:
# 6
# Column: Total Right Turn Bouts in Stim Block
# T-statistic: nan
# P-value: nan
#
# Column: Total Left Turn Bouts in Stim Block
# T-statistic: nan
# P-value: nan
#
# Column: Total Locomotion Bouts in Stim Block
# T-statistic: nan
# P-value: nan
#
# Column: Total Face Groom Bouts in Stim Block
# T-statistic: nan
# P-value: nan
#
# Column: Total All Other Groom Bouts in Stim Block
# T-statistic: nan
# P-value: nan
#
# Column: Total All Other Bouts in Stim Block
# T-statistic: nan
# P-value: nan
#
# Independent T-Test: D1 vs D2  Bouts During Stim Period (Face Groom)
#
# Column                         T-statistic    P-value
# ---------------------------  -------------  ---------
# Total Right Turn Bouts                 nan        nan
# Total Left Turn Bouts                  nan        nan
# Total Locomotion Bouts                 nan        nan
# Total Face Groom Bouts                 nan        nan
# Total All Other Groom Bouts            nan        nan
# Total All Other Bouts                  nan        nan

# %%
# Find all columns dynamically
before_columns = [col for col in prepost_boutduration.columns if 'Average Duration in Stim Block' in col]
after_columns = [col for col in prepost_boutduration.columns if 'Average Duration Post Stim' in col]

# Initialize an empty list to store the results
results = []

# Iterate over each pair of columns and perform the t-test
for before_column, after_column in zip(before_columns, after_columns):
    # Extract the data associated with the columns
    before_data = prepost_boutduration.loc[(prepost_boutduration['Genotype'] == 'D1') & 
                                            (prepost_boutduration['Session Type'] == "Stim Session")&
                                           (prepost_boutduration['Selected Behavior'] == "Locomotion")&
                                           (prepost_boutduration['Date'] >= comparison_date),
                                            before_column].values

    after_data = prepost_boutduration.loc[(prepost_boutduration['Genotype'] == 'D1') &
                                           (prepost_boutduration['Session Type'] == "Stim Session")&
                                          (prepost_boutduration['Selected Behavior'] == "Locomotion")&
                                          (prepost_boutduration['Date'] >= comparison_date),
                                           after_column].values

    # Perform paired t-test
    t_statistic, p_value = stats.ttest_rel(before_data, after_data)

    # Append results to the list
    results.append([before_column, t_statistic, p_value])

# Print results as a table
headers = ["Before Column", "t-statistic", "p-value"]
title="D1 Stim vs Post Bouts (Sham Session)"
print(title)
print()
print(tabulate(results, headers=headers, floatfmt=".3f", tablefmt="pretty"))
# Out:
# D1 Stim vs Post Bouts (Sham Session)
#
# +---------------------------------------------------------+----------------------+-----------------------+
# |                      Before Column                      |     t-statistic      |        p-value        |
# +---------------------------------------------------------+----------------------+-----------------------+
# |   Right Turn Average Duration in Stim Block(seconds)    |         0.0          |          1.0          |
# |    Left Turn Average Duration in Stim Block(seconds)    |  -720575940379279.0  | 8.834874115176439e-16 |
# |   Locomotion Average Duration in Stim Block(seconds)    | -0.5000000000000002  |  0.7048327646991335   |
# |   Face Groom Average Duration in Stim Block(seconds)    |  0.5652173913043477  |  0.6724901221861586   |
# | All Other Groom Average Duration in Stim Block(seconds) | -0.33333333333333365 |  0.7951672353008663   |
# |    All Other Average Duration in Stim Block(seconds)    |         1.0          |  0.49999999999999956  |
# +---------------------------------------------------------+----------------------+-----------------------+
# /Users/kaycei/anaconda3/envs/closed-loop/lib/python3.10/site-packages/scipy/stats/_axis_nan_policy.py:531: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
headers = ["Before Column", "After Column", "t-statistic", "p-value"]
print(tabulate(results, headers=headers, floatfmt=".3f", tablefmt="pretty"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [492], in <cell line: 2>()
#       1 headers = ["Before Column", "After Column", "t-statistic", "p-value"]
# ----> 2 print(tabulate(results, headers=headers, floatfmt=".3f", tablefmt="pretty"))
#
# NameError: name 'results' is not defined

# %% [raw]
# for _ in range(12):
#     prepost_boutduration.pop(prepost_boutduration.columns[-1])

# %% [markdown]
# print(prepost_boutduration.loc[3,'Right Turn Average Duration in Stim Block(seconds)'])
# print(prepost_boutduration.loc[3,'Right Turn Average Duration Pre Stim'])
# print(prepost_boutduration.loc[3,'Right Turn stim-pre duration'])

# %% [markdown]
# ## Total Pre, Stim, Post of All Behaviors

# %% [markdown]
# ### Step 1: Bout

# %% [raw]
# bout_prestimpost={}
#
# count_pre=0
# count_stim=0
# count_post=0
#
# for col in current_match.columns:
#     if "Array" in col:
#         bout_col = col.split("Array")[0].strip()
#         for row in current_match[col]:
#             for tup in row:
#                 if 0<=tup[5] and tup[6]<= 3000:
#                     count_pre+=1
#                 if tup[5]>=3001 and tup[6]<=21000:
#                     count_stim+=1
#                 if tup[5]>=21001 and tup[6]<=39001:
#                     count_post+=1
#         bout_prestimpost[bout_col]=(count_pre, count_stim,count_post)

# %% [markdown]
# ### Step 2

# %% [raw]
# for key,value in bout_prestimpost.items():
#     new_value=tuple(int(x/len(current_match))for x in value)
#     bout_prestimpost[key]=new_value

# %% [raw]
# print(bout_prestimpost)

# %% [markdown]
# ### Step 3

# %% [raw]
# # Simulating the condition for selecting a behavior
# selected_behavior = current_match['Selected Behavior'].iloc[0]
# print(selected_behavior)
# selected_genotype = current_match['Genotype'].iloc[0]
#
# # Reorder the rows such that the row matching the condition is the first row
#
# if selected_behavior in duration_pre_stim_post.index:
#     durationdf = duration_pre_stim_post.reindex([selected_behavior] + [idx for idx in duration_pre_stim_post.index if idx != selected_behavior])
#
#
# # Plotting
# fig, ax = plt.subplots(figsize=(10, 6))
# boutdf.plot(kind='bar', ax=ax, width=0.5, color=['#d0e1f9', '#283655', '#1e1f26'])  # Adjust width and colors here
#
# ax.set_ylabel('Counts')
# if selected_behavior== 'Right Turn':
#     print ('True')
#     ax.set_title(f"{selected_genotype} {selected_behavior} {current_match['Fiber Connection'].iloc[0]} Bout Count ({current_match['Session Type'].iloc[0]})")
# else:
#     ax.set_title(f"{selected_genotype} {selected_behavior} Bout Count ({current_match['Session Type'].iloc[0]})")
# ax.set_xticklabels(boutdf.index, rotation=45, ha='right')
# plt.legend(title='Period', loc='upper left')
# plt.tight_layout()
# # Set the current figure as the active figure
# plt.gcf()
#
# # Specify the folder path
# folder_path = '/Users/kaycei/K on Server (NoMachine)/KayCei/Naturalistic Closed Loop/Overall Data'
#
# # Save the plot as a PNG image with increased DPI
# title_str = ax.get_title()
# filename = ''.join(e for e in title_str if e.isalnum())  # Remove special characters and spaces
# plt.savefig(os.path.join(folder_path, f'{filename}.png'), dpi=300)  # Save as PNG file with increased DPI in the specif
#
# plt.show()

# %% [markdown]
# ## Step 1: Duration

# %%
duration_pre_stim_post={}

count_pre=[]
count_stim=[]
count_post=[]
pre_rowdur=[]
stim_rowdur=[]
post_rowdur=[]

for col in current_match.columns:
    if "Array" in col:
        dur_col = col.split("Array")[0].strip()
        for row in current_match[col]:
            for tup in row:
                if 0<=tup[5] and tup[6]<= 3000:
                    count_pre.append(tup[4])
                if tup[5]>=3001 and tup[6]<=21000:
                    count_stim.append(tup[4])
                if tup[5]>=21001 and tup[6]<=39001:
                    count_post.append(tup[4])
                    
            #After each row add up the sum of the values 
            pre_dur=sum(count_pre)
            stim_dur=sum(count_stim)
            post_dur=sum(count_post)
            
            #Append row totals to the row list 
            pre_rowdur.append(pre_dur)
            stim_rowdur.append(stim_dur)
            post_rowdur.append(post_dur)
            
            #Clear row values
            count_pre.clear()
            count_stim.clear()
            count_post.clear()
            
        #average the values of all the rows of pre stim post and make the values seconds 
        x= int(statistics.mean(pre_rowdur)/10)
        y= int(statistics.mean(stim_rowdur)/10)
        z= int(statistics.mean(post_rowdur)/10)
           
        #append to the suration dictionary Key(Behavior): Value (pre, stim, post total)
        duration_pre_stim_post[dur_col]=(x, y,z)
           
        #clear the columns averages for next column 
        pre_rowdur.clear()
        stim_rowdur.clear()
        post_rowdur.clear()

# %%
index_labels=['Pre','Stim','Post']
totalduration=pd.DataFrame(duration_pre_stim_post,index_labels)
totalduration

# %% [markdown]
# ### Duration Plot of Average Pre Post Stim During Selected Action

# %%
# Simulating the condition for selecting a behavior
selected_behavior = current_match['Selected Behavior'].iloc[0]
print(selected_behavior)
selected_genotype = current_match['Genotype'].iloc[0]

# Reorder the rows such that the row matching the condition is the first row
if selected_behavior in totalduration.columns:
    selected_col=totalduration.pop(selected_behavior)
    totalduration.insert(0,selected_behavior,selected_col)

# Transpose the DataFrame to have columns as x values
totalduration_transposed = totalduration.transpose()

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the transposed DataFrame
totalduration_transposed.plot(kind='bar', ax=ax, width=0.5,color=['#d0e1f9', '#283655', '#1e1f26'])

ax.set_ylabel('Time (s)')

# Set the title based on selected_behavior
if selected_behavior == 'Right Turn':
    ax.set_title(f"{selected_genotype} {selected_behavior} {current_match['Fiber Connection'].iloc[0]} Average Duration ({current_match['Session Type'].iloc[0]})")
else:
    ax.set_title(f"{selected_genotype} {selected_behavior} Average Duration ({current_match['Session Type'].iloc[0]})")

# Set the x-axis label
ax.set_xlabel('Behavior')

plt.legend(title='Period', loc='upper left')

plt.tight_layout()

# Set the current figure as the active figure
plt.gcf()

# Specify the folder path
folder_path = 'K:/KayCei/Naturalistic Closed Loop/Totals/Duration Plots'

# Save the plot as a PNG image with increased DPI
title_str = ax.get_title()
filename = ''.join(e for e in title_str if e.isalnum())  # Remove special characters and spaces
plt.savefig(os.path.join(folder_path, f'{filename}.png'), dpi=300)  # Save as PNG file with increased DPI in the specif


plt.show()

# %%
plt.close()

# %%
# Check if sham_stim_duration is already initialized
if 'sham_stim_duration' not in locals():
    sham_stim_duration = []

# Define the new tuple
new_tuple = (title_str, totalduration_transposed)

# Check if the first element of the new tuple already exists in sham_stim_duration
existing_titles = [tup[0] for tup in sham_stim_duration]
if title_str not in existing_titles:
    sham_stim_duration.append(new_tuple)

# %%
d2stimsham={}
d1stimsham={}

for tup in sham_stim_duration:
    if "D1" in tup[0]:
        d1stimsham[tup[0]]=tup[1]
    else:
        if "D2" in tup[0]:
            d2stimsham[tup[0]]=tup[1]

# %%
# Define a function to extract "sham" DataFrame from a given dictionary
def extract_sham_data(data_dict):
    sham_title, sham_df = None, None
    for key, value in data_dict.items():
        if "Sham Session" in key:
            sham_title, sham_df = key, value
            data_dict.pop(key)
            break
    return sham_title, sham_df

# Extract "sham" DataFrame from d1stimsham
sham_title_d1, sham_df_d1 = extract_sham_data(d1stimsham)
if sham_df_d1 is None:
    print("No 'sham' data found in d1stimsham.")
else:
    print(f"Extracted 'sham' data from d1stimsham with title '{sham_title_d1}'.")

# Extract "sham" DataFrame from d2stimsham
sham_title_d2, sham_df_d2 = extract_sham_data(d2stimsham)
if sham_df_d2 is None:
    print("No 'sham' data found in d2stimsham.")
else:
    print(f"Extracted 'sham' data from d2stimsham with title '{sham_title_d2}'.")

# Iterate over each DataFrame in d1stimsham and compare it to the transposed "sham" DataFrame
for title, df in d1stimsham.items():
    if df is sham_df_d1:
        continue  # Skip if the DataFrame is the "sham" DataFrame
    
    # Plot the transposed DataFrames
    fig, ax = plt.subplots(figsize=(10, 6))
    
    df.plot(kind='bar', ax=ax, width=0.5, color=['#d0e1f9', '#283655', '#1e1f26'])
    sham_df_d1.plot(kind='bar', ax=ax, width=0.5, color=['#FF5733', '#FF5733', '#FF5733'], alpha=0.7)

    ax.set_ylabel('Time (s)')
    ax.set_xlabel('Behavior')
    ax.set_title(f"Comparison of {title} vs Sham (d1stimsham)")
    
    plt.legend(["Pre", 'Stim', 'Post', 'Sham'], title='Period', loc='upper left')
    
    plt.tight_layout()
    
    plt.show()

# Iterate over each DataFrame in d2stimsham and compare it to the transposed "sham" DataFrame
for title, df in d2stimsham.items():
    if df is sham_df_d2:
        continue  # Skip if the DataFrame is the "sham" DataFrame
    
    # Plot the transposed DataFrames
    fig, ax = plt.subplots(figsize=(10, 6))
    
    df.plot(kind='bar', ax=ax, width=0.5, color=['#d0e1f9', '#283655', '#1e1f26'])
    sham_df_d2.plot(kind='bar', ax=ax, width=0.5, color=['#FF5733', '#FF5733', '#FF5733'], alpha=0.7)

    ax.set_ylabel('Time (s)')
    ax.set_xlabel('Behavior')
    ax.set_title(f"Comparison of {title} vs Sham (d2stimsham)")
    
    plt.legend(["Pre", 'Stim', 'Post', 'Sham'], title='Period', loc='upper left')
    
    plt.tight_layout()
    
    plt.show()

# %%
# Extract the "sham" DataFrame
sham_title, sham_df = None, None
for key, value in d2stimsham.items():
    if "Sham Session" in key:
        sham_title, sham_df = key, value
        d2stimsham.pop(key)
        break

if sham_df is None:
    print("No 'sham' data found.")
else:
    print(f"Extracted 'sham' data with title '{sham_title}'.")

# Iterate over each DataFrame and compare it to the transposed "sham" DataFrame
for title, df in d2stimsham.items():
    if df is sham_df:
        continue  # Skip if the DataFrame is the "sham" DataFrame
    
    # Plot the transposed DataFrames
    fig, ax = plt.subplots(figsize=(10, 6))
    
    df.plot(kind='bar', ax=ax, width=0.5, color=['#d0e1f9', '#283655', '#1e1f26'])
    sham_df.plot(kind='bar', ax=ax, width=0.5, color=['#FF5733', '#FF5733', '#FF5733'], alpha=0.7)

    ax.set_ylabel('Time (s)')
    ax.set_xlabel('Behavior')
    ax.set_title(f"Comparison of {title} vs Sham")
    
    plt.legend(["Pre", 'Stim', 'Post', 'Sham'], title='Period', loc='upper left')
    
    plt.tight_layout()
    
    plt.show()

# %%
current_match.columns

# %%
# Step 1: Statistical Methods
# Calculate summary statistics
for col in current_match.columns:
    if "Average Duration in Stim Block(seconds)" in col:
        col_name=col
        duration_data = current_match[col]
        summary_stats = duration_data.describe()

        # Calculate IQR (Interquartile Range)
        Q1 = duration_data.quantile(0.25)
        Q3 = duration_data.quantile(0.75)
        IQR = Q3 - Q1

        # Identify outliers using IQR method
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        outliers = duration_data[(duration_data < lower_bound) | (duration_data > upper_bound)]

        # Step 2: Visualization Techniques
        # Create a box plot to visualize the distribution and identify outliers
        plt.figure(figsize=(8, 6))
        plt.boxplot(duration_data, vert=False)
        plt.title(f'Box Plot of {col_name}')
        plt.xlabel(col_name)
        plt.grid(True)
        plt.show()

        # Create a histogram to visualize the frequency distribution
        plt.figure(figsize=(8, 6))
        plt.hist(duration_data, bins=20, color='skyblue', edgecolor='black')
        plt.title(f'Histogram of {col_name}')
        plt.xlabel(col_name)
        plt.ylabel('Frequency')
        plt.grid(True)
        plt.show()

        # Print summary statistics and outliers
        print("Summary Statistics:")
        print(summary_stats)
        print("\nOutliers:")
        print(outliers)

# %% [markdown]
# ## Stim vs Sham (Repeated ANOVA)

# %%
while True:
    finalize_match = input("\nDo you want to finalize matching data? (yes/no): ")
    if finalize_match.lower() == 'yes':
        break  # Exit the loop if the user chooses to finalize matching data
    
    for iteration, (filtering_criteria, columns, current_match) in iteration_list.items():
        print(iteration, filtering_criteria)

    # Prompt the user to select an iteration to go back to
    selected_iteration = input("\nEnter the iteration number to go back to, or 'exit' to exit: ")
    if selected_iteration.lower() == 'exit':
        break  # Exit the loop if the user chooses to exit
    else:
        try:
            selected_iteration = int(selected_iteration)
            if selected_iteration in iteration_list:
                df=iteration_list[selected_iteration][2]
                current_match = iteration_list[selected_iteration][2]
                iteration_list = {k: v for k, v in iteration_list.items() if k <= selected_iteration}
                print('Run cell above as current match')
                break
        except ValueError:
            print("Invalid input. Please enter a valid iteration number or 'exit' to exit.")

# %%
if finalize_match!='yes':
    # Define a list to store all selections and filtering criteria
    #iteration_list={}
    # Display available columns in groups of 3 with aligned numbering
    num_columns = 3
    columns = df.columns.tolist()
    num_options = len(columns)

    # Calculate the width of each column
    column_width = 32

    # Define the number of spaces for tab spacing
    tab_space = 1

    # Set the number of rows for displaying column options
    num_rows = 13

    while columns:  # Continue filtering until all headers are filtered
        for i in range(num_rows):
            for j in range(i, len(columns), num_rows):
                col_num = j + 1
                col_name = columns[j]
                # Adjust font size for smaller font
                if len(col_name) > column_width:
                    print(f"\033[1;33m{col_num:<2}.\033[1;32m{col_name[:column_width]:<{column_width}}\033[0m", end=" " * tab_space)  # Yellow color for smaller font size
                else:
                    print(f"\033[1;33m{col_num:<2}.{col_name:<{column_width}}\033[0m", end=" " * tab_space)
            print()

        if len(iteration_list)!=1:
            df=current_match
        else:
            pass
        filtering_criteria = []
        # Prompt user to enter the number corresponding to the header
        selected_option = None
        while selected_option is None:
            user_input = input("Enter the number corresponding to the header or '0' to cancel filtering: ")
            try:
                selected_option = int(user_input)
                if selected_option == 0:
                    print("Cell execution stopped.")
                    sys.exit()  # Exit just the current cell
                elif selected_option > len(columns):
                    raise ValueError
            except ValueError:
                print(f"Invalid input. Please enter a number between 1 and {len(columns)} or '0' to cancel filtering.")
                selected_option = None

        print((columns[selected_option-1]))
        selected_header = columns[selected_option - 1]

        # Append the selected header to filtering_criteria
        filtering_criteria.append(f"Selected Header: {selected_header}")

        # Remove the selected header from the list of available columns

        if selected_header in df.columns and all(isinstance(value, str) for value in df[selected_header]):
            avaliable_value=df[selected_header].unique()
            print(avaliable_value)
            filter_value = input(f"Enter the value to filter by {selected_header}: ")
            # Append the filter value to filtering_criteria
            filtering_criteria.append(f"Filter Value: {filter_value}")

        elif 'Array' in selected_header:
            available_elements = {
                0:"Behavior",
                1:"Stim Count",
                2: "Frames", 
                3: "Bout", 
                4: "Duration",
                5: "Start Time",
                6: "End Time",
            }
            print("Available elements:")
            for key, value in available_elements.items():
                print(f"{key}: {value}")

            # Prompt user to select elements
            element_positions_input = input(f"Enter the elements you want to filter by {selected_header} (comma-separated): ")
            print("Selected positions:", selected_positions)  # Add this line for debugging
            if ',' in element_positions_input:
                selected_positions = [int(pos.strip()) for pos in element_positions_input.split(',')]
                # Check if input is valid
                if all(pos in available_elements for pos in selected_positions):
                    combined_filters = []
                    for pos in selected_positions:
                        range_or_exact = input(f"Do you want an exact value or a range of values for {available_elements[pos]}?: ")
                        if range_or_exact.lower() == 'exact':
                            filter_value = input(f"Enter the exact value for {available_elements[pos]}: ")
                            # Add condition to the combined filter
                            combined_filters.append(df[selected_header].apply(lambda row: any((x[pos] == filter_value for x in tup)for tup in row)))
                            filtering_criteria.append(f"Element to filter: {available_elements.get(pos)}")
                            filtering_criteria.append(f"Exact Value for {available_elements[pos]}: {filter_value}")
                        elif range_or_exact.lower() == 'range':
                            range_value = input(f"Enter the range for {available_elements[pos]} (min,max): ")
                            min_val, max_val = map(float, range_value.split(','))
                            # Add condition to the combined filter
                            combined_filters.append(df[selected_header].apply(lambda row: any((min_val <= x[pos]<= max_val for x in tup)for tup in row)))
                            filtering_criteria.append(f"Element to filter: {available_elements.get(pos)}")
                            filtering_criteria.append(f"Range for {available_elements[pos]}: {min_val} to {max_val}")
                        else:
                            print("Invalid input. Please enter 'exact' or 'range'.")
                    # Apply combined filter
                    array_df = df[reduce(lambda x, y: x & y, combined_filters)]
                else:
                    print("Value is not an elemental position")
            else:
                selected_positions = int(element_positions_input)
                print(selected_positions)
                if selected_positions in available_elements:
                    range_or_exact = input(f"Do you want an exact value or a range of values for {available_elements[selected_positions]}?: ")
                    if range_or_exact.lower() == 'exact':
                        filter_value= input(f"Enter the exact value for {available_elements[selected_positions]}: ")
                        filtering_criteria.append(f"Element to filter: {available_elements.get(selected_positions)}")
                        filtering_criteria.append(f"Exact Value for {available_elements.get(selected_positions)}: {filter_value}")
                        array_df = df[df[selected_header].apply(lambda row: any((x[selected_positions] == filter_value for x in tup) for tup in row))]
                    elif range_or_exact== 'range':
                        range_value = input(f"Enter the range for {available_elements[selected_positions]} (min,max): ")
                        min_val, max_val = map(float, range_value.split(','))
                        filtering_criteria.append(f"Element to filter: {available_elements.get(selected_positions)}")
                        filtering_criteria.append(f"Range for {available_elements.get(pos)}: {min_val} to {max_val}")
                        array_df=df[df[selected_header].apply(lambda y: any((min_val <= x[selected_positions] <= max_val for x in tup)for tup in y))]
                else:
                    print('An element position was not selected')

        if 'Array'not in selected_header:
            columns.remove(selected_header)

        if len(iteration_list)==1:
            if "Array" not in selected_header:                                          
                current_match=df[df[selected_header] == filter_value]
                iteration+=1
                iteration_list[iteration]=(filtering_criteria.copy(), columns.copy(), current_match)
            elif "Selected Behavior" or 'Fiber Connection' in selected_header:
                current_match = df[(df[selected_header] == filter_value) | (df[selected_header] == "No Error Value")]
                iteration += 1
                iteration_list[iteration] = (filtering_criteria.copy(), columns.copy(), current_match)
            else:
                current_match=array_df
                iteration+=1
                iteration_list[iteration]=(filtering_criteria.copy(), columns.copy(), current_match)                                       
        else:
            previous_match=current_match
            if'Array' in selected_header:
                current_match=array_df
                iteration+=1
                iteration_list[iteration]=(filtering_criteria.copy(), columns.copy(), current_match) 
            elif "Selected Behavior" or 'Fiber Connection' in selected_header:
                current_match = df[(df[selected_header] == filter_value) | (df[selected_header] == "No Error Value")]
                iteration += 1
                iteration_list[iteration] = (filtering_criteria.copy(), columns.copy(), current_match)
            else:
                current_match=df[df[selected_header]==filter_value]
                iteration+=1
                iteration_list[iteration]=(filtering_criteria.copy(), columns.copy(), current_match)                                       

        # Extracting the headers in the original order from the DataFrame
        original_headers = current_match.columns.tolist()
else:
    pass

# %%
anovadf=current_match.copy()

# %%
count_pre = []
count_stim = []
count_post = []
num_array_columns = sum("Array" in col for col in anovadf.columns)
current_iteration = 0

for col in anovadf.columns:
    if "Array" in col:
        current_iteration += 1
        bout_col_1 = col.split("Array")[0].strip()
        bout_col = '_'.join(bout_col_1.split())
        print(bout_col)
        for row in anovadf[col]:
            pre_count=0
            stim_count=0
            post_count=0
            for tup in row:
                if 0<=tup[5] and tup[6]<= 3000:
                    pre_count+=1
                if tup[5]>=3001 and tup[6]<=21000:
                    stim_count+=1
                if tup[5]>=21001 and tup[6]<=39001:
                    post_count+=1
            count_pre.append(pre_count)
            count_stim.append(stim_count)
            count_post.append(post_count)

        # Add new columns to anovadf before moving to the next array column
        anovadf[f'{bout_col}_Pre_Bout'] = count_pre
        anovadf[f'{bout_col}_Stim_Bout_Count'] = count_stim
        anovadf[f'{bout_col}_Post_Bout'] = count_post

        
        # Clear the count lists if it's not the last iteration
        if current_iteration != num_array_columns:
            count_pre.clear()
            count_stim.clear()
            count_post.clear()

# Add remaining counts to the DataFrame if needed
anovadf[f'{bout_col}_Pre_Bout'] = count_pre
anovadf[f'{bout_col}_Stim_Bout_Count'] = count_stim
anovadf[f'{bout_col}_Post_Bout'] = count_post

# %%
print(anovadf.columns)

# %%
anovadf.rename(columns={'Session Type': 'Session_Type'}, inplace=True)

# %%
anovadf

# %%
len(anovadf[anovadf['Session_Type'] == 'Stim Session'])

# %%
# Filter columns with '_Stim_Bout_Count' in header
filtered_columns = [col for col in anovadf.columns if '_Stim_Bout_Count' in col]

# Filter columns with 'Bouts in Stim Block' in header
filtered_columns_1 = [col for col in anovadf.columns if 'Bouts in Stim Block' in col]

# List to store column pairs with matching values
matching_columns = []

# Iterate over columns pairwise
for col1 in filtered_columns:
    for col2 in filtered_columns_1:
        # Check if values in columns col1 and col2 match at the same index
        if (anovadf[col1] == anovadf[col2]).all():
            matching_columns.append((col1, col2))

print("Columns with matching values at the same index:")
for pair in matching_columns:
    print(pair)

# %%
import statsmodels.api as sm
from statsmodels.multivariate.manova import MANOVA

# %%
# Define the dependent variables
dependent_vars = ['Right_Turn_Pre_Bout', 'Right_Turn_Stim_Bout_Count',
       'Right_Turn_Post_Bout', 'Left_Turn_Pre_Bout',
       'Left_Turn_Stim_Bout_Count', 'Left_Turn_Post_Bout',
       'Locomotion_Pre_Bout', 'Locomotion_Stim_Bout_Count',
       'Locomotion_Post_Bout', 'Face_Groom_Pre_Bout',
       'Face_Groom_Stim_Bout_Count', 'Face_Groom_Post_Bout',
       'All_Other_Groom_Pre_Bout', 'All_Other_Groom_Stim_Bout_Count',
       'All_Other_Groom_Post_Bout', 'All_Other_Pre_Bout',
       'All_Other_Stim_Bout_Count', 'All_Other_Post_Bout']

# Create a copy of the original dataframe
filtered_data = anovadf.copy()

# Filter out zero values for each dependent variable separately
for var in dependent_vars:
    filtered_data = filtered_data[filtered_data[var] != 0]

# Perform MANOVA on filtered data
manova_model = MANOVA.from_formula(" + ".join(dependent_vars) + " ~ Session_Type", data=filtered_data)
manova_results = manova_model.mv_test()

# Define the title for the Multivariate Linear Model section
stim_session_rows = filtered_data[filtered_data['Session_Type'] == 'Stim Session']
selected_behavior = stim_session_rows['Selected Behavior'].iloc[0]
fiber_connection = stim_session_rows['Fiber Connection'].iloc[0]

title = f"{selected_behavior} {fiber_connection} Multivariate Linear Model (excluding zeros for each dependent variable)"

# Print results with modified title
print(title.center(60, '='))
print(manova_results.summary())

# %%
# Define the dependent variables
dependent_vars = ['Right_Turn_Pre_Bout', 'Right_Turn_Stim_Bout_Count',
       'Right_Turn_Post_Bout', 'Left_Turn_Pre_Bout',
       'Left_Turn_Stim_Bout_Count', 'Left_Turn_Post_Bout',
       'Locomotion_Pre_Bout', 'Locomotion_Stim_Bout_Count',
       'Locomotion_Post_Bout', 'Face_Groom_Pre_Bout',
       'Face_Groom_Stim_Bout_Count', 'Face_Groom_Post_Bout',
       'All_Other_Groom_Pre_Bout', 'All_Other_Groom_Stim_Bout_Count',
       'All_Other_Groom_Post_Bout', 'All_Other_Pre_Bout',
       'All_Other_Stim_Bout_Count', 'All_Other_Post_Bout']

# Extract variables containing the substring "Stim_Bout_Count"
Bout_stim_vars = [var for var in dependent_vars if 'Stim_Bout_Count' in var]

# Create a copy of the original dataframe
filtered_data = anovadf.copy()

# Filter out zero values for each dependent variable separately
for var in Bout_stim_vars:
    filtered_data = filtered_data[filtered_data[var] != 0]

# Perform MANOVA on filtered data
manova_model = MANOVA.from_formula(" + ".join(Bout_stim_vars) + " ~ Session_Type", data=filtered_data)
manova_results = manova_model.mv_test()

# Define the title for the Multivariate Linear Model section
stim_session_rows = filtered_data[filtered_data['Session_Type'] == 'Stim Session']
selected_behavior = stim_session_rows['Selected Behavior'].iloc[0]
fiber_connection = stim_session_rows['Fiber Connection'].iloc[0]

title = f"{selected_behavior} {fiber_connection} Multivariate Linear Model (excluding zeros for each dependent variable)"

# Print results with modified title
print(title.center(60, '='))
print(manova_results.summary())

# %%
# Define the file path
file_path = "/Users/kaycei/K on Server (NoMachine)/KayCei/Naturalistic Closed Loop/Totals/Multivariance with manova"

# Save MANOVA results to a file with the title as the filename
filename = os.path.join(file_path, f"{title}.csv")
manova_results_summary = manova_results.summary().as_text()
with open(filename, 'w') as f:
    f.write(manova_results_summary)

# %%
anovadf

# %%
import pandas as pd
from scipy.stats import ttest_rel

# Define the group names and corresponding columns from anovadf
group_columns = {
    'Right': ['Right_Turn_Pre_Bout', 'Right_Turn_Stim_Bout_Count', 'Right_Turn_Post_Bout'],
    'Left': ['Left_Turn_Pre_Bout', 'Left_Turn_Stim_Bout_Count', 'Left_Turn_Post_Bout'],
    'Locomotion': ['Locomotion_Pre_Bout', 'Locomotion_Stim_Bout_Count', 'Locomotion_Post_Bout'],
    'Face Groom':['Face_Groom_Pre_Bout','Face_Groom_Stim_Bout_Count', 'Face_Groom_Post_Bout',],
    'All Other Groom':['All_Other_Groom_Pre_Bout', 'All_Other_Groom_Stim_Bout_Count','All_Other_Groom_Post_Bout'],
    'All Other':['All_Other_Pre_Bout','All_Other_Stim_Bout_Count', 'All_Other_Post_Bout'],
}

# Initialize dictionaries to store results
group_comparison_results = {}
pairwise_comparison_results = {}

# Step 1: Subgroup Analysis and Pairwise Comparisons
for group, columns in group_columns.items():
    # Select columns related to the current group from anovadf
    group_data = anovadf[columns]

    # Separate data into "Stim" and "Sham" sessions
    stim_data_1 = group_data[anovadf['Session_Type'] == 'Stim Session']
    sham_data_1 = group_data[anovadf['Session_Type'] == 'Sham Session']

    # Ensure that the number of observations in "Stim" and "Sham" sessions are equal
    min_obs = min(len(stim_data_1), len(sham_data_1))
    if min_obs == 0:
        continue  # Skip this group if one of the sessions has no data
    stim_data = stim_data.sample(min_obs, replace=True, random_state=42)
    sham_data = sham_data.sample(min_obs, replace=True, random_state=42)

    # Perform paired t-test for "Stim" vs. "Sham" within the current group
    t_stat, p_value = ttest_rel(stim_data.values.flatten(), sham_data.values.flatten())
    group_comparison_results[group] = {'t_stat': t_stat, 'p_value': p_value}

    # Perform pairwise comparisons across groups
    other_groups = [other_group for other_group in group_columns.keys() if other_group != group]
    pairwise_comparison_results[group] = {}
    for other_group in other_groups:
        other_group_data = anovadf[group_columns[other_group]]

        # Perform paired t-test between the current group and other groups
        t_stat, p_value = ttest_rel(group_data.values.flatten(), other_group_data.values.flatten())
        pairwise_comparison_results[group][other_group] = {'t_stat': t_stat, 'p_value': p_value}

# %%
# Print subgroup analysis results
print("Subgroup Analysis Results:")
for group, result in group_comparison_results.items():
    print(f"Group: {group}")
    print(f"T-statistic: {result['t_stat']}")
    print(f"P-value: {result['p_value']}")
    print()

# Print pairwise comparison results
print("Pairwise Comparison Results:")
for group, comparisons in pairwise_comparison_results.items():
    print(f"Group: {group}")
    for other_group, result in comparisons.items():
        print(f"Comparison with {other_group}:")
        print(f"T-statistic: {result['t_stat']}")
        print(f"P-value: {result['p_value']}")
        print()

# %%
# Define the group names and corresponding columns
group_columns = {
    'Right': ['Right_Turn_Stim_Bout_Count'],
    'Left': ['Left_Turn_Stim_Bout_Count'],
    'Locomotion': ['Locomotion_Stim_Bout_Count'],
    'Face Groom': ['Face_Groom_Stim_Bout_Count'],
    'All Other Groom': ['All_Other_Groom_Stim_Bout_Count'],
    'All Other': ['All_Other_Stim_Bout_Count'],
}

# Initialize dictionaries to store results
group_comparison_results = {}
pairwise_comparison_results = {}

# Step 1: Subgroup Analysis and Pairwise Comparisons
for group, columns in group_columns.items():
    # Select columns related to the current group from anovadf
    group_data = anovadf[columns]

    # Separate data into "Stim" and "Sham" sessions
    stim_data = group_data[anovadf['Session_Type'] == 'Stim Session']
    sham_data = group_data[anovadf['Session_Type'] == 'Sham Session']

    # Ensure that the number of observations in "Stim" and "Sham" sessions are equal
    min_obs = min(len(stim_data), len(sham_data))
    stim_data = stim_data.sample(min_obs, random_state=42)
    sham_data = sham_data.sample(min_obs, random_state=42)

    # Perform paired t-test for "Stim" vs. "Sham" within the current group
    t_stat, p_value = ttest_rel(stim_data.values.flatten(), sham_data.values.flatten())
    group_comparison_results[group] = {'t_stat': t_stat, 'p_value': p_value}

    # Perform pairwise comparisons across groups
    other_groups = [other_group for other_group in group_columns.keys() if other_group != group]
    pairwise_comparison_results[group] = {}
    for other_group in other_groups:
        other_group_data = anovadf[group_columns[other_group]]

        # Perform paired t-test between the current group and other groups
        t_stat, p_value = ttest_rel(group_data.values.flatten(), other_group_data.values.flatten())
        pairwise_comparison_results[group][other_group] = {'t_stat': t_stat, 'p_value': p_value}

# %%
# Print subgroup analysis results
print("Subgroup Analysis Results:")
for group, result in group_comparison_results.items():
    print(f"Group: {group}")
    print(f"T-statistic: {result['t_stat']}")
    print(f"P-value: {result['p_value']}")
    print()

# Print pairwise comparison results
print("Pairwise Comparison Results:")
for group, comparisons in pairwise_comparison_results.items():
    print(f"Group: {group}")
    for other_group, result in comparisons.items():
        print(f"Comparison with {other_group}:")
        print(f"T-statistic: {result['t_stat']}")
        print(f"P-value: {result['p_value']}")
        print()

# %%
len(sham_data_1)

# %%
len(stim_data_1)

# %%
stim_data

# %%
print(min_obs)
