# %%
print(combined_df)
# Out:
#             Key,Total Bouts
# 0           Locomotion,5394
# 1   Investigate Type 2,4812
# 2        Contra-Orient,1802
# 3          Contra-Itch,1238
# 4    Investigate Type 1,250
# 5          Ipsi-Orient,1658
# 6        insignificant,2075
# 7      Ipsi-Itch Type 1,248
# 8          Dive/Scrunch,154
# 9     Face Groom Type 1,101
# 10      Ipsi-Body Groom,209
# 11   Investigate Type 3,147
# 12                 Rear,120
# 13            Head Groom,20
# 14              Paw-Groom,7
# 15    Contra-Body Groom,164
# 16      Face Groom Type 2,4
# 17          Locomotion,4143
# 18       Contra-Orient,1710
# 19         Ipsi-Orient,2053
# 20  Investigate Type 2,4497
# 21       insignificant,2597
# 22    Face Groom Type 1,183
# 23   Investigate Type 1,505
# 24          Contra-Itch,790
# 25         Dive/Scrunch,278
# 26     Ipsi-Itch Type 1,227
# 27   Investigate Type 3,281
# 28      Ipsi-Body Groom,147
# 29             Paw-Groom,16
# 30            Head Groom,36
# 31    Contra-Body Groom,131
# ...

# %%
# Iterate over the rows of the combined DataFrame and split the string to extract "Key" and "Total Bouts"
for index, row in combined_df.iterrows():
    data = row[0].split(',')
    if len(data) == 2:
        key = data[0].strip()
        total_bouts = int(data[1])
        print(f"Key: {key}, Total Bouts: {total_bouts}")

# Create a bar plot for combined data
plt.figure(figsize=(10, 6))
width = 0.35
x = range(len(combined_df))

# Create a bar plot using total_bouts directly (assuming it's an integer column)
plt.bar(x, [int(data.split(',')[1]) for data in combined_df.iloc[:, 0]], width, label='Combined Data')
plt.xlabel('Key')
plt.ylabel('Total Bouts')
plt.title('Comparison of Total Bouts for Each Key (Combined Data)')
plt.xticks(x, [data.split(',')[0].strip() for data in combined_df.iloc[:, 0]], rotation=90)

# Show the legend for the combined data
plt.legend()

# Show the combined plot
plt.tight_layout()
plt.show()
# Out:
# /var/folders/9t/qv6qlpv10ylgs0y_f9_d4hkr0000gn/T/ipykernel_1777/3282140731.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data = row[0].split(',')
# Key: Locomotion, Total Bouts: 5394
# Key: Investigate Type 2, Total Bouts: 4812
# Key: Contra-Orient, Total Bouts: 1802
# Key: Contra-Itch, Total Bouts: 1238
# Key: Investigate Type 1, Total Bouts: 250
# Key: Ipsi-Orient, Total Bouts: 1658
# Key: insignificant, Total Bouts: 2075
# Key: Ipsi-Itch Type 1, Total Bouts: 248
# Key: Dive/Scrunch, Total Bouts: 154
# Key: Face Groom Type 1, Total Bouts: 101
# Key: Ipsi-Body Groom, Total Bouts: 209
# Key: Investigate Type 3, Total Bouts: 147
# Key: Rear, Total Bouts: 120
# Key: Head Groom, Total Bouts: 20
# Key: Paw-Groom, Total Bouts: 7
# Key: Contra-Body Groom, Total Bouts: 164
# ...
